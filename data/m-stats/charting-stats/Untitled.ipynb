# %%
import pandas as pd
import numpy as np

# %%
key_points = pd.read_csv('charting-m-stats-KeyPointsReturn.csv', index_col = 0, engine = 'python', error_bad_lines = False)
key_points
# Out:
# Skipping line 2: Expected 8 fields in line 2, saw 19
# Skipping line 3: Expected 8 fields in line 3, saw 19
# Skipping line 4: Expected 8 fields in line 4, saw 19
# Skipping line 5: Expected 8 fields in line 5, saw 19
# Skipping line 6: Expected 8 fields in line 6, saw 19
# Skipping line 7: Expected 8 fields in line 7, saw 19
# Skipping line 8: Expected 8 fields in line 8, saw 19
# Skipping line 9: Expected 8 fields in line 9, saw 19
# Skipping line 10: Expected 8 fields in line 10, saw 19
# Skipping line 11: Expected 8 fields in line 11, saw 19
# Skipping line 12: Expected 8 fields in line 12, saw 19
# Skipping line 13: Expected 8 fields in line 13, saw 19
# Skipping line 14: Expected 8 fields in line 14, saw 19
# Skipping line 15: Expected 8 fields in line 15, saw 19
# Skipping line 16: Expected 8 fields in line 16, saw 19
# Skipping line 17: Expected 8 fields in line 17, saw 19
# Skipping line 18: Expected 8 fields in line 18, saw 19
# ...
