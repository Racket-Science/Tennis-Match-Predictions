# %%
# hmm
import pandas as pd
pd.options.display.max_columns = 50
pd.options.display.max_rows = 50
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read .csv into frame
df = pd.read_csv('ATPtotal.csv', index_col = 0)
df.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0  2019-M020     Brisbane    Hard         32             A      20181231
# 1  2019-M020     Brisbane    Hard         32             A      20181231
# 2  2019-M020     Brisbane    Hard         32             A      20181231
# 3  2019-M020     Brisbane    Hard         32             A      20181231
# 4  2019-M020     Brisbane    Hard         32             A      20181231
#
#    match_num  winner_id  winner_seed winner_entry         winner_name  \
# 0        300     105453          2.0          NaN       Kei Nishikori
# 1        299     106421          4.0          NaN     Daniil Medvedev
# 2        298     105453          2.0          NaN       Kei Nishikori
# 3        297     104542          NaN           PR  Jo-Wilfried Tsonga
# 4        296     106421          4.0          NaN     Daniil Medvedev
#
#   winner_hand  winner_ht winner_ioc  winner_age  loser_id  loser_seed  \
# ...

# %%
# check shape of frame
df.shape
# Out:
# (180305, 49)

# %%
# get dataframe info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 180305 entries, 0 to 2900
# Data columns (total 49 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   tourney_id          180305 non-null  object
#  1   tourney_name        180305 non-null  object
#  2   surface             177866 non-null  object
#  3   draw_size           180305 non-null  int64
#  4   tourney_level       180305 non-null  object
#  5   tourney_date        180305 non-null  int64
#  6   match_num           180305 non-null  int64
#  7   winner_id           180305 non-null  int64
#  8   winner_seed         68460 non-null   float64
#  9   winner_entry        15845 non-null   object
#  10  winner_name         180305 non-null  object
#  11  winner_hand         180245 non-null  object
#  12  winner_ht           161551 non-null  float64
#  13  winner_ioc          180297 non-null  object
#  14  winner_age          178334 non-null  float64
# ...

# %%
# list columns for compact view
df.columns
# Out:
# Index(['tourney_id', 'tourney_name', 'surface', 'draw_size', 'tourney_level',
#        'tourney_date', 'match_num', 'winner_id', 'winner_seed', 'winner_entry',
#        'winner_name', 'winner_hand', 'winner_ht', 'winner_ioc', 'winner_age',
#        'loser_id', 'loser_seed', 'loser_entry', 'loser_name', 'loser_hand',
#        'loser_ht', 'loser_ioc', 'loser_age', 'score', 'best_of', 'round',
#        'minutes', 'w_ace', 'w_df', 'w_svpt', 'w_1stIn', 'w_1stWon', 'w_2ndWon',
#        'w_SvGms', 'w_bpSaved', 'w_bpFaced', 'l_ace', 'l_df', 'l_svpt',
#        'l_1stIn', 'l_1stWon', 'l_2ndWon', 'l_SvGms', 'l_bpSaved', 'l_bpFaced',
#        'winner_rank', 'winner_rank_points', 'loser_rank', 'loser_rank_points'],
#       dtype='object')

# %%
# rename columns
df.columns = df.columns.str.lower()\
.str.replace('_ace', '_aces')\
.str.replace('df', 'double_faults')\
.str.replace('svpt', 'service_points')\
.str.replace('1stin', 'first_serves_in')\
.str.replace('1stwon', 'first_serve_points_won')\
.str.replace('2ndwon', 'second_serve_points_won')\
.str.replace('svgms', 'service_game_total')\
.str.replace('bpsaved', 'break_points_saved')\
.str.replace('bpfaced', 'break_points_faced')

# %%
# verify
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 180305 entries, 0 to 2900
# Data columns (total 49 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   tourney_id                 180305 non-null  object
#  1   tourney_name               180305 non-null  object
#  2   surface                    177866 non-null  object
#  3   draw_size                  180305 non-null  int64
#  4   tourney_level              180305 non-null  object
#  5   tourney_date               180305 non-null  int64
#  6   match_num                  180305 non-null  int64
#  7   winner_id                  180305 non-null  int64
#  8   winner_seed                68460 non-null   float64
#  9   winner_entry               15845 non-null   object
#  10  winner_name                180305 non-null  object
#  11  winner_hand                180245 non-null  object
#  12  winner_ht                  161551 non-null  float64
# ...

# %%
df.to_csv('ATP_updated_columns.csv')
