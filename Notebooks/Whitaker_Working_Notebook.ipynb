# %% [markdown]
# ## Chloe's Scratchpad for the Tennis Predictions Group Project

# %% [markdown]
# ### imports

# %%
# imports

import pandas as pd
import numpy as np

# Custom Helper Files
from prepare import *

# Ignore Warnings
import warnings
warnings.filterwarnings("ignore")

# Remove Limits On Viewing Dataframes
pd.set_option('display.max_columns', None)

# %%
# read .csv
# df = pd.read_csv('PlayerData.csv')

# %%
# df.head()

# %%
# read .csv
player1 = pd.read_csv('ATPUpdated.csv')

# %%
player1.head()
# Out:
#    Unnamed: 0 tourney_id tourney_name surface  draw_size tourney_level  \
# 0           0  2019-M020     Brisbane    Hard         32             A
# 1           1  2019-M020     Brisbane    Hard         32             A
# 2           2  2019-M020     Brisbane    Hard         32             A
# 3           3  2019-M020     Brisbane    Hard         32             A
# 4           4  2019-M020     Brisbane    Hard         32             A
#
#    tourney_date  match_num  Player1_id  Player1_seed Player1_entry  \
# 0      20181231        300      105453           2.0           NaN
# 1      20181231        299      106421           4.0           NaN
# 2      20181231        298      105453           2.0           NaN
# 3      20181231        297      104542           NaN            PR
# 4      20181231        296      106421           4.0           NaN
#
#          Player1_name Player1_hand  Player1_ht Player1_ioc  Player1_age  \
# ...

# %%
player1.columns
# Out:
# Index(['Unnamed: 0', 'tourney_id', 'tourney_name', 'surface', 'draw_size',
#        'tourney_level', 'tourney_date', 'match_num', 'Player1_id',
#        'Player1_seed', 'Player1_entry', 'Player1_name', 'Player1_hand',
#        'Player1_ht', 'Player1_ioc', 'Player1_age', 'Player2_id',
#        'Player2_seed', 'Player2_entry', 'Player2_name', 'Player2_hand',
#        'Player2_ht', 'Player2_ioc', 'Player2_age', 'score', 'best_of', 'round',
#        'minutes', 'Player1_aces', 'Player1_double_faults',
#        'Player1_service_points', 'Player1_first_serves_in',
#        'Player1_first_serve_points_won', 'Player1_second_serve_points_won',
#        'Player1_service_game_total', 'Player1_break_points_saved',
#        'Player1_break_points_faced', 'Player2_aces', 'Player2_double_faults',
#        'Player2_service_points', 'Player2_first_serves_in',
#        'Player2_first_serve_points_won', 'Player2_second_serve_points_won',
# ...

# %%
player2 = player1.copy(0)

# %%
player2.head()
# Out:
#    Unnamed: 0 tourney_id tourney_name surface  draw_size tourney_level  \
# 0           0  2019-M020     Brisbane    Hard         32             A
# 1           1  2019-M020     Brisbane    Hard         32             A
# 2           2  2019-M020     Brisbane    Hard         32             A
# 3           3  2019-M020     Brisbane    Hard         32             A
# 4           4  2019-M020     Brisbane    Hard         32             A
#
#    tourney_date  match_num  Player1_id  Player1_seed Player1_entry  \
# 0      20181231        300      105453           2.0           NaN
# 1      20181231        299      106421           4.0           NaN
# 2      20181231        298      105453           2.0           NaN
# 3      20181231        297      104542           NaN            PR
# 4      20181231        296      106421           4.0           NaN
#
#          Player1_name Player1_hand  Player1_ht Player1_ioc  Player1_age  \
# ...

# %%
player2 = player2.rename(columns = {'Player1_id': 'Player2_id', 'Player1_seed': 'Player2_seed', 'Player1_entry': 'Player2_entry', 'Player1_name': 'Player2_name', 'Player1_hand': 'Player2_hand', 'Player1_ht': 'Player2_ht', 'Player1_ioc': 'Player2_ioc', 'Player1_age': 'Player2_age', 'Player2_id': 'Player1_id', 'Player2_seed': 'Player1_seed', 'Player2_entry': 'Player1_entry', 'Player2_name': 'Player1_name', 'Player2_hand': 'Player1_hand', 'Player2_ht': 'Player1_ht', 'Player2_ioc': 'Player1_ioc', 'Player2_age': 'Player1_age'})

# %%
player2.head()
# Out:
#    Unnamed: 0 tourney_id tourney_name surface  draw_size tourney_level  \
# 0           0  2019-M020     Brisbane    Hard         32             A
# 1           1  2019-M020     Brisbane    Hard         32             A
# 2           2  2019-M020     Brisbane    Hard         32             A
# 3           3  2019-M020     Brisbane    Hard         32             A
# 4           4  2019-M020     Brisbane    Hard         32             A
#
#    tourney_date  match_num  Player2_id  Player2_seed Player2_entry  \
# 0      20181231        300      105453           2.0           NaN
# 1      20181231        299      106421           4.0           NaN
# 2      20181231        298      105453           2.0           NaN
# 3      20181231        297      104542           NaN            PR
# 4      20181231        296      106421           4.0           NaN
#
#          Player2_name Player2_hand  Player2_ht Player2_ioc  Player2_age  \
# ...

# %%
player2 = player2.rename(columns = {'Player1_aces': 'Player2_aces', 'Player1_double_faults': 'Player2_double_faults', 'Player1_service_points': 'Player2_service_points', 'Player1_first_serves_in': 'Player2_first_serves_in', 'Player1_first_serve_points_won': 'Player2_first_serve_points_won', 'Player1_second_serve_points_won': 'Player2_second_serve_points_won', 'Player1_service_game_total': 'Player2_service_game_total', 'Player1_break_points_saved': 'Player2_break_points_saved', 'Player1_break_points_faced': 'Player2_break_points_faced', 'Player2_aces': 'Player1_aces', 'Player2_double_faults': 'Player1_double_faults', 'Player2_service_points': 'Player1_service_points', 'Player2_first_serves_in': 'Player1_first_serves_in', 'Player2_first_serve_points_won': 'Player1_first_serve_points_won', 'Player2_second_serve_points_won': 'Player1_second_serve_points_won', 'Player2_service_game_total': 'Player1_service_game_total', 'Player2_break_points_saved': 'Player1_break_points_saved', 'Player2_break_points_faced': 'Player1_break_points_faced'})

# %%
player2.head()
# Out:
#    Unnamed: 0 tourney_id tourney_name surface  draw_size tourney_level  \
# 0           0  2019-M020     Brisbane    Hard         32             A
# 1           1  2019-M020     Brisbane    Hard         32             A
# 2           2  2019-M020     Brisbane    Hard         32             A
# 3           3  2019-M020     Brisbane    Hard         32             A
# 4           4  2019-M020     Brisbane    Hard         32             A
#
#    tourney_date  match_num  Player2_id  Player2_seed Player2_entry  \
# 0      20181231        300      105453           2.0           NaN
# 1      20181231        299      106421           4.0           NaN
# 2      20181231        298      105453           2.0           NaN
# 3      20181231        297      104542           NaN            PR
# 4      20181231        296      106421           4.0           NaN
#
#          Player2_name Player2_hand  Player2_ht Player2_ioc  Player2_age  \
# ...

# %%
player2 = player2.rename(columns = {'Player1_rank': 'Player2_rank', 'Player1_rank_points': 'Player2_rank_points', 'Player2_rank': 'Player1_rank', 'Player2_rank_points': 'Player1_rank_points', 'Player1_first_serve_%': 'Player2_first_serve_%', 'Player1_first_serve_win_%': 'Player2_first_serve_win_%', 'Player1_break_points_won': 'Player2_break_points_won', 'Player2_first_serve_%': 'Player1_first_serve_%', 'Player2_first_serve_win_%': 'Player1_first_serve_win_%', 'Player2_break_points_won': 'Player1_break_points_won'})

# %%
player2.head()
# Out:
#    Unnamed: 0 tourney_id tourney_name surface  draw_size tourney_level  \
# 0           0  2019-M020     Brisbane    Hard         32             A
# 1           1  2019-M020     Brisbane    Hard         32             A
# 2           2  2019-M020     Brisbane    Hard         32             A
# 3           3  2019-M020     Brisbane    Hard         32             A
# 4           4  2019-M020     Brisbane    Hard         32             A
#
#    tourney_date  match_num  Player2_id  Player2_seed Player2_entry  \
# 0      20181231        300      105453           2.0           NaN
# 1      20181231        299      106421           4.0           NaN
# 2      20181231        298      105453           2.0           NaN
# 3      20181231        297      104542           NaN            PR
# 4      20181231        296      106421           4.0           NaN
#
#          Player2_name Player2_hand  Player2_ht Player2_ioc  Player2_age  \
# ...

# %%
# # read .csv
# df1 = pd.read_csv('Player1.csv')

# %%
# df1.head(1)

# %%
# # read .csv
# df2 = pd.read_csv('Player2.csv')

# %%
# df2.head(1)

# %%
frames = [player1, player2]

# %%
combined_df = pd.concat(frames)

# %%
combined_df.head(1)
# Out:
#    Unnamed: 0 tourney_id tourney_name surface  draw_size tourney_level  \
# 0           0  2019-M020     Brisbane    Hard         32             A
#
#    tourney_date  match_num  Player1_id  Player1_seed Player1_entry  \
# 0      20181231        300      105453           2.0           NaN
#
#     Player1_name Player1_hand  Player1_ht Player1_ioc  Player1_age  \
# 0  Kei Nishikori            R       178.0         JPN    29.004791
#
#    Player2_id  Player2_seed Player2_entry     Player2_name Player2_hand  \
# 0      106421           4.0           NaN  Daniil Medvedev            R
#
#    Player2_ht Player2_ioc  Player2_age        score  best_of round  minutes  \
# 0       198.0         RUS    22.885695  6-4 3-6 6-2        3     F    124.0
#
#    Player1_aces  Player1_double_faults  Player1_service_points  \
# 0           3.0                    3.0                    77.0
#
#    Player1_first_serves_in  Player1_first_serve_points_won  \
# ...

# %%
combined_df.shape
# Out:
# (360610, 56)

# %%
combined_df.sample(10)
# Out:
#         Unnamed: 0 tourney_id   tourney_name surface  draw_size tourney_level  \
# 112102        1919   1971-425  Barcelona WCT    Clay         64             A
# 114949        1405   1970-424       Berkeley    Hard         64             A
# 117659        1533   1999-520  Roland Garros    Clay        128             G
# 56073         2157   1987-419   Indianapolis    Clay         56             A
# 100893        2639   1989-434          Seoul    Hard         32             A
# 115345        1801   1970-540      Wimbledon   Grass        128             G
# 115502        1958   1970-560        US Open   Grass        128             G
# 53930           14   1987-201        Guaruja    Hard         32             A
# 125222        2444   1973-423    Los Angeles    Hard         64             A
# 127674         772   1998-403  Miami Masters    Hard         96             M
#
#         tourney_date  match_num  Player1_id  Player1_seed Player1_entry  \
# ...

# %%
combined_df.match_num.unique().shape
# Out:
# (497,)

# %%
# save df to csv in current location
combined_df.to_csv('ATPUpdated_Combined.csv')

# %%
# read .csv
df = pd.read_csv('ATPUpdated_Combined.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 tourney_id tourney_name surface  draw_size  \
# 0           0             0  2019-M020     Brisbane    Hard         32
# 1           1             1  2019-M020     Brisbane    Hard         32
# 2           2             2  2019-M020     Brisbane    Hard         32
# 3           3             3  2019-M020     Brisbane    Hard         32
# 4           4             4  2019-M020     Brisbane    Hard         32
#
#   tourney_level  tourney_date  match_num  Player1_id  Player1_seed  \
# 0             A      20181231        300      105453           2.0
# 1             A      20181231        299      106421           4.0
# 2             A      20181231        298      105453           2.0
# 3             A      20181231        297      104542           NaN
# 4             A      20181231        296      106421           4.0
#
#   Player1_entry        Player1_name Player1_hand  Player1_ht Player1_ioc  \
# ...

# %%
df.shape
# Out:
# (360610, 57)

# %%
# check to see if combined properly
df[df.Player1_name.isin(['Kei Nishikori'])]
# Out:
#         Unnamed: 0  Unnamed: 0.1 tourney_id      tourney_name surface  \
# 0                0             0  2019-M020          Brisbane    Hard
# 2                2             2  2019-M020          Brisbane    Hard
# 6                6             6  2019-M020          Brisbane    Hard
# 14              14            14  2019-M020          Brisbane    Hard
# 160            160           160   2019-580   Australian Open    Hard
# ...            ...           ...        ...               ...     ...
# 360130      179825          2421   2014-560           US Open    Hard
# 360378      180073          2669  2014-5014  Shanghai Masters    Hard
# 360589      180284          2880   2014-352     Paris Masters    Hard
# 360598      180293          2889   2014-605       Tour Finals    Hard
# 360605      180300          2896   2014-605       Tour Finals    Hard
#
#         draw_size tourney_level  tourney_date  match_num  Player1_id  \
# ...

# %%
# check to see if combined properly
df[df.Player2_name.isin(['Kei Nishikori'])]
# Out:
#         Unnamed: 0  Unnamed: 0.1 tourney_id          tourney_name surface  \
# 145            145           145   2019-580       Australian Open    Hard
# 402            402           402  2019-0407             Rotterdam    Hard
# 559            559           559  2019-0495                 Dubai    Hard
# 633            633           633  2019-M006  Indian Wells Masters    Hard
# 751            751           751  2019-M007         Miami Masters    Hard
# ...            ...           ...        ...                   ...     ...
# 360568      180263          2859   2014-352         Paris Masters    Hard
# 360580      180275          2871   2014-352         Paris Masters    Hard
# 360586      180281          2877   2014-352         Paris Masters    Hard
# 360600      180295          2891   2014-605           Tour Finals    Hard
# 360601      180296          2892   2014-605           Tour Finals    Hard
#
#         draw_size tourney_level  tourney_date  match_num  Player1_id  \
# ...

# %% [markdown]
# ### Acquire

# %% [markdown]
# Changed winner/loser to player1/player2 based on whose name came alphabetically first (outsourced code for that part).

# %% [markdown]
# Dataset with randomized player1 and player2:

# %%
# # read .csv
# df = pd.read_csv('ATPMain.csv')

# %%
df = prepare_atp()

# %%
df.head()
# Out:
#              tourney_id                 tourney_name surface  draw_size  \
# tourney_date
# 1968-03-20    1968-D042  Davis Cup G2 SF: SRI vs MAS    Clay          4
# 1968-03-20    1968-D042  Davis Cup G2 SF: SRI vs MAS    Clay          4
# 1968-03-20    1968-D042  Davis Cup G2 SF: SRI vs MAS    Clay          4
# 1968-03-20    1968-D042  Davis Cup G2 SF: SRI vs MAS    Clay          4
# 1968-03-23    1968-D039  Davis Cup G2 SF: JPN vs KOR     NaN          4
#
#              tourney_level  match_num                score  best_of round  \
# tourney_date
# 1968-03-20               D          1  6-4 6-4 3-6 3-6 6-4        5    RR
# 1968-03-20               D          2          6-0 6-2 6-4        5    RR
# 1968-03-20               D          4          6-3 6-3 7-5        5    RR
# 1968-03-20               D          5          8-6 6-3 6-2        5    RR
# 1968-03-23               D          1      6-1 6-2 6-8 6-1        5    RR
#
# ...

# %% [markdown]
# ### Prepare

# %%
# Drop duplicates if any

print(df.shape)
df = df.drop_duplicates()
print(df.shape)
# Out:
# (134602, 57)
# (134602, 57)

# %% [markdown]
# There are no duplicates.

# %%
df.isnull().sum()
# Out:
# tourney_id                               0
# tourney_name                             0
# surface                               1866
# draw_size                                0
# tourney_level                            0
# match_num                                0
# score                                    8
# best_of                                  0
# round                                    0
# minutes                              70801
# player_1                                 0
# player_2                                 0
# player_1_age                          2412
# player_2_age                          2533
# player_1_entry                      118734
# player_2_entry                      118449
# player_1_hand                           77
# player_2_hand                           65
# player_1_ht                          17800
# player_2_ht                          17303
# player_1_id                              0
# player_2_id                              0
# ...

# %% [markdown]
# My goal is modeling (MVP) so I'm going to add only the columns that i need to a new copied df, and prepare it from there.

# %%
df.columns
# Out:
# Index(['tourney_id', 'tourney_name', 'surface', 'draw_size', 'tourney_level',
#        'match_num', 'score', 'best_of', 'round', 'minutes', 'player_1',
#        'player_2', 'player_1_age', 'player_2_age', 'player_1_entry',
#        'player_2_entry', 'player_1_hand', 'player_2_hand', 'player_1_ht',
#        'player_2_ht', 'player_1_id', 'player_2_id', 'player_1_ioc',
#        'player_2_ioc', 'player_1_name', 'player_2_name', 'player_1_rank',
#        'player_2_rank', 'player_1_rank_points', 'player_2_rank_points',
#        'player_1_seed', 'player_2_seed', 'player_1_aces', 'player_2_aces',
#        'player_1_double_faults', 'player_2_double_faults',
#        'player_1_service_points', 'player_2_service_points',
#        'player_1_first_serves_in', 'player_2_first_serves_in',
#        'player_1_first_serve_points_won', 'player_2_first_serve_points_won',
#        'player_1_second_serve_points_won', 'player_2_second_serve_points_won',
# ...

# %%
dfm = df[['tourney_id', 'surface', 'draw_size',
       'tourney_level', 'best_of',
       'round', 'player_1', 'player_2', 'player_1_age',
       'player_2_age', 'player_1_hand',
       'player_2_hand', 'player_1_ht', 'player_2_ht', 'player_1_ioc', 'player_2_ioc', 'player_1_name',
       'player_2_name', 'player_1_rank', 'player_2_rank',
       'player_1_rank_points', 'player_2_rank_points', 'winner']].copy(0)

# %%
dfm.head()
# Out:
#              tourney_id surface  draw_size tourney_level  best_of round  \
# tourney_date
# 1968-03-20    1968-D042    Clay          4             D        5    RR
# 1968-03-20    1968-D042    Clay          4             D        5    RR
# 1968-03-20    1968-D042    Clay          4             D        5    RR
# 1968-03-20    1968-D042    Clay          4             D        5    RR
# 1968-03-23    1968-D039     NaN          4             D        5    RR
#
#                    player_1           player_2  player_1_age  player_2_age  \
# tourney_date
# 1968-03-20    Bernard Pinto  Sultan Aman Azman     39.624914           NaN
# 1968-03-20        Billy Yap      Senaka Kumara           NaN           NaN
# 1968-03-20    Bernard Pinto          Billy Yap     39.624914           NaN
# 1968-03-20    Senaka Kumara  Sultan Aman Azman           NaN           NaN
# 1968-03-23       Ek Son Lee      Toshiro Sakai           NaN      20.33128
#
# ...

# %%
dfm.surface.describe()
# Out:
# count     132736
# unique         4
# top         Hard
# freq       52697
# Name: surface, dtype: object

# %%
# create dummy columns for surface column and concat to df
dummy_df = pd.get_dummies(dfm[['surface', 'tourney_level', 'player_1_hand', 'player_2_hand', 'round']], dummy_na=False, drop_first=[False])
dfm = pd.concat([dfm, dummy_df], axis=1)

# %%
dfm.head()
# Out:
#              tourney_id surface  draw_size tourney_level  best_of round  \
# tourney_date
# 1968-03-20    1968-D042    Clay          4             D        5    RR
# 1968-03-20    1968-D042    Clay          4             D        5    RR
# 1968-03-20    1968-D042    Clay          4             D        5    RR
# 1968-03-20    1968-D042    Clay          4             D        5    RR
# 1968-03-23    1968-D039     NaN          4             D        5    RR
#
#                    player_1           player_2  player_1_age  player_2_age  \
# tourney_date
# 1968-03-20    Bernard Pinto  Sultan Aman Azman     39.624914           NaN
# 1968-03-20        Billy Yap      Senaka Kumara           NaN           NaN
# 1968-03-20    Bernard Pinto          Billy Yap     39.624914           NaN
# 1968-03-20    Senaka Kumara  Sultan Aman Azman           NaN           NaN
# 1968-03-23       Ek Son Lee      Toshiro Sakai           NaN      20.33128
#
# ...

# %%
dfm.dtypes
# Out:
# tourney_id               object
# surface                  object
# draw_size                 int64
# tourney_level            object
# best_of                   int64
# round                    object
# player_1                 object
# player_2                 object
# player_1_age            float64
# player_2_age            float64
# player_1_hand            object
# player_2_hand            object
# player_1_ht             float64
# player_2_ht             float64
# player_1_ioc             object
# player_2_ioc             object
# player_1_name            object
# player_2_name            object
# player_1_rank           float64
# player_2_rank           float64
# player_1_rank_points    float64
# player_2_rank_points    float64
# winner                   object
# surface_Clay              uint8
# surface_Grass             uint8
# surface_Hard              uint8
# tourney_level_D           uint8
# tourney_level_F           uint8
# tourney_level_G           uint8
# ...

# %%
dfm['player1_wins'] = np.where(dfm['winner'] == dfm['player1_name'], True, False)
dfm.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'player1_name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-131-74b9280a509e> in <module>
# ...

# %%
# drop null rows in weight column

# %%
saa, sk, bp, sk, ts
saa, sk, by, saa, ts
