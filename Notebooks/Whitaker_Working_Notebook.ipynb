# %% [markdown]
# ## Chloe's Scratchpad for the Tennis Predictions Group Project

# %% [markdown]
# ### imports

# %%
# imports

import pandas as pd
import numpy as np
import regex as re

# Custom Helper Files
from prepare import *

# Split 
from sklearn.model_selection import train_test_split

# Ignore Warnings
import warnings
warnings.filterwarnings("ignore")

# Remove Limits On Viewing Dataframes
pd.set_option('display.max_columns', None)

# %%
# read .csv
# df = pd.read_csv('PlayerData.csv')

# %%
# df.head()

# %%
# # read .csv
# player1 = pd.read_csv('ATPUpdated.csv')

# %%
# player1.head()

# %%
# player1.columns

# %%
# player2 = player1.copy(0)

# %%
# player2.head()

# %%
# player2 = player2.rename(columns = {'Player1_id': 'Player2_id', 'Player1_seed': 'Player2_seed', 'Player1_entry': 'Player2_entry', 'Player1_name': 'Player2_name', 'Player1_hand': 'Player2_hand', 'Player1_ht': 'Player2_ht', 'Player1_ioc': 'Player2_ioc', 'Player1_age': 'Player2_age', 'Player2_id': 'Player1_id', 'Player2_seed': 'Player1_seed', 'Player2_entry': 'Player1_entry', 'Player2_name': 'Player1_name', 'Player2_hand': 'Player1_hand', 'Player2_ht': 'Player1_ht', 'Player2_ioc': 'Player1_ioc', 'Player2_age': 'Player1_age'})

# %%
# player2.head()

# %%
# player2 = player2.rename(columns = {'Player1_aces': 'Player2_aces', 'Player1_double_faults': 'Player2_double_faults', 'Player1_service_points': 'Player2_service_points', 'Player1_first_serves_in': 'Player2_first_serves_in', 'Player1_first_serve_points_won': 'Player2_first_serve_points_won', 'Player1_second_serve_points_won': 'Player2_second_serve_points_won', 'Player1_service_game_total': 'Player2_service_game_total', 'Player1_break_points_saved': 'Player2_break_points_saved', 'Player1_break_points_faced': 'Player2_break_points_faced', 'Player2_aces': 'Player1_aces', 'Player2_double_faults': 'Player1_double_faults', 'Player2_service_points': 'Player1_service_points', 'Player2_first_serves_in': 'Player1_first_serves_in', 'Player2_first_serve_points_won': 'Player1_first_serve_points_won', 'Player2_second_serve_points_won': 'Player1_second_serve_points_won', 'Player2_service_game_total': 'Player1_service_game_total', 'Player2_break_points_saved': 'Player1_break_points_saved', 'Player2_break_points_faced': 'Player1_break_points_faced'})

# %%
# player2.head()

# %%
# player2 = player2.rename(columns = {'Player1_rank': 'Player2_rank', 'Player1_rank_points': 'Player2_rank_points', 'Player2_rank': 'Player1_rank', 'Player2_rank_points': 'Player1_rank_points', 'Player1_first_serve_%': 'Player2_first_serve_%', 'Player1_first_serve_win_%': 'Player2_first_serve_win_%', 'Player1_break_points_won': 'Player2_break_points_won', 'Player2_first_serve_%': 'Player1_first_serve_%', 'Player2_first_serve_win_%': 'Player1_first_serve_win_%', 'Player2_break_points_won': 'Player1_break_points_won'})

# %%
# player2.head()

# %%
# # read .csv
# df1 = pd.read_csv('Player1.csv')

# %%
# df1.head(1)

# %%
# # read .csv
# df2 = pd.read_csv('Player2.csv')

# %%
# df2.head(1)

# %% [markdown]
# Concat the two frames together

# %%
# frames = [player1, player2]

# %%
# combined_df = pd.concat(frames)

# %%
# combined_df.head(1)

# %%
# combined_df.shape

# %%
# combined_df.sample(10)

# %%
# combined_df.match_num.unique().shape

# %%
# # save df to csv in current location
# combined_df.to_csv('ATPUpdated_Combined.csv')

# %%
# # read .csv
# df = pd.read_csv('ATPUpdated_Combined.csv')

# %%
# df.head()

# %%
# df.shape

# %%
# # check to see if combined properly
# df[df.Player1_name.isin(['Kei Nishikori'])]

# %%
# # check to see if combined properly
# df[df.Player2_name.isin(['Kei Nishikori'])]

# %% [markdown]
# ### Acquire

# %% [markdown]
# Changed winner/loser to player1/player2 based on whose name came alphabetically first (outsourced code for that part).

# %% [markdown]
# Dataset with randomized player1 and player2:

# %%
# # read .csv
# df = pd.read_csv('ATPMain.csv')

# %%
# df = prepare_atp()

# %%
# df.head()

# %% [markdown]
# ### Prepare

# %%
# # Drop duplicates if any

# print(df.shape)
# df = df.drop_duplicates()
# print(df.shape)

# %% [markdown]
# There are no duplicates.

# %%
# df.isnull().sum()

# %% [markdown]
# My goal is modeling (MVP) so I'm going to add only the columns that i need to a new copied df, and prepare it from there.

# %%
# df.columns

# %%
# dfm = df[['tourney_id', 'surface', 'draw_size',
#        'tourney_level', 'best_of',
#        'round', 'player_1', 'player_2', 'player_1_age',
#        'player_2_age', 'player_1_hand',
#        'player_2_hand', 'player_1_ht', 'player_2_ht', 'player_1_ioc', 'player_2_ioc', 'player_1_name',
#        'player_2_name', 'player_1_rank', 'player_2_rank',
#        'player_1_rank_points', 'player_2_rank_points', 'winner']].copy(0)

# %%
# dfm.head()

# %%
# dfm.surface.describe()

# %%
# # create dummy columns for surface column and concat to df
# dummy_df = pd.get_dummies(dfm[['surface', 'tourney_level', 'player_1_hand', 'player_2_hand', 'round']], dummy_na=False, drop_first=[False])
# dfm = pd.concat([dfm, dummy_df], axis=1)

# %%
# dfm.head()

# %%
# dfm.dtypes

# %%
# dfm['player_1_wins'] = np.where(dfm['winner'] == dfm['player_1_name'], True, False)
# dfm.head()

# %%
# dfm['player_1_wins'] = np.where(dfm['winner'] == dfm['player_1_name'], 1, 0)
# dfm.head()

# %%
# dfm.dtypes

# %%
# dfm.head()

# %%
# dfm.dtypes

# %%
# def prepare_atp():

#     # read .csv into a dataframe
#     df = pd.read_csv('ATPMain.csv', index_col = 0)

#     # set index to the tournament start date
#     df = df.set_index('tourney_date')

#     # convert index to datetime object and sort in ascending order
#     df.index = pd.to_datetime(df.index, format = '%Y%m%d')
#     df = df.sort_index(ascending = True)

#     # create target variable 
#     df['player_1_wins'] = np.where(df['winner'] == df['player_1_name'], True, False)

#     # create dummy columns for surface, level, hand, and round 
#     dummy_df = pd.get_dummies(df[['surface', 'tourney_level', 'player_1_hand', 'player_2_hand', 'round']], dummy_na=False, drop_first=[False])
#     # concat dummy columns to df
#     df = pd.concat([df, dummy_df], axis=1)
    

#     # drop all walkovers (no useful stats) and best of 1 matches (extremely rare format)
#     df = df.drop(df[df.score == 'W/O'].index)
#     df = df.drop(df[df.best_of == 1].index)

#     df_clean = df = df.dropna(subset=['player_1_aces'])
    
#     return df

# %%
df = prepare_atp()

# %%
df.head()
# Out:
#              tourney_id tourney_name surface  draw_size tourney_level  \
# tourney_date
# 1999-01-11     1999-338       Sydney    Hard         32             A
# 1999-01-11     1999-338       Sydney    Hard         32             A
# 1999-01-11     1999-338       Sydney    Hard         32             A
# 1999-01-11     1999-338       Sydney    Hard         32             A
# 1999-01-11     1999-338       Sydney    Hard         32             A
#
#               match_num        score  best_of round  minutes        player_1  \
# tourney_date
# 1999-01-11           16   7-6(1) 6-1        3   R32     84.0  Lleyton Hewitt
# 1999-01-11           15  5-7 6-3 6-2        3   R32    115.0  Martin Damm Sr
# 1999-01-11           14      6-2 6-4        3   R32     61.0   Jan Siemerink
# 1999-01-11           13      6-1 6-3        3   R32     43.0    Hicham Arazi
# 1999-01-11           12   6-3 7-6(4)        3   R32     85.0     Carlos Moya
#
# ...

# %% [markdown]
# Create a column with the total games played in each match.

# %%
# function to create a column adding all of the games in the score column together using regex

def total_games(s):
    num_list = re.findall('\d+', s)
    num_list = [int(x) for x in num_list]
    return sum(num_list)

df['total_games'] = df['score'].apply(total_games)
df
# Out:
#                                    tourney_id  \
# tourney_date
# 1999-01-11                           1999-338
# 1999-01-11                           1999-338
# 1999-01-11                           1999-338
# 1999-01-11                           1999-338
# 1999-01-11                           1999-338
# ...                                       ...
# 2019-11-23    2019-M-DC-2019-FLS-M-RUS-CAN-01
# 2019-11-23    2019-M-DC-2019-FLS-M-RUS-CAN-01
# 2019-11-23    2019-M-DC-2019-FLS-M-GBR-ESP-01
# 2019-11-24    2019-M-DC-2019-FLS-M-CAN-ESP-01
# 2019-11-24    2019-M-DC-2019-FLS-M-CAN-ESP-01
#
#                                  tourney_name surface  draw_size  \
# tourney_date
# 1999-01-11                             Sydney    Hard         32
# 1999-01-11                             Sydney    Hard         32
# 1999-01-11                             Sydney    Hard         32
# 1999-01-11                             Sydney    Hard         32
# ...

# %%
df.shape
# Out:
# (43704, 79)

# %%
# removes rows where the score contains letters that indicate a retirement, default, or walkover

score_mask = df['score'].apply(lambda x: bool(re.findall('[a-zA-Z]', x)))
df = df[~score_mask]
df
# Out:
#                                    tourney_id  \
# tourney_date
# 1999-01-11                           1999-338
# 1999-01-11                           1999-338
# 1999-01-11                           1999-338
# 1999-01-11                           1999-338
# 1999-01-11                           1999-338
# ...                                       ...
# 2019-11-23    2019-M-DC-2019-FLS-M-RUS-CAN-01
# 2019-11-23    2019-M-DC-2019-FLS-M-RUS-CAN-01
# 2019-11-23    2019-M-DC-2019-FLS-M-GBR-ESP-01
# 2019-11-24    2019-M-DC-2019-FLS-M-CAN-ESP-01
# 2019-11-24    2019-M-DC-2019-FLS-M-CAN-ESP-01
#
#                                  tourney_name surface  draw_size  \
# tourney_date
# 1999-01-11                             Sydney    Hard         32
# 1999-01-11                             Sydney    Hard         32
# 1999-01-11                             Sydney    Hard         32
# 1999-01-11                             Sydney    Hard         32
# ...

# %%
df.shape
# Out:
# (42336, 79)

# %%
# Remove Limits On Viewing Dataframes
pd.set_option('display.max_rows', None)

# %%
df.isnull().sum()
# Out:
# tourney_id                              0
# tourney_name                            0
# surface                                 0
# draw_size                               0
# tourney_level                           0
# match_num                               0
# score                                   0
# best_of                                 0
# round                                   0
# minutes                               933
# player_1                                0
# player_2                                0
# player_1_age                            0
# player_2_age                            0
# player_1_entry                      35039
# player_2_entry                      34811
# player_1_hand                          16
# player_2_hand                          11
# player_1_ht                          1116
# player_2_ht                          1042
# player_1_id                             0
# player_2_id                             0
# ...

# %%
dfm = df[['draw_size',
       'tourney_level', 'best_of', 'player_1', 'player_2', 'player_1_age',
       'player_2_age', 'player_1_hand',
       'player_2_hand', 'player_1_ht', 'player_2_ht', 'player_1_ioc', 'player_2_ioc', 'player_1_name',
       'player_2_name', 'player_1_rank', 'player_2_rank',
       'player_1_rank_points', 'player_2_rank_points', 'player_1_wins', 'round_ER', 'round_F', 'round_QF', 'round_R128', 'round_R16', 'round_R32', 'round_R64', 'round_RR', 'round_SF', 'player_1_hand_R', 'player_1_hand_U', 
       'tourney_level_D', 'tourney_level_F', 'tourney_level_G', 'tourney_level_M', 'surface_Clay',
       'surface_Grass', 'surface_Hard']].copy(0)

# %%
dfm.head()
# Out:
#               draw_size tourney_level  best_of        player_1  \
# tourney_date
# 1999-01-11           32             A        3  Lleyton Hewitt
# 1999-01-11           32             A        3  Martin Damm Sr
# 1999-01-11           32             A        3   Jan Siemerink
# 1999-01-11           32             A        3    Hicham Arazi
# 1999-01-11           32             A        3     Carlos Moya
#
#                       player_2  player_1_age  player_2_age player_1_hand  \
# tourney_date
# 1999-01-11      Patrick Rafter     17.878166     26.036961             R
# 1999-01-11      Nicolas Kiefer     26.444901     21.519507             R
# 1999-01-11      Mariano Puerta     28.744695     20.312115             L
# 1999-01-11         Todd Martin     25.229295     28.511978             L
# 1999-01-11    Thomas Johansson     22.373717     23.802875             R
#
#              player_2_hand  player_1_ht  player_2_ht player_1_ioc  \
# tourney_date
# ...

# %%
dfm.isnull().sum()
# Out:
# draw_size                  0
# tourney_level              0
# best_of                    0
# player_1                   0
# player_2                   0
# player_1_age               0
# player_2_age               0
# player_1_hand             16
# player_2_hand             11
# player_1_ht             1116
# player_2_ht             1042
# player_1_ioc               0
# player_2_ioc               0
# player_1_name              0
# player_2_name              0
# player_1_rank            136
# player_2_rank            104
# player_1_rank_points     136
# player_2_rank_points     104
# player_1_wins              0
# round_ER                   0
# round_F                    0
# round_QF                   0
# round_R128                 0
# round_R16                  0
# round_R32                  0
# round_R64                  0
# round_RR                   0
# round_SF                   0
# player_1_hand_R            0
# player_1_hand_U            0
# tourney_level_D            0
# ...

# %%
# drop null rows in specific columns
dfm = dfm[dfm.player_1_hand.notnull()]
dfm = dfm[dfm.player_2_hand.notnull()]
dfm = dfm[dfm.player_1_ht.notnull()]
dfm = dfm[dfm.player_2_ht.notnull()]
dfm = dfm[dfm.player_1_rank.notnull()]
dfm = dfm[dfm.player_2_rank.notnull()]
dfm = dfm[dfm.player_1_rank_points.notnull()]
dfm = dfm[dfm.player_2_rank_points.notnull()]

# %%
dfm.isnull().sum()
# Out:
# draw_size               0
# tourney_level           0
# best_of                 0
# player_1                0
# player_2                0
# player_1_age            0
# player_2_age            0
# player_1_hand           0
# player_2_hand           0
# player_1_ht             0
# player_2_ht             0
# player_1_ioc            0
# player_2_ioc            0
# player_1_name           0
# player_2_name           0
# player_1_rank           0
# player_2_rank           0
# player_1_rank_points    0
# player_2_rank_points    0
# player_1_wins           0
# round_ER                0
# round_F                 0
# round_QF                0
# round_R128              0
# round_R16               0
# round_R32               0
# round_R64               0
# round_RR                0
# round_SF                0
# player_1_hand_R         0
# player_1_hand_U         0
# tourney_level_D         0
# tourney_level_F         0
# tourney_level_G         0
# tourney_level_M         0
# ...

# %%
# Calculate the difference in stats between player1 and playeer2. Save to new column. 
dfm['ht_diff'] = dfm.player_1_ht - dfm.player_2_ht
dfm['age_diff'] = dfm.player_1_age - dfm.player_2_age
dfm['rank_diff'] = dfm.player_1_rank - dfm.player_2_rank
dfm['rank_points_diff'] = dfm.player_1_rank_points - dfm.player_2_rank_points

# %%
dfm.head()
# Out:
#               draw_size tourney_level  best_of        player_1  \
# tourney_date
# 1999-01-11           32             A        3  Lleyton Hewitt
# 1999-01-11           32             A        3  Martin Damm Sr
# 1999-01-11           32             A        3   Jan Siemerink
# 1999-01-11           32             A        3    Hicham Arazi
# 1999-01-11           32             A        3     Carlos Moya
#
#                       player_2  player_1_age  player_2_age player_1_hand  \
# tourney_date
# 1999-01-11      Patrick Rafter     17.878166     26.036961             R
# 1999-01-11      Nicolas Kiefer     26.444901     21.519507             R
# 1999-01-11      Mariano Puerta     28.744695     20.312115             L
# 1999-01-11         Todd Martin     25.229295     28.511978             L
# 1999-01-11    Thomas Johansson     22.373717     23.802875             R
#
#              player_2_hand  player_1_ht  player_2_ht player_1_ioc  \
# tourney_date
# ...

# %%
# split the data

# %%
def train_validate_test_split(dfm):
    '''
    This function takes in a dataframe (df) and returns 3 dfs
    (train, validate, and test) split 20%, 24%, 56% respectively. 
    
    Also takes in a random seed for replicating results.  
    '''
    
    from sklearn.model_selection import train_test_split
     
    train_and_validate, test = train_test_split(
        dfm, test_size=0.2, random_state=123, stratify=dfm.player_1_wins
    )
    train, validate = train_test_split(
        train_and_validate,
        test_size=0.3,
        random_state=123,
        stratify=train_and_validate.player_1_wins,
    )
    return train, validate, test

# %%
train, validate, test = train_validate_test_split(dfm)

# %%
train.head()
# Out:
#               draw_size tourney_level  best_of               player_1  \
# tourney_date
# 2016-04-25           32             A        3          Dominic Thiem
# 2000-07-17           32             A        3        Bohdan Ulihrach
# 2015-06-15           32             A        3      Fernando Verdasco
# 2018-08-27          128             G        5  Philipp Kohlschreiber
# 2013-02-18           32             A        3               Go Soeda
#
#                            player_2  player_1_age  player_2_age player_1_hand  \
# tourney_date
# 2016-04-25               Ivan Dodig     22.642026     31.310062             R
# 2000-07-17           Mariano Puerta     25.396304     21.826146             R
# 2015-06-15    Roberto Bautista Agut     31.581109     27.167693             L
# 2018-08-27         Yannick Hanfmann     34.863792     26.787132             R
# 2013-02-18        Marinko Matosevic     28.454483     27.531828             R
#
# ...

# %% [markdown]
# Plan for explore:

# %% [markdown]
# To identify features to use in modeling, separate the groups by wins / losses and then see if there was a significant difference between variables in that group. I'll take all of the matches that player1 wins and get the mean hight difference for player1 for that group then do the same for all of the matyches where player1 loses. If there is a significant difference then hight is likely a driver of winning and losing.

# %% [markdown]
# reference:
# https://www.dataquest.io/blog/tutorial-add-column-pandas-dataframe-based-on-if-else-condition/

# %%
# seperate player 1 wins and losses into dfs

# %%
player_1_w = train[train['player_1_wins'] == True]
player_1_l = train[train['player_1_wins'] == False]

# %%
player_1_w.head(1)
# Out:
#               draw_size tourney_level  best_of       player_1    player_2  \
# tourney_date
# 2016-04-25           32             A        3  Dominic Thiem  Ivan Dodig
#
#               player_1_age  player_2_age player_1_hand player_2_hand  \
# tourney_date
# 2016-04-25       22.642026     31.310062             R             R
#
#               player_1_ht  player_2_ht player_1_ioc player_2_ioc  \
# tourney_date
# 2016-04-25          185.0        183.0          AUT          CRO
#
#               player_1_name player_2_name  player_1_rank  player_2_rank  \
# tourney_date
# 2016-04-25    Dominic Thiem    Ivan Dodig           15.0           75.0
#
#               player_1_rank_points  player_2_rank_points  player_1_wins  \
# tourney_date
# 2016-04-25                  2420.0                 714.0           True
#
#               round_ER  round_F  round_QF  round_R128  round_R16  round_R32  \
# tourney_date
# 2016-04-25           0        0         1           0          0          0
#
# ...

# %%
player_1_w.shape
# Out:
# (10943, 42)

# %%
player_1_l.head(1)
# Out:
#               draw_size tourney_level  best_of         player_1  \
# tourney_date
# 2000-07-17           32             A        3  Bohdan Ulihrach
#
#                     player_2  player_1_age  player_2_age player_1_hand  \
# tourney_date
# 2000-07-17    Mariano Puerta     25.396304     21.826146             R
#
#              player_2_hand  player_1_ht  player_2_ht player_1_ioc  \
# tourney_date
# 2000-07-17               L        188.0        180.0          CZE
#
#              player_2_ioc    player_1_name   player_2_name  player_1_rank  \
# tourney_date
# 2000-07-17            ARG  Bohdan Ulihrach  Mariano Puerta           85.0
#
#               player_2_rank  player_1_rank_points  player_2_rank_points  \
# tourney_date
# 2000-07-17             21.0                 477.0                1211.0
#
#               player_1_wins  round_ER  round_F  round_QF  round_R128  \
# tourney_date
# 2000-07-17            False         0        0         0           0
#
# ...

# %%
player_1_l.shape
# Out:
# (11625, 42)

# %% [markdown]
# Use .mean() to compare variables.

# %%
# Hight
print('Average hight, all matches: ' + str(train['player_1_ht'].mean()))
print('Average hight, player 1 wins: ' + str(player_1_w['player_1_ht'].mean()))
print('Average hight, player 1 loses: ' + str(player_1_l['player_1_ht'].mean()))
print('\n')
# Out:
# Average hight, all matches: 185.4499734136831
# Average hight, player 1 wins: 185.65713241341496
# Average hight, player 1 loses: 185.25496774193547

# %% [markdown]
# Doesn't look like there's a significant difference in the average hight amongst wins and losses.

# %%
# Age
print('Average age, all matches: ' + str(train['player_1_age'].mean()))
print('Average age, player 1 wins: ' + str(player_1_w['player_1_age'].mean()))
print('Average age, player 1 loses: ' + str(player_1_l['player_1_age'].mean()))
print('\n')
# Out:
# Average age, all matches: 26.330231171755898
# Average age, player 1 wins: 26.23038540259904
# Average age, player 1 loses: 26.424219322455887

# %% [markdown]
# Doesn't look like there's a significant difference in the average age amongst wins and losses.

# %%
# Rank
print('Average rank, all matches: ' + str(train['player_1_rank'].mean()))
print('Average rank, player 1 wins: ' + str(player_1_w['player_1_rank'].mean()))
print('Average rank, player 1 loses: ' + str(player_1_l['player_1_rank'].mean()))
print('\n')
# Out:
# Average rank, all matches: 71.21043069833392
# Average rank, player 1 wins: 57.039660056657226
# Average rank, player 1 loses: 84.54984946236559

# %% [markdown]
# It does look like there's a significant difference in the average rank amongst wins and losses.

# %%
# Rank points
print('Average rank points, all matches: ' + str(train['player_1_rank_points'].mean()))
print('Average rank points, player 1 wins: ' + str(player_1_w['player_1_rank_points'].mean()))
print('Average rank points, player 1 loses: ' + str(player_1_l['player_1_rank_points'].mean()))
print('\n')
# Out:
# Average rank points, all matches: 1245.1468007798653
# Average rank points, player 1 wins: 1535.4688842182218
# Average rank points, player 1 loses: 971.8569462365591

# %% [markdown]
# It does look like there's a significant difference in the average rank points amongst wins and losses.

# %% [markdown]
# I will now perform a chi-square test to determin if "player_1_wins" and "player_1_rank" are independant.
#
# I will use a confidence interval of 95% meaning the alpha will be .05
#
# Ho: "Matches ending in player 1 winning and player1 rank are independant of one another.
# Ha: "Matches ending in player 1 winning and player1 rank are dependant on one another.`
