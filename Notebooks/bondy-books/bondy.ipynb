# %%
# hmm
import pandas as pd
pd.options.display.max_columns = 60
pd.options.display.max_rows = 60
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read .csv into frame
# df = pd.read_csv('ATPtotal.csv', index_col = 0)
# df.head()

# %%
# check shape of frame
# df.shape

# %%
# get dataframe info
# df.info()

# %%
# list columns for compact view
# df.columns

# %%
# rename columns
# df.columns = df.columns.str.lower()\
# .str.replace('_ace', '_aces')\
# .str.replace('df', 'double_faults')\
# .str.replace('svpt', 'service_points')\
# .str.replace('1stin', 'first_serves_in')\
# .str.replace('1stwon', 'first_serve_points_won')\
# .str.replace('2ndwon', 'second_serve_points_won')\
# .str.replace('svgms', 'service_game_total')\
# .str.replace('bpsaved', 'break_points_saved')\
# .str.replace('bpfaced', 'break_points_faced')

# %%
# verify
# df.info()

# %%
# df.to_csv('ATP_updated_columns.csv')

# %%
# df = pd.read_csv('ATPUpdated_Combined.csv', index_col = 0)
# df.head()

# %%
# df.info()

# %%
# df_2 = pd.read_csv('ATP_Updated2.0', index_col = 0)
# df_2.head(20)

# %%
# df_2.info()

# %%
# read another frame
df = pd.read_csv('ATPMain.csv', index_col = 0)
df.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0  2019-M020     Brisbane    Hard         32             A      20181231
# 1  2019-M020     Brisbane    Hard         32             A      20181231
# 2  2019-M020     Brisbane    Hard         32             A      20181231
# 3  2019-M020     Brisbane    Hard         32             A      20181231
# 4  2019-M020     Brisbane    Hard         32             A      20181231
#
#    match_num           score  best_of round  minutes         player_1  \
# 0        300     6-4 3-6 6-2        3     F    124.0  Daniil Medvedev
# 1        299      7-6(6) 6-2        3    SF     82.0  Daniil Medvedev
# 2        298         6-2 6-2        3    SF     66.0    Jeremy Chardy
# 3        297      6-4 7-6(2)        3    QF    106.0   Alex De Minaur
# 4        296  6-7(2) 6-3 6-4        3    QF    129.0  Daniil Medvedev
#
#              player_2  player_1_age  player_2_age player_1_entry  \
# ...

# %%
# check end of data
df.tail()
# Out:
#      tourney_id                tourney_name surface  draw_size tourney_level  \
# 2896   2014-605                 Tour Finals    Hard          8             F
# 2897   2014-605                 Tour Finals    Hard          8             F
# 2898  2014-D015  Davis Cup WG F: FRA vs SUI    Clay          4             D
# 2899  2014-D015  Davis Cup WG F: FRA vs SUI    Clay          4             D
# 2900  2014-D015  Davis Cup WG F: FRA vs SUI    Clay          4             D
#
#       tourney_date  match_num            score  best_of round  minutes  \
# 2896      20141109        514      6-1 3-6 6-0        3    SF     88.0
# 2897      20141109        515              W/O        3     F      NaN
# 2898      20141121          1  6-1 3-6 6-3 6-2        5    RR      NaN
# 2899      20141121          2      6-1 6-4 6-3        5    RR      NaN
# 2900      20141121          4      6-4 6-2 6-2        5    RR      NaN
#
#                 player_1        player_2  player_1_age  player_2_age  \
# ...

# %%
# check df info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 180305 entries, 0 to 2900
# Data columns (total 58 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   tourney_id                        180305 non-null  object
#  1   tourney_name                      180305 non-null  object
#  2   surface                           177866 non-null  object
#  3   draw_size                         180305 non-null  int64
#  4   tourney_level                     180305 non-null  object
#  5   tourney_date                      180305 non-null  int64
#  6   match_num                         180305 non-null  int64
#  7   score                             180294 non-null  object
#  8   best_of                           180305 non-null  int64
#  9   round                             180305 non-null  object
#  10  minutes                           86872 non-null   float64
# ...

# %%
# set index to the date
df = df.set_index('tourney_date')
df.head()
# Out:
#              tourney_id tourney_name surface  draw_size tourney_level  \
# tourney_date
# 20181231      2019-M020     Brisbane    Hard         32             A
# 20181231      2019-M020     Brisbane    Hard         32             A
# 20181231      2019-M020     Brisbane    Hard         32             A
# 20181231      2019-M020     Brisbane    Hard         32             A
# 20181231      2019-M020     Brisbane    Hard         32             A
#
#               match_num           score  best_of round  minutes  \
# tourney_date
# 20181231            300     6-4 3-6 6-2        3     F    124.0
# 20181231            299      7-6(6) 6-2        3    SF     82.0
# 20181231            298         6-2 6-2        3    SF     66.0
# 20181231            297      6-4 7-6(2)        3    QF    106.0
# 20181231            296  6-7(2) 6-3 6-4        3    QF    129.0
#
#                      player_1            player_2  player_1_age  player_2_age  \
# tourney_date
# ...

# %%
# set index to datetime object and verify
df.index = pd.to_datetime(df.index, format = '%Y%m%d')
df.head()
# Out:
#              tourney_id tourney_name surface  draw_size tourney_level  \
# tourney_date
# 2018-12-31    2019-M020     Brisbane    Hard         32             A
# 2018-12-31    2019-M020     Brisbane    Hard         32             A
# 2018-12-31    2019-M020     Brisbane    Hard         32             A
# 2018-12-31    2019-M020     Brisbane    Hard         32             A
# 2018-12-31    2019-M020     Brisbane    Hard         32             A
#
#               match_num           score  best_of round  minutes  \
# tourney_date
# 2018-12-31          300     6-4 3-6 6-2        3     F    124.0
# 2018-12-31          299      7-6(6) 6-2        3    SF     82.0
# 2018-12-31          298         6-2 6-2        3    SF     66.0
# 2018-12-31          297      6-4 7-6(2)        3    QF    106.0
# 2018-12-31          296  6-7(2) 6-3 6-4        3    QF    129.0
#
#                      player_1            player_2  player_1_age  player_2_age  \
# tourney_date
# ...

# %%
# checking
df.tail()
# Out:
#              tourney_id                tourney_name surface  draw_size  \
# tourney_date
# 2014-11-09     2014-605                 Tour Finals    Hard          8
# 2014-11-09     2014-605                 Tour Finals    Hard          8
# 2014-11-21    2014-D015  Davis Cup WG F: FRA vs SUI    Clay          4
# 2014-11-21    2014-D015  Davis Cup WG F: FRA vs SUI    Clay          4
# 2014-11-21    2014-D015  Davis Cup WG F: FRA vs SUI    Clay          4
#
#              tourney_level  match_num            score  best_of round  \
# tourney_date
# 2014-11-09               F        514      6-1 3-6 6-0        3    SF
# 2014-11-09               F        515              W/O        3     F
# 2014-11-21               D          1  6-1 3-6 6-3 6-2        5    RR
# 2014-11-21               D          2      6-1 6-4 6-3        5    RR
# 2014-11-21               D          4      6-4 6-2 6-2        5    RR
#
#               minutes            player_1        player_2  player_1_age  \
# ...

# %%
# sort index
df = df.sort_index(ascending = True)
df.head()
# Out:
#              tourney_id      tourney_name surface  draw_size tourney_level  \
# tourney_date
# 1968-01-19     1968-580  Australian Chps.   Grass         64             G
# 1968-01-19     1968-580  Australian Chps.   Grass         64             G
# 1968-01-19     1968-580  Australian Chps.   Grass         64             G
# 1968-01-19     1968-580  Australian Chps.   Grass         64             G
# 1968-01-19     1968-580  Australian Chps.   Grass         64             G
#
#               match_num                score  best_of round  minutes  \
# tourney_date
# 1968-01-19           48     10-8 1-6 6-3 6-4        5   R16      NaN
# 1968-01-19           27  2-6 4-6 6-4 7-5 6-1        5   R64      NaN
# 1968-01-19           26          6-1 6-1 6-0        5   R64      NaN
# 1968-01-19           25          6-3 6-4 6-2        5   R64      NaN
# 1968-01-19           24          6-4 6-1 6-2        5   R64      NaN
#
# ...

# %%
# check values and counts for match formats
df.best_of.value_counts()
# Out:
# 3    140084
# 5     40195
# 1        26
# Name: best_of, dtype: int64

# %%
df[df.score == 'W/O']
# Out:
#              tourney_id          tourney_name surface  draw_size  \
# tourney_date
# 1968-01-19     1968-580      Australian Chps.   Grass         64
# 1968-02-08     1968-401      Philadelphia WCT  Carpet         16
# 1968-05-06     1968-416                  Rome    Clay        128
# 1968-05-06     1968-416                  Rome    Clay        128
# 1968-05-06     1968-416                  Rome    Clay        128
# ...                 ...                   ...     ...        ...
# 2021-07-12    2021-0414               Hamburg    Clay         32
# 2021-08-09    2021-0421        Canada Masters    Hard         64
# 2021-09-27    2021-7434                 Sofia    Hard         32
# 2021-10-04    2021-0404  Indian Wells Masters    Hard        128
# 2021-11-01    2021-0352         Paris Masters    Hard         64
#
#              tourney_level  match_num score  best_of round  minutes  \
# tourney_date
# 1968-01-19               G         47   W/O        5   R16      NaN
# ...

# %%
# drop records where the match outcome is a walk over and check df info
df = df.drop(df[df.score == 'W/O'].index)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 134631 entries, 1968-03-20 to 2021-12-05
# Data columns (total 57 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   tourney_id                        134631 non-null  object
#  1   tourney_name                      134631 non-null  object
#  2   surface                           132765 non-null  object
#  3   draw_size                         134631 non-null  int64
#  4   tourney_level                     134631 non-null  object
#  5   match_num                         134631 non-null  int64
#  6   score                             134623 non-null  object
#  7   best_of                           134631 non-null  int64
#  8   round                             134631 non-null  object
#  9   minutes                           63801 non-null   float64
#  10  player_1                          134631 non-null  object
# ...

# %%
# double check
df[df.score == 'W/O']
# Out:
# Empty DataFrame
# ...

# %%
# assign variable to best of 5 match format
best_of_5 = df[df.best_of == 5]
best_of_5
# Out:
#              tourney_id                 tourney_name surface  draw_size  \
# tourney_date
# 1968-03-20    1968-D042  Davis Cup G2 SF: SRI vs MAS    Clay          4
# 1968-03-20    1968-D042  Davis Cup G2 SF: SRI vs MAS    Clay          4
# 1968-03-20    1968-D042  Davis Cup G2 SF: SRI vs MAS    Clay          4
# 1968-03-20    1968-D042  Davis Cup G2 SF: SRI vs MAS    Clay          4
# 1968-03-23    1968-D039  Davis Cup G2 SF: JPN vs KOR     NaN          4
# ...                 ...                          ...     ...        ...
# 2021-08-30     2021-560                      Us Open    Hard        128
# 2021-08-30     2021-560                      Us Open    Hard        128
# 2021-08-30     2021-560                      Us Open    Hard        128
# 2021-08-30     2021-560                      Us Open    Hard        128
# 2021-08-30     2021-560                      Us Open    Hard        128
#
#              tourney_level  match_num                   score  best_of round  \
# ...

# %%
# assign variable to most popular match format
best_of_3 = df[df.best_of == 3]

# %%
# drop best of 1 matches (26 records) and verify
df = df.drop(df[df.best_of == 1].index)
df[df.best_of == 1]
# Out:
# Empty DataFrame
# ...

# %%
# check values and counts for different draws
df.draw_size.value_counts()
# Out:
# 32     55689
# 64     19893
# 128    18703
# 4      12445
# 56     10716
# 48      6766
# 28      4320
# 96      2755
# 16      1879
# 8        994
# 24       161
# 12        74
# 6         71
# 2         51
# 9         44
# 7         21
# 10        15
# 5          5
# Name: draw_size, dtype: int64

# %%
# gather all null counts for review
df.isnull().sum()
# Out:
# tourney_id                               0
# tourney_name                             0
# surface                               1866
# draw_size                                0
# tourney_level                            0
# match_num                                0
# score                                    8
# best_of                                  0
# round                                    0
# minutes                              70801
# player_1                                 0
# player_2                                 0
# player_1_age                          2412
# player_2_age                          2533
# player_1_entry                      118734
# player_2_entry                      118449
# player_1_hand                           77
# player_2_hand                           65
# player_1_ht                          17800
# player_2_ht                          17303
# player_1_id                              0
# player_2_id                              0
# ...

# %% [markdown]
# I want to check out the missing hands. Let's inspect who's missing...

# %%
# check unique names that have missing values for their racquet hand
df[df.player_1_hand.isnull()].player_1.unique()
# Out:
# array(['Omar Pabst', 'Jean Pierre Courcol', 'Bronislaw Lewandowski',
#        'Felicisimo Ampon', 'Frank Arthur Sedgman', 'Sam Match',
#        'Jerry Dewitts', 'Enrique Perez Alvarez', 'Ernesto Rios',
#        'Carlos Alberto Fernandes', 'Ricky Morea', 'Raymundo Deyro',
#        'Mieczyslaw Rybarczyk', 'Ichizo Konishi', 'James Rombeau',
#        'Eduardo Zuleta', 'Isao Kobayashi', 'Andre Thielemans',
#        'Desmond Early', 'John Mcgrath', 'Armando Vieira',
#        'Fritz Kolbinger', 'Joseph Offenheim', 'Jesus Hernandez',
#        'Fred Drilling', 'Haibibi Bouchaib', 'David Pratt',
#        'Lennart Bergelin', 'Linh Giang Trinh', 'Jose Olivares',
#        'Peter Bertran', 'Christophe Tholl', 'Salvador Andres Bolanos',
#        'Nicolas Xiviller', 'Ignacio Garcia', 'Adam Hornby',
#        'Hernando Jose Escurra Isnardi', 'Bruno Britez', 'Dac Tien Nguyen',
#        'Illia Biloborodko', 'Matthew Foster Estwick',
#        'Ainius Sabaliauskas', 'Jerome Kym'], dtype=object)
