# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)

from prepare import *

# %% [markdown]
# ###### Who said the data science pipeline was a linear thing?

# %%
df = pd.read_csv('ATPMain.csv', index_col = 0)
df
# Out:
#      tourney_id                tourney_name surface  draw_size tourney_level  \
# 0     2019-M020                    Brisbane    Hard         32             A
# 1     2019-M020                    Brisbane    Hard         32             A
# 2     2019-M020                    Brisbane    Hard         32             A
# 3     2019-M020                    Brisbane    Hard         32             A
# 4     2019-M020                    Brisbane    Hard         32             A
# ...         ...                         ...     ...        ...           ...
# 2896   2014-605                 Tour Finals    Hard          8             F
# 2897   2014-605                 Tour Finals    Hard          8             F
# 2898  2014-D015  Davis Cup WG F: FRA vs SUI    Clay          4             D
# 2899  2014-D015  Davis Cup WG F: FRA vs SUI    Clay          4             D
# 2900  2014-D015  Davis Cup WG F: FRA vs SUI    Clay          4             D
#
#       tourney_date  match_num            score  best_of round  minutes  \
# 0         20181231        300      6-4 3-6 6-2        3     F    124.0
# 1         20181231        299       7-6(6) 6-2        3    SF     82.0
# 2         20181231        298          6-2 6-2        3    SF     66.0
# 3         20181231        297       6-4 7-6(2)        3    QF    106.0
# 4         20181231        296   6-7(2) 6-3 6-4        3    QF    129.0
# ...            ...        ...              ...      ...   ...      ...
# 2896      20141109        514      6-1 3-6 6-0        3    SF     88.0
# 2897      20141109        515              W/O        3     F      NaN
# 2898      20141121          1  6-1 3-6 6-3 6-2        5    RR      NaN
# 2899      20141121          2      6-1 6-4 6-3        5    RR      NaN
# 2900      20141121          4      6-4 6-2 6-2        5    RR      NaN
#
#                 player_1            player_2  player_1_age  player_2_age  \
# 0        Daniil Medvedev       Kei Nishikori     22.885695     29.004791
# 1        Daniil Medvedev  Jo-Wilfried Tsonga     22.885695     33.705681
# 2          Jeremy Chardy       Kei Nishikori     31.882272     29.004791
# 3         Alex De Minaur  Jo-Wilfried Tsonga     19.868583     33.705681
# 4        Daniil Medvedev        Milos Raonic     22.885695     28.010951
# ...                  ...                 ...           ...           ...
# 2896       Kei Nishikori      Novak Djokovic     24.865161     27.471595
# 2897      Novak Djokovic       Roger Federer     27.471595     33.256674
# 2898  Jo-Wilfried Tsonga       Stan Wawrinka     29.585216     29.639973
# 2899        Gael Monfils       Roger Federer     28.210815     33.275838
# 2900     Richard Gasquet       Roger Federer     28.416153     33.275838
#
#      player_1_entry player_2_entry player_1_hand player_2_hand  player_1_ht  \
# 0               NaN            NaN             R             R        198.0
# 1               NaN             PR             R             R        198.0
# 2               NaN            NaN             R             R        188.0
# 3               NaN             PR             R             R        183.0
# 4               NaN            NaN             R             R        198.0
# ...             ...            ...           ...           ...          ...
# 2896            NaN            NaN             R             R        178.0
# 2897            NaN            NaN             R             R        188.0
# 2898            NaN            NaN             R             R        188.0
# 2899            NaN            NaN             R             R        193.0
# 2900            NaN            NaN             R             R        185.0
#
#       player_2_ht  player_1_id  player_2_id player_1_ioc player_2_ioc  \
# 0           178.0       106421       105453          RUS          JPN
# 1           188.0       106421       104542          RUS          FRA
# 2           178.0       104871       105453          FRA          JPN
# 3           188.0       200282       104542          AUS          FRA
# 4           196.0       106421       105683          RUS          CAN
# ...           ...          ...          ...          ...          ...
# 2896        188.0       105453       104925          JPN          SRB
# 2897        185.0       104925       103819          SRB          SUI
# 2898        183.0       104542       104527          FRA          SUI
# 2899        185.0       104792       103819          FRA          SUI
# 2900        185.0       104755       103819          FRA          SUI
#
#            player_1_name       player_2_name  player_1_rank  player_2_rank  \
# 0        Daniil Medvedev       Kei Nishikori           16.0            9.0
# 1        Daniil Medvedev  Jo-Wilfried Tsonga           16.0          239.0
# 2          Jeremy Chardy       Kei Nishikori           40.0            9.0
# 3         Alex De Minaur  Jo-Wilfried Tsonga           31.0          239.0
# 4        Daniil Medvedev        Milos Raonic           16.0           18.0
# ...                  ...                 ...            ...            ...
# 2896       Kei Nishikori      Novak Djokovic            5.0            1.0
# 2897      Novak Djokovic       Roger Federer            1.0            2.0
# 2898  Jo-Wilfried Tsonga       Stan Wawrinka           12.0            4.0
# 2899        Gael Monfils       Roger Federer           19.0            2.0
# 2900     Richard Gasquet       Roger Federer           26.0            2.0
#
#       player_1_rank_points  player_2_rank_points  player_1_seed  \
# 0                   1977.0                3590.0            4.0
# 1                   1977.0                 200.0            4.0
# 2                   1050.0                3590.0            NaN
# 3                   1298.0                 200.0            7.0
# 4                   1977.0                1855.0            4.0
# ...                    ...                   ...            ...
# 2896                4625.0               10010.0            4.0
# 2897               10010.0                8700.0            1.0
# 2898                2740.0                5295.0            NaN
# 2899                1825.0                9700.0            NaN
# 2900                1350.0                9700.0            NaN
#
#       player_2_seed  player_1_aces  player_2_aces  player_1_double_faults  \
# 0               2.0            8.0            3.0                     6.0
# 1               NaN           10.0           17.0                     1.0
# 2               2.0           10.0            2.0                     3.0
# 3               NaN            1.0           12.0                     2.0
# 4               5.0           12.0           29.0                     3.0
# ...             ...            ...            ...                     ...
# 2896            1.0            3.0            3.0                     6.0
# 2897            2.0            NaN            NaN                     NaN
# 2898            NaN            NaN            NaN                     NaN
# 2899            NaN            NaN            NaN                     NaN
# 2900            NaN            NaN            NaN                     NaN
#
#       player_2_double_faults  player_1_service_points  \
# 0                        3.0                    100.0
# 1                        2.0                     52.0
# 2                        2.0                     46.0
# 3                        2.0                     81.0
# 4                        5.0                    105.0
# ...                      ...                      ...
# 2896                     2.0                     67.0
# 2897                     NaN                      NaN
# 2898                     NaN                      NaN
# 2899                     NaN                      NaN
# 2900                     NaN                      NaN
#
#       player_2_service_points  player_1_first_serves_in  \
# 0                        77.0                      54.0
# 1                        77.0                      33.0
# 2                        47.0                      27.0
# 3                        68.0                      60.0
# 4                        94.0                      68.0
# ...                       ...                       ...
# 2896                     58.0                      38.0
# 2897                      NaN                       NaN
# 2898                      NaN                       NaN
# 2899                      NaN                       NaN
# 2900                      NaN                       NaN
#
#       player_2_first_serves_in  player_1_first_serve_points_won  \
# 0                         44.0                             34.0
# 1                         52.0                             28.0
# 2                         33.0                             15.0
# 3                         43.0                             38.0
# 4                         56.0                             48.0
# ...                        ...                              ...
# 2896                      34.0                             29.0
# 2897                       NaN                              NaN
# 2898                       NaN                              NaN
# 2899                       NaN                              NaN
# 2900                       NaN                              NaN
#
#       player_2_first_serve_points_won  player_1_second_serve_points_won  \
# 0                                31.0                              20.0
# 1                                36.0                              14.0
# 2                                26.0                               6.0
# 3                                34.0                               9.0
# 4                                46.0                              25.0
# ...                               ...                               ...
# 2896                             28.0                               5.0
# 2897                              NaN                               NaN
# 2898                              NaN                               NaN
# 2899                              NaN                               NaN
# 2900                              NaN                               NaN
#
#       player_2_second_serve_points_won  player_1_service_game_total  \
# 0                                 17.0                         14.0
# 1                                  7.0                         10.0
# 2                                  9.0                          8.0
# 3                                 15.0                         11.0
# 4                                 19.0                         16.0
# ...                                ...                          ...
# 2896                              13.0                         11.0
# 2897                               NaN                          NaN
# 2898                               NaN                          NaN
# 2899                               NaN                          NaN
# 2900                               NaN                          NaN
#
#       player_2_service_game_total  player_1_break_points_saved  \
# 0                            13.0                         10.0
# 1                            10.0                          0.0
# 2                             8.0                          1.0
# 3                            11.0                          4.0
# 4                            15.0                          8.0
# ...                           ...                          ...
# 2896                         11.0                          3.0
# 2897                          NaN                          NaN
# 2898                          NaN                          NaN
# 2899                          NaN                          NaN
# 2900                          NaN                          NaN
#
#       player_2_break_points_saved  player_1_break_points_faced  \
# 0                             3.0                         15.0
# 1                            10.0                          1.0
# 2                             2.0                          5.0
# 3                             4.0                          6.0
# 4                             2.0                          8.0
# ...                           ...                          ...
# 2896                          2.0                          9.0
# 2897                          NaN                          NaN
# 2898                          NaN                          NaN
# 2899                          NaN                          NaN
# 2900                          NaN                          NaN
#
#       player_2_break_points_faced              winner  player_1_first_serve_%  \
# 0                             6.0       Kei Nishikori                0.540000
# 1                            13.0     Daniil Medvedev                0.634615
# 2                             2.0       Kei Nishikori                0.586957
# 3                             5.0  Jo-Wilfried Tsonga                0.740741
# 4                             4.0     Daniil Medvedev                0.647619
# ...                           ...                 ...                     ...
# 2896                          4.0      Novak Djokovic                0.567164
# 2897                          NaN      Novak Djokovic                     NaN
# 2898                          NaN       Stan Wawrinka                     NaN
# 2899                          NaN        Gael Monfils                     NaN
# 2900                          NaN       Roger Federer                     NaN
#
#       player_2_first_serve_%  player_1_first_serve_win_%  \
# 0                   0.571429                    0.629630
# 1                   0.675325                    0.848485
# 2                   0.702128                    0.555556
# 3                   0.632353                    0.633333
# 4                   0.595745                    0.705882
# ...                      ...                         ...
# 2896                0.586207                    0.763158
# 2897                     NaN                         NaN
# 2898                     NaN                         NaN
# 2899                     NaN                         NaN
# 2900                     NaN                         NaN
#
#       player_2_first_serve_win_%  player_1_break_points_won  \
# 0                       0.704545                        3.0
# 1                       0.692308                        3.0
# 2                       0.787879                        0.0
# 3                       0.790698                        1.0
# 4                       0.821429                        2.0
# ...                          ...                        ...
# 2896                    0.823529                        2.0
# 2897                         NaN                        NaN
# 2898                         NaN                        NaN
# 2899                         NaN                        NaN
# 2900                         NaN                        NaN
#
#       player_2_break_points_won
# 0                           5.0
# 1                           1.0
# 2                           4.0
# 3                           2.0
# 4                           0.0
# ...                         ...
# 2896                        6.0
# 2897                        NaN
# 2898                        NaN
# 2899                        NaN
# 2900                        NaN
#
# [180305 rows x 58 columns]

# %%
df = df.sort_values(by = ['tourney_date', 'tourney_id', 'match_num'])
df.head(3)
# Out:
#      tourney_id      tourney_name surface  draw_size tourney_level  \
# 1026   1968-580  Australian Chps.   Grass         64             G
# 1027   1968-580  Australian Chps.   Grass         64             G
# 1028   1968-580  Australian Chps.   Grass         64             G
#
#       tourney_date  match_num              score  best_of round  minutes  \
# 1026      19680119          1  12-10 7-5 4-6 7-5        5   R64      NaN
# 1027      19680119          2        6-3 6-2 6-4        5   R64      NaN
# 1028      19680119          3    6-4 3-6 6-3 7-5        5   R64      NaN
#
#            player_1           player_2  player_1_age  player_2_age  \
# 1026     Max Senior  Richard Coulthard           NaN           NaN
# 1027   Ernie Mccabe         John Brown           NaN     27.520876
# 1028  Gondo Widjojo          Ross Case           NaN     16.216290
#
#      player_1_entry player_2_entry player_1_hand player_2_hand  player_1_ht  \
# 1026            NaN            NaN             R             R          NaN
# 1027            NaN            NaN             R             R          NaN
# 1028            NaN            NaN             R             R          NaN
#
#       player_2_ht  player_1_id  player_2_id player_1_ioc player_2_ioc  \
# 1026          NaN       107760       110023          AUS          AUS
# 1027          NaN       106964       109803          AUS          AUS
# 1028          NaN       110024       100257          INA          AUS
#
#       player_1_name      player_2_name  player_1_rank  player_2_rank  \
# 1026     Max Senior  Richard Coulthard            NaN            NaN
# 1027   Ernie Mccabe         John Brown            NaN            NaN
# 1028  Gondo Widjojo          Ross Case            NaN            NaN
#
#       player_1_rank_points  player_2_rank_points  player_1_seed  \
# 1026                   NaN                   NaN            NaN
# 1027                   NaN                   NaN            NaN
# 1028                   NaN                   NaN           15.0
#
#       player_2_seed  player_1_aces  player_2_aces  player_1_double_faults  \
# 1026            NaN            NaN            NaN                     NaN
# 1027            NaN            NaN            NaN                     NaN
# 1028            NaN            NaN            NaN                     NaN
#
#       player_2_double_faults  player_1_service_points  \
# 1026                     NaN                      NaN
# 1027                     NaN                      NaN
# 1028                     NaN                      NaN
#
#       player_2_service_points  player_1_first_serves_in  \
# 1026                      NaN                       NaN
# 1027                      NaN                       NaN
# 1028                      NaN                       NaN
#
#       player_2_first_serves_in  player_1_first_serve_points_won  \
# 1026                       NaN                              NaN
# 1027                       NaN                              NaN
# 1028                       NaN                              NaN
#
#       player_2_first_serve_points_won  player_1_second_serve_points_won  \
# 1026                              NaN                               NaN
# 1027                              NaN                               NaN
# 1028                              NaN                               NaN
#
#       player_2_second_serve_points_won  player_1_service_game_total  \
# 1026                               NaN                          NaN
# 1027                               NaN                          NaN
# 1028                               NaN                          NaN
#
#       player_2_service_game_total  player_1_break_points_saved  \
# 1026                          NaN                          NaN
# 1027                          NaN                          NaN
# 1028                          NaN                          NaN
#
#       player_2_break_points_saved  player_1_break_points_faced  \
# 1026                          NaN                          NaN
# 1027                          NaN                          NaN
# 1028                          NaN                          NaN
#
#       player_2_break_points_faced             winner  player_1_first_serve_%  \
# 1026                          NaN  Richard Coulthard                     NaN
# 1027                          NaN         John Brown                     NaN
# 1028                          NaN          Ross Case                     NaN
#
#       player_2_first_serve_%  player_1_first_serve_win_%  \
# 1026                     NaN                         NaN
# 1027                     NaN                         NaN
# 1028                     NaN                         NaN
#
#       player_2_first_serve_win_%  player_1_break_points_won  \
# 1026                         NaN                        NaN
# 1027                         NaN                        NaN
# 1028                         NaN                        NaN
#
#       player_2_break_points_won
# 1026                        NaN
# 1027                        NaN
# 1028                        NaN

# %%
df.tail(3)
# Out:
#                            tourney_id                     tourney_name  \
# 2643  2021-M-DC-2021-FLS-M-RTF-GER-01  Davis Cup Finals SF: RTF vs GER
# 2640  2021-M-DC-2021-FLS-M-RTF-CRO-01   Davis Cup Finals F: RTF vs CRO
# 2641  2021-M-DC-2021-FLS-M-RTF-CRO-01   Davis Cup Finals F: RTF vs CRO
#
#      surface  draw_size tourney_level  tourney_date  match_num       score  \
# 2643    Hard          2             D      20211204          2     6-4 6-4
# 2640    Hard          2             D      20211205          1  6-4 7-6(5)
# 2641    Hard          2             D      20211205          2  7-6(7) 6-2
#
#       best_of round  minutes         player_1            player_2  \
# 2643        3    RR     66.0  Daniil Medvedev  Jan Lennard Struff
# 2640        3    RR     92.0    Andrey Rublev          Borna Gojo
# 2641        3    RR     87.0  Daniil Medvedev         Marin Cilic
#
#       player_1_age  player_2_age player_1_entry player_2_entry player_1_hand  \
# 2643     25.798768     31.597536            NaN            NaN             R
# 2640     24.109514     23.753593            NaN            NaN             R
# 2641     25.798768     33.169062            NaN            NaN             R
#
#      player_2_hand  player_1_ht  player_2_ht  player_1_id  player_2_id  \
# 2643             R        198.0        193.0       106421       105526
# 2640             R        188.0          NaN       126094       127339
# 2641             R        198.0        198.0       106421       105227
#
#      player_1_ioc player_2_ioc    player_1_name       player_2_name  \
# 2643          RUS          GER  Daniil Medvedev  Jan Lennard Struff
# 2640          RUS          CRO    Andrey Rublev          Borna Gojo
# 2641          RUS          CRO  Daniil Medvedev         Marin Cilic
#
#       player_1_rank  player_2_rank  player_1_rank_points  \
# 2643            2.0           51.0                8640.0
# 2640            5.0          279.0                5150.0
# 2641            2.0           30.0                8640.0
#
#       player_2_rank_points  player_1_seed  player_2_seed  player_1_aces  \
# 2643                1134.0            NaN            NaN            7.0
# 2640                 196.0            NaN            NaN            8.0
# 2641                1710.0            NaN            NaN            8.0
#
#       player_2_aces  player_1_double_faults  player_2_double_faults  \
# 2643            5.0                     0.0                     4.0
# 2640           15.0                     2.0                     2.0
# 2641            8.0                     2.0                     1.0
#
#       player_1_service_points  player_2_service_points  \
# 2643                     50.0                     54.0
# 2640                     57.0                     83.0
# 2641                     63.0                     61.0
#
#       player_1_first_serves_in  player_2_first_serves_in  \
# 2643                      35.0                      34.0
# 2640                      39.0                      52.0
# 2641                      39.0                      38.0
#
#       player_1_first_serve_points_won  player_2_first_serve_points_won  \
# 2643                             29.0                             29.0
# 2640                             36.0                             33.0
# 2641                             34.0                             31.0
#
#       player_1_second_serve_points_won  player_2_second_serve_points_won  \
# 2643                              12.0                               7.0
# 2640                              12.0                              20.0
# 2641                              13.0                               9.0
#
#       player_1_service_game_total  player_2_service_game_total  \
# 2643                         10.0                         10.0
# 2640                         11.0                         11.0
# 2641                         10.0                         10.0
#
#       player_1_break_points_saved  player_2_break_points_saved  \
# 2643                          1.0                          3.0
# 2640                          0.0                          7.0
# 2641                          1.0                          1.0
#
#       player_1_break_points_faced  player_2_break_points_faced  \
# 2643                          1.0                          5.0
# 2640                          0.0                          8.0
# 2641                          1.0                          3.0
#
#                winner  player_1_first_serve_%  player_2_first_serve_%  \
# 2643  Daniil Medvedev                0.700000                0.629630
# 2640    Andrey Rublev                0.684211                0.626506
# 2641  Daniil Medvedev                0.619048                0.622951
#
#       player_1_first_serve_win_%  player_2_first_serve_win_%  \
# 2643                    0.828571                    0.852941
# 2640                    0.923077                    0.634615
# 2641                    0.871795                    0.815789
#
#       player_1_break_points_won  player_2_break_points_won
# 2643                        2.0                        0.0
# 2640                        1.0                        0.0
# 2641                        2.0                        0.0

# %%
df = df.reset_index().drop(columns = 'index')
df.head(3)
# Out:
#   tourney_id      tourney_name surface  draw_size tourney_level  tourney_date  \
# 0   1968-580  Australian Chps.   Grass         64             G      19680119
# 1   1968-580  Australian Chps.   Grass         64             G      19680119
# 2   1968-580  Australian Chps.   Grass         64             G      19680119
#
#    match_num              score  best_of round  minutes       player_1  \
# 0          1  12-10 7-5 4-6 7-5        5   R64      NaN     Max Senior
# 1          2        6-3 6-2 6-4        5   R64      NaN   Ernie Mccabe
# 2          3    6-4 3-6 6-3 7-5        5   R64      NaN  Gondo Widjojo
#
#             player_2  player_1_age  player_2_age player_1_entry  \
# 0  Richard Coulthard           NaN           NaN            NaN
# 1         John Brown           NaN     27.520876            NaN
# 2          Ross Case           NaN     16.216290            NaN
#
#   player_2_entry player_1_hand player_2_hand  player_1_ht  player_2_ht  \
# 0            NaN             R             R          NaN          NaN
# 1            NaN             R             R          NaN          NaN
# 2            NaN             R             R          NaN          NaN
#
#    player_1_id  player_2_id player_1_ioc player_2_ioc  player_1_name  \
# 0       107760       110023          AUS          AUS     Max Senior
# 1       106964       109803          AUS          AUS   Ernie Mccabe
# 2       110024       100257          INA          AUS  Gondo Widjojo
#
#        player_2_name  player_1_rank  player_2_rank  player_1_rank_points  \
# 0  Richard Coulthard            NaN            NaN                   NaN
# 1         John Brown            NaN            NaN                   NaN
# 2          Ross Case            NaN            NaN                   NaN
#
#    player_2_rank_points  player_1_seed  player_2_seed  player_1_aces  \
# 0                   NaN            NaN            NaN            NaN
# 1                   NaN            NaN            NaN            NaN
# 2                   NaN           15.0            NaN            NaN
#
#    player_2_aces  player_1_double_faults  player_2_double_faults  \
# 0            NaN                     NaN                     NaN
# 1            NaN                     NaN                     NaN
# 2            NaN                     NaN                     NaN
#
#    player_1_service_points  player_2_service_points  player_1_first_serves_in  \
# 0                      NaN                      NaN                       NaN
# 1                      NaN                      NaN                       NaN
# 2                      NaN                      NaN                       NaN
#
#    player_2_first_serves_in  player_1_first_serve_points_won  \
# 0                       NaN                              NaN
# 1                       NaN                              NaN
# 2                       NaN                              NaN
#
#    player_2_first_serve_points_won  player_1_second_serve_points_won  \
# 0                              NaN                               NaN
# 1                              NaN                               NaN
# 2                              NaN                               NaN
#
#    player_2_second_serve_points_won  player_1_service_game_total  \
# 0                               NaN                          NaN
# 1                               NaN                          NaN
# 2                               NaN                          NaN
#
#    player_2_service_game_total  player_1_break_points_saved  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
#
#    player_2_break_points_saved  player_1_break_points_faced  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
#
#    player_2_break_points_faced             winner  player_1_first_serve_%  \
# 0                          NaN  Richard Coulthard                     NaN
# 1                          NaN         John Brown                     NaN
# 2                          NaN          Ross Case                     NaN
#
#    player_2_first_serve_%  player_1_first_serve_win_%  \
# 0                     NaN                         NaN
# 1                     NaN                         NaN
# 2                     NaN                         NaN
#
#    player_2_first_serve_win_%  player_1_break_points_won  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2                         NaN                        NaN
#
#    player_2_break_points_won
# 0                        NaN
# 1                        NaN
# 2                        NaN

# %%
df.tourney_date = pd.to_datetime(df.tourney_date, format = '%Y%m%d')
df.head(1)
# Out:
#   tourney_id      tourney_name surface  draw_size tourney_level tourney_date  \
# 0   1968-580  Australian Chps.   Grass         64             G   1968-01-19
#
#    match_num              score  best_of round  minutes    player_1  \
# 0          1  12-10 7-5 4-6 7-5        5   R64      NaN  Max Senior
#
#             player_2  player_1_age  player_2_age player_1_entry  \
# 0  Richard Coulthard           NaN           NaN            NaN
#
#   player_2_entry player_1_hand player_2_hand  player_1_ht  player_2_ht  \
# 0            NaN             R             R          NaN          NaN
#
#    player_1_id  player_2_id player_1_ioc player_2_ioc player_1_name  \
# 0       107760       110023          AUS          AUS    Max Senior
#
#        player_2_name  player_1_rank  player_2_rank  player_1_rank_points  \
# 0  Richard Coulthard            NaN            NaN                   NaN
#
#    player_2_rank_points  player_1_seed  player_2_seed  player_1_aces  \
# 0                   NaN            NaN            NaN            NaN
#
#    player_2_aces  player_1_double_faults  player_2_double_faults  \
# 0            NaN                     NaN                     NaN
#
#    player_1_service_points  player_2_service_points  player_1_first_serves_in  \
# 0                      NaN                      NaN                       NaN
#
#    player_2_first_serves_in  player_1_first_serve_points_won  \
# 0                       NaN                              NaN
#
#    player_2_first_serve_points_won  player_1_second_serve_points_won  \
# 0                              NaN                               NaN
#
#    player_2_second_serve_points_won  player_1_service_game_total  \
# 0                               NaN                          NaN
#
#    player_2_service_game_total  player_1_break_points_saved  \
# 0                          NaN                          NaN
#
#    player_2_break_points_saved  player_1_break_points_faced  \
# 0                          NaN                          NaN
#
#    player_2_break_points_faced             winner  player_1_first_serve_%  \
# 0                          NaN  Richard Coulthard                     NaN
#
#    player_2_first_serve_%  player_1_first_serve_win_%  \
# 0                     NaN                         NaN
#
#    player_2_first_serve_win_%  player_1_break_points_won  \
# 0                         NaN                        NaN
#
#    player_2_break_points_won
# 0                        NaN

# %%
df = df[(df.tourney_date > '1998-12-31') & (df.tourney_date < '2020-01-01')]

# %%
df.head(2)
# Out:
#        tourney_id tourney_name surface  draw_size tourney_level tourney_date  \
# 111077   1999-339     Adelaide    Hard         32             A   1999-01-04
# 111078   1999-339     Adelaide    Hard         32             A   1999-01-04
#
#         match_num    score  best_of round  minutes        player_1  \
# 111077          1  6-3 6-0        3   R32     54.0  Patrick Rafter
# 111078          2  7-5 6-3        3   R32     71.0     Jim Courier
#
#              player_2  player_1_age  player_2_age player_1_entry  \
# 111077   Takao Suzuki     26.017796     22.288843            NaN
# 111078  Slava Dosedel     28.383299     28.391513            NaN
#
#        player_2_entry player_1_hand player_2_hand  player_1_ht  player_2_ht  \
# 111077              Q             R             R        185.0        175.0
# 111078            NaN             R             R        185.0        183.0
#
#         player_1_id  player_2_id player_1_ioc player_2_ioc   player_1_name  \
# 111077       102158       102863          AUS          JPN  Patrick Rafter
# 111078       101793       101792          USA          CZE     Jim Courier
#
#         player_2_name  player_1_rank  player_2_rank  player_1_rank_points  \
# 111077   Takao Suzuki            4.0          115.0                3315.0
# 111078  Slava Dosedel           77.0           64.0                 635.0
#
#         player_2_rank_points  player_1_seed  player_2_seed  player_1_aces  \
# 111077                 415.0            1.0            NaN            4.0
# 111078                 723.0            NaN            NaN            3.0
#
#         player_2_aces  player_1_double_faults  player_2_double_faults  \
# 111077            2.0                     3.0                     2.0
# 111078            5.0                     2.0                     0.0
#
#         player_1_service_points  player_2_service_points  \
# 111077                     55.0                     36.0
# 111078                     71.0                     53.0
#
#         player_1_first_serves_in  player_2_first_serves_in  \
# 111077                      36.0                      28.0
# 111078                      41.0                      37.0
#
#         player_1_first_serve_points_won  player_2_first_serve_points_won  \
# 111077                             29.0                             14.0
# 111078                             31.0                             29.0
#
#         player_1_second_serve_points_won  player_2_second_serve_points_won  \
# 111077                               9.0                               4.0
# 111078                              12.0                              12.0
#
#         player_1_service_game_total  player_2_service_game_total  \
# 111077                          8.0                          7.0
# 111078                         11.0                         10.0
#
#         player_1_break_points_saved  player_2_break_points_saved  \
# 111077                          8.0                          3.0
# 111078                          5.0                          1.0
#
#         player_1_break_points_faced  player_2_break_points_faced  \
# 111077                          8.0                          7.0
# 111078                          8.0                          1.0
#
#                 winner  player_1_first_serve_%  player_2_first_serve_%  \
# 111077  Patrick Rafter                0.654545                0.777778
# 111078   Slava Dosedel                0.577465                0.698113
#
#         player_1_first_serve_win_%  player_2_first_serve_win_%  \
# 111077                    0.805556                    0.500000
# 111078                    0.756098                    0.783784
#
#         player_1_break_points_won  player_2_break_points_won
# 111077                        4.0                        0.0
# 111078                        0.0                        3.0

# %%
df.tail(3)
# Out:
#                              tourney_id                     tourney_name  \
# 176113  2019-M-DC-2019-FLS-M-RUS-CAN-01  Davis Cup Finals SF: RUS vs CAN
# 176114  2019-M-DC-2019-FLS-M-CAN-ESP-01   Davis Cup Finals F: CAN vs ESP
# 176115  2019-M-DC-2019-FLS-M-CAN-ESP-01   Davis Cup Finals F: CAN vs ESP
#
#        surface  draw_size tourney_level tourney_date  match_num        score  \
# 176113    Hard          4             D   2019-11-23          2  6-4 4-6 6-4
# 176114    Hard          4             D   2019-11-24          1   7-6(3) 6-3
# 176115    Hard          4             D   2019-11-24          2   6-3 7-6(7)
#
#         best_of round  minutes               player_1               player_2  \
# 176113        3    RR    110.0       Denis Shapovalov        Karen Khachanov
# 176114        3    RR    109.0  Felix Auger Aliassime  Roberto Bautista Agut
# 176115        3    RR    115.0       Denis Shapovalov           Rafael Nadal
#
#         player_1_age  player_2_age player_1_entry player_2_entry  \
# 176113     20.594114     23.493498            NaN            NaN
# 176114     19.277207     31.594798            NaN            NaN
# 176115     20.594114     33.459274            NaN            NaN
#
#        player_1_hand player_2_hand  player_1_ht  player_2_ht  player_1_id  \
# 176113             L             R        185.0        198.0       133430
# 176114             R             R        193.0        183.0       200000
# 176115             L             L        185.0        185.0       133430
#
#         player_2_id player_1_ioc player_2_ioc          player_1_name  \
# 176113       111575          CAN          RUS       Denis Shapovalov
# 176114       105138          CAN          ESP  Felix Auger Aliassime
# 176115       104745          CAN          ESP       Denis Shapovalov
#
#                 player_2_name  player_1_rank  player_2_rank  \
# 176113        Karen Khachanov           15.0           17.0
# 176114  Roberto Bautista Agut           21.0            9.0
# 176115           Rafael Nadal           15.0            1.0
#
#         player_1_rank_points  player_2_rank_points  player_1_seed  \
# 176113                2050.0                1840.0            NaN
# 176114                1636.0                2540.0            NaN
# 176115                2050.0                9985.0            NaN
#
#         player_2_seed  player_1_aces  player_2_aces  player_1_double_faults  \
# 176113            NaN           11.0            5.0                     6.0
# 176114            NaN            4.0            1.0                     6.0
# 176115            NaN            4.0            7.0                     1.0
#
#         player_2_double_faults  player_1_service_points  \
# 176113                     2.0                     93.0
# 176114                     1.0                     68.0
# 176115                     1.0                     76.0
#
#         player_2_service_points  player_1_first_serves_in  \
# 176113                     85.0                      58.0
# 176114                     68.0                      36.0
# 176115                     74.0                      49.0
#
#         player_2_first_serves_in  player_1_first_serve_points_won  \
# 176113                      59.0                             46.0
# 176114                      49.0                             28.0
# 176115                      51.0                             38.0
#
#         player_2_first_serve_points_won  player_1_second_serve_points_won  \
# 176113                             42.0                              14.0
# 176114                             38.0                              15.0
# 176115                             42.0                              10.0
#
#         player_2_second_serve_points_won  player_1_service_game_total  \
# 176113                              14.0                         15.0
# 176114                              14.0                         10.0
# 176115                              13.0                         10.0
#
#         player_2_service_game_total  player_1_break_points_saved  \
# 176113                         15.0                          5.0
# 176114                         11.0                          3.0
# 176115                         11.0                          5.0
#
#         player_2_break_points_saved  player_1_break_points_faced  \
# 176113                          2.0                          7.0
# 176114                          3.0                          5.0
# 176115                          1.0                          6.0
#
#         player_2_break_points_faced                 winner  \
# 176113                          5.0       Denis Shapovalov
# 176114                          4.0  Roberto Bautista Agut
# 176115                          1.0           Rafael Nadal
#
#         player_1_first_serve_%  player_2_first_serve_%  \
# 176113                0.623656                0.694118
# 176114                0.529412                0.720588
# 176115                0.644737                0.689189
#
#         player_1_first_serve_win_%  player_2_first_serve_win_%  \
# 176113                    0.793103                    0.711864
# 176114                    0.777778                    0.775510
# 176115                    0.775510                    0.823529
#
#         player_1_break_points_won  player_2_break_points_won
# 176113                        3.0                        2.0
# 176114                        1.0                        2.0
# 176115                        0.0                        1.0

# %%
df = df.reset_index().drop(columns = 'index')

# %%
df.head(3)
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level tourney_date  \
# 0   1999-339     Adelaide    Hard         32             A   1999-01-04
# 1   1999-339     Adelaide    Hard         32             A   1999-01-04
# 2   1999-339     Adelaide    Hard         32             A   1999-01-04
#
#    match_num    score  best_of round  minutes        player_1       player_2  \
# 0          1  6-3 6-0        3   R32     54.0  Patrick Rafter   Takao Suzuki
# 1          2  7-5 6-3        3   R32     71.0     Jim Courier  Slava Dosedel
# 2          3  6-2 6-1        3   R32     45.0     Andrew Ilie     Jiri Novak
#
#    player_1_age  player_2_age player_1_entry player_2_entry player_1_hand  \
# 0     26.017796     22.288843            NaN              Q             R
# 1     28.383299     28.391513            NaN            NaN             R
# 2     22.713210     23.789185            NaN            NaN             R
#
#   player_2_hand  player_1_ht  player_2_ht  player_1_id  player_2_id  \
# 0             R        185.0        175.0       102158       102863
# 1             R        185.0        183.0       101793       101792
# 2             R        180.0        190.0       102776       102562
#
#   player_1_ioc player_2_ioc   player_1_name  player_2_name  player_1_rank  \
# 0          AUS          JPN  Patrick Rafter   Takao Suzuki            4.0
# 1          USA          CZE     Jim Courier  Slava Dosedel           77.0
# 2          AUS          CZE     Andrew Ilie     Jiri Novak           59.0
#
#    player_2_rank  player_1_rank_points  player_2_rank_points  player_1_seed  \
# 0          115.0                3315.0                 415.0            1.0
# 1           64.0                 635.0                 723.0            NaN
# 2           75.0                 757.0                 669.0            NaN
#
#    player_2_seed  player_1_aces  player_2_aces  player_1_double_faults  \
# 0            NaN            4.0            2.0                     3.0
# 1            NaN            3.0            5.0                     2.0
# 2            NaN            2.0            1.0                     4.0
#
#    player_2_double_faults  player_1_service_points  player_2_service_points  \
# 0                     2.0                     55.0                     36.0
# 1                     0.0                     71.0                     53.0
# 2                     2.0                     47.0                     41.0
#
#    player_1_first_serves_in  player_2_first_serves_in  \
# 0                      36.0                      28.0
# 1                      41.0                      37.0
# 2                      22.0                      24.0
#
#    player_1_first_serve_points_won  player_2_first_serve_points_won  \
# 0                             29.0                             14.0
# 1                             31.0                             29.0
# 2                             12.0                             19.0
#
#    player_1_second_serve_points_won  player_2_second_serve_points_won  \
# 0                               9.0                               4.0
# 1                              12.0                              12.0
# 2                               8.0                              11.0
#
#    player_1_service_game_total  player_2_service_game_total  \
# 0                          8.0                          7.0
# 1                         11.0                         10.0
# 2                          8.0                          7.0
#
#    player_1_break_points_saved  player_2_break_points_saved  \
# 0                          8.0                          3.0
# 1                          5.0                          1.0
# 2                          3.0                          0.0
#
#    player_1_break_points_faced  player_2_break_points_faced          winner  \
# 0                          8.0                          7.0  Patrick Rafter
# 1                          8.0                          1.0   Slava Dosedel
# 2                          8.0                          0.0      Jiri Novak
#
#    player_1_first_serve_%  player_2_first_serve_%  player_1_first_serve_win_%  \
# 0                0.654545                0.777778                    0.805556
# 1                0.577465                0.698113                    0.756098
# 2                0.468085                0.585366                    0.545455
#
#    player_2_first_serve_win_%  player_1_break_points_won  \
# 0                    0.500000                        4.0
# 1                    0.783784                        0.0
# 2                    0.791667                        0.0
#
#    player_2_break_points_won
# 0                        0.0
# 1                        3.0
# 2                        5.0

# %%
df.tail(3)
# Out:
#                             tourney_id                     tourney_name  \
# 65036  2019-M-DC-2019-FLS-M-RUS-CAN-01  Davis Cup Finals SF: RUS vs CAN
# 65037  2019-M-DC-2019-FLS-M-CAN-ESP-01   Davis Cup Finals F: CAN vs ESP
# 65038  2019-M-DC-2019-FLS-M-CAN-ESP-01   Davis Cup Finals F: CAN vs ESP
#
#       surface  draw_size tourney_level tourney_date  match_num        score  \
# 65036    Hard          4             D   2019-11-23          2  6-4 4-6 6-4
# 65037    Hard          4             D   2019-11-24          1   7-6(3) 6-3
# 65038    Hard          4             D   2019-11-24          2   6-3 7-6(7)
#
#        best_of round  minutes               player_1               player_2  \
# 65036        3    RR    110.0       Denis Shapovalov        Karen Khachanov
# 65037        3    RR    109.0  Felix Auger Aliassime  Roberto Bautista Agut
# 65038        3    RR    115.0       Denis Shapovalov           Rafael Nadal
#
#        player_1_age  player_2_age player_1_entry player_2_entry player_1_hand  \
# 65036     20.594114     23.493498            NaN            NaN             L
# 65037     19.277207     31.594798            NaN            NaN             R
# 65038     20.594114     33.459274            NaN            NaN             L
#
#       player_2_hand  player_1_ht  player_2_ht  player_1_id  player_2_id  \
# 65036             R        185.0        198.0       133430       111575
# 65037             R        193.0        183.0       200000       105138
# 65038             L        185.0        185.0       133430       104745
#
#       player_1_ioc player_2_ioc          player_1_name          player_2_name  \
# 65036          CAN          RUS       Denis Shapovalov        Karen Khachanov
# 65037          CAN          ESP  Felix Auger Aliassime  Roberto Bautista Agut
# 65038          CAN          ESP       Denis Shapovalov           Rafael Nadal
#
#        player_1_rank  player_2_rank  player_1_rank_points  \
# 65036           15.0           17.0                2050.0
# 65037           21.0            9.0                1636.0
# 65038           15.0            1.0                2050.0
#
#        player_2_rank_points  player_1_seed  player_2_seed  player_1_aces  \
# 65036                1840.0            NaN            NaN           11.0
# 65037                2540.0            NaN            NaN            4.0
# 65038                9985.0            NaN            NaN            4.0
#
#        player_2_aces  player_1_double_faults  player_2_double_faults  \
# 65036            5.0                     6.0                     2.0
# 65037            1.0                     6.0                     1.0
# 65038            7.0                     1.0                     1.0
#
#        player_1_service_points  player_2_service_points  \
# 65036                     93.0                     85.0
# 65037                     68.0                     68.0
# 65038                     76.0                     74.0
#
#        player_1_first_serves_in  player_2_first_serves_in  \
# 65036                      58.0                      59.0
# 65037                      36.0                      49.0
# 65038                      49.0                      51.0
#
#        player_1_first_serve_points_won  player_2_first_serve_points_won  \
# 65036                             46.0                             42.0
# 65037                             28.0                             38.0
# 65038                             38.0                             42.0
#
#        player_1_second_serve_points_won  player_2_second_serve_points_won  \
# 65036                              14.0                              14.0
# 65037                              15.0                              14.0
# 65038                              10.0                              13.0
#
#        player_1_service_game_total  player_2_service_game_total  \
# 65036                         15.0                         15.0
# 65037                         10.0                         11.0
# 65038                         10.0                         11.0
#
#        player_1_break_points_saved  player_2_break_points_saved  \
# 65036                          5.0                          2.0
# 65037                          3.0                          3.0
# 65038                          5.0                          1.0
#
#        player_1_break_points_faced  player_2_break_points_faced  \
# 65036                          7.0                          5.0
# 65037                          5.0                          4.0
# 65038                          6.0                          1.0
#
#                       winner  player_1_first_serve_%  player_2_first_serve_%  \
# 65036       Denis Shapovalov                0.623656                0.694118
# 65037  Roberto Bautista Agut                0.529412                0.720588
# 65038           Rafael Nadal                0.644737                0.689189
#
#        player_1_first_serve_win_%  player_2_first_serve_win_%  \
# 65036                    0.793103                    0.711864
# 65037                    0.777778                    0.775510
# 65038                    0.775510                    0.823529
#
#        player_1_break_points_won  player_2_break_points_won
# 65036                        3.0                        2.0
# 65037                        1.0                        2.0
# 65038                        0.0                        1.0

# %%
# drop all walkovers (no useful stats) and best of 1 matches (extremely rare format)
df = df.drop(df[df.score == 'W/O'].index)
df = df.drop(df[df.best_of == 1].index)

# %%
# df = df.reset_index().drop(columns = 'index')
df.head(3)
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level tourney_date  \
# 0   1999-339     Adelaide    Hard         32             A   1999-01-04
# 1   1999-339     Adelaide    Hard         32             A   1999-01-04
# 2   1999-339     Adelaide    Hard         32             A   1999-01-04
#
#    match_num    score  best_of round  minutes        player_1       player_2  \
# 0          1  6-3 6-0        3   R32     54.0  Patrick Rafter   Takao Suzuki
# 1          2  7-5 6-3        3   R32     71.0     Jim Courier  Slava Dosedel
# 2          3  6-2 6-1        3   R32     45.0     Andrew Ilie     Jiri Novak
#
#    player_1_age  player_2_age player_1_entry player_2_entry player_1_hand  \
# 0     26.017796     22.288843            NaN              Q             R
# 1     28.383299     28.391513            NaN            NaN             R
# 2     22.713210     23.789185            NaN            NaN             R
#
#   player_2_hand  player_1_ht  player_2_ht  player_1_id  player_2_id  \
# 0             R        185.0        175.0       102158       102863
# 1             R        185.0        183.0       101793       101792
# 2             R        180.0        190.0       102776       102562
#
#   player_1_ioc player_2_ioc   player_1_name  player_2_name  player_1_rank  \
# 0          AUS          JPN  Patrick Rafter   Takao Suzuki            4.0
# 1          USA          CZE     Jim Courier  Slava Dosedel           77.0
# 2          AUS          CZE     Andrew Ilie     Jiri Novak           59.0
#
#    player_2_rank  player_1_rank_points  player_2_rank_points  player_1_seed  \
# 0          115.0                3315.0                 415.0            1.0
# 1           64.0                 635.0                 723.0            NaN
# 2           75.0                 757.0                 669.0            NaN
#
#    player_2_seed  player_1_aces  player_2_aces  player_1_double_faults  \
# 0            NaN            4.0            2.0                     3.0
# 1            NaN            3.0            5.0                     2.0
# 2            NaN            2.0            1.0                     4.0
#
#    player_2_double_faults  player_1_service_points  player_2_service_points  \
# 0                     2.0                     55.0                     36.0
# 1                     0.0                     71.0                     53.0
# 2                     2.0                     47.0                     41.0
#
#    player_1_first_serves_in  player_2_first_serves_in  \
# 0                      36.0                      28.0
# 1                      41.0                      37.0
# 2                      22.0                      24.0
#
#    player_1_first_serve_points_won  player_2_first_serve_points_won  \
# 0                             29.0                             14.0
# 1                             31.0                             29.0
# 2                             12.0                             19.0
#
#    player_1_second_serve_points_won  player_2_second_serve_points_won  \
# 0                               9.0                               4.0
# 1                              12.0                              12.0
# 2                               8.0                              11.0
#
#    player_1_service_game_total  player_2_service_game_total  \
# 0                          8.0                          7.0
# 1                         11.0                         10.0
# 2                          8.0                          7.0
#
#    player_1_break_points_saved  player_2_break_points_saved  \
# 0                          8.0                          3.0
# 1                          5.0                          1.0
# 2                          3.0                          0.0
#
#    player_1_break_points_faced  player_2_break_points_faced          winner  \
# 0                          8.0                          7.0  Patrick Rafter
# 1                          8.0                          1.0   Slava Dosedel
# 2                          8.0                          0.0      Jiri Novak
#
#    player_1_first_serve_%  player_2_first_serve_%  player_1_first_serve_win_%  \
# 0                0.654545                0.777778                    0.805556
# 1                0.577465                0.698113                    0.756098
# 2                0.468085                0.585366                    0.545455
#
#    player_2_first_serve_win_%  player_1_break_points_won  \
# 0                    0.500000                        4.0
# 1                    0.783784                        0.0
# 2                    0.791667                        0.0
#
#    player_2_break_points_won
# 0                        0.0
# 1                        3.0
# 2                        5.0

# %%
df.tail(3)
# Out:
#                             tourney_id                     tourney_name  \
# 64778  2019-M-DC-2019-FLS-M-RUS-CAN-01  Davis Cup Finals SF: RUS vs CAN
# 64779  2019-M-DC-2019-FLS-M-CAN-ESP-01   Davis Cup Finals F: CAN vs ESP
# 64780  2019-M-DC-2019-FLS-M-CAN-ESP-01   Davis Cup Finals F: CAN vs ESP
#
#       surface  draw_size tourney_level tourney_date  match_num        score  \
# 64778    Hard          4             D   2019-11-23          2  6-4 4-6 6-4
# 64779    Hard          4             D   2019-11-24          1   7-6(3) 6-3
# 64780    Hard          4             D   2019-11-24          2   6-3 7-6(7)
#
#        best_of round  minutes               player_1               player_2  \
# 64778        3    RR    110.0       Denis Shapovalov        Karen Khachanov
# 64779        3    RR    109.0  Felix Auger Aliassime  Roberto Bautista Agut
# 64780        3    RR    115.0       Denis Shapovalov           Rafael Nadal
#
#        player_1_age  player_2_age player_1_entry player_2_entry player_1_hand  \
# 64778     20.594114     23.493498            NaN            NaN             L
# 64779     19.277207     31.594798            NaN            NaN             R
# 64780     20.594114     33.459274            NaN            NaN             L
#
#       player_2_hand  player_1_ht  player_2_ht  player_1_id  player_2_id  \
# 64778             R        185.0        198.0       133430       111575
# 64779             R        193.0        183.0       200000       105138
# 64780             L        185.0        185.0       133430       104745
#
#       player_1_ioc player_2_ioc          player_1_name          player_2_name  \
# 64778          CAN          RUS       Denis Shapovalov        Karen Khachanov
# 64779          CAN          ESP  Felix Auger Aliassime  Roberto Bautista Agut
# 64780          CAN          ESP       Denis Shapovalov           Rafael Nadal
#
#        player_1_rank  player_2_rank  player_1_rank_points  \
# 64778           15.0           17.0                2050.0
# 64779           21.0            9.0                1636.0
# 64780           15.0            1.0                2050.0
#
#        player_2_rank_points  player_1_seed  player_2_seed  player_1_aces  \
# 64778                1840.0            NaN            NaN           11.0
# 64779                2540.0            NaN            NaN            4.0
# 64780                9985.0            NaN            NaN            4.0
#
#        player_2_aces  player_1_double_faults  player_2_double_faults  \
# 64778            5.0                     6.0                     2.0
# 64779            1.0                     6.0                     1.0
# 64780            7.0                     1.0                     1.0
#
#        player_1_service_points  player_2_service_points  \
# 64778                     93.0                     85.0
# 64779                     68.0                     68.0
# 64780                     76.0                     74.0
#
#        player_1_first_serves_in  player_2_first_serves_in  \
# 64778                      58.0                      59.0
# 64779                      36.0                      49.0
# 64780                      49.0                      51.0
#
#        player_1_first_serve_points_won  player_2_first_serve_points_won  \
# 64778                             46.0                             42.0
# 64779                             28.0                             38.0
# 64780                             38.0                             42.0
#
#        player_1_second_serve_points_won  player_2_second_serve_points_won  \
# 64778                              14.0                              14.0
# 64779                              15.0                              14.0
# 64780                              10.0                              13.0
#
#        player_1_service_game_total  player_2_service_game_total  \
# 64778                         15.0                         15.0
# 64779                         10.0                         11.0
# 64780                         10.0                         11.0
#
#        player_1_break_points_saved  player_2_break_points_saved  \
# 64778                          5.0                          2.0
# 64779                          3.0                          3.0
# 64780                          5.0                          1.0
#
#        player_1_break_points_faced  player_2_break_points_faced  \
# 64778                          7.0                          5.0
# 64779                          5.0                          4.0
# 64780                          6.0                          1.0
#
#                       winner  player_1_first_serve_%  player_2_first_serve_%  \
# 64778       Denis Shapovalov                0.623656                0.694118
# 64779  Roberto Bautista Agut                0.529412                0.720588
# 64780           Rafael Nadal                0.644737                0.689189
#
#        player_1_first_serve_win_%  player_2_first_serve_win_%  \
# 64778                    0.793103                    0.711864
# 64779                    0.777778                    0.775510
# 64780                    0.775510                    0.823529
#
#        player_1_break_points_won  player_2_break_points_won
# 64778                        3.0                        2.0
# 64779                        1.0                        2.0
# 64780                        0.0                        1.0

# %%
calculate_column_nulls(df)
# Out:
#                                   nulls  null_ratio null_percentage
# player_1_entry                    54472     0.84086          84.09%
# player_2_entry                    54195     0.83659          83.66%
# player_1_seed                     44856     0.69243          69.24%
# player_2_seed                     43530     0.67196           67.2%
# minutes                            7406     0.11432          11.43%
# player_2_first_serve_win_%         6086     0.09395           9.39%
# player_2_first_serve_%             6084     0.09392           9.39%
# player_1_first_serve_win_%         6081     0.09387           9.39%
# player_1_first_serve_%             6081     0.09387           9.39%
# player_1_first_serve_points_won    6078     0.09382           9.38%
# player_1_aces                      6078     0.09382           9.38%
# player_2_aces                      6078     0.09382           9.38%
# player_1_double_faults             6078     0.09382           9.38%
# player_2_double_faults             6078     0.09382           9.38%
# player_1_service_points            6078     0.09382           9.38%
# player_2_service_points            6078     0.09382           9.38%
# player_1_first_serves_in           6078     0.09382           9.38%
# player_2_first_serves_in           6078     0.09382           9.38%
# player_1_second_serve_points_won   6078     0.09382           9.38%
# player_2_first_serve_points_won    6078     0.09382           9.38%
# player_1_break_points_won          6078     0.09382           9.38%
# player_2_second_serve_points_won   6078     0.09382           9.38%
# player_1_service_game_total        6078     0.09382           9.38%
# player_2_service_game_total        6078     0.09382           9.38%
# player_1_break_points_saved        6078     0.09382           9.38%
# player_2_break_points_saved        6078     0.09382           9.38%
# player_1_break_points_faced        6078     0.09382           9.38%
# player_2_break_points_faced        6078     0.09382           9.38%
# player_2_break_points_won          6078     0.09382           9.38%
# player_1_ht                        3470     0.05357           5.36%
# player_2_ht                        3361     0.05188           5.19%
# player_1_rank_points                986     0.01522           1.52%
# player_1_rank                       986     0.01522           1.52%
# player_2_rank_points                951     0.01468           1.47%
# player_2_rank                       951     0.01468           1.47%
# player_1_hand                        25     0.00039           0.04%
# player_2_hand                        19     0.00029           0.03%
# player_2_age                          5     0.00008           0.01%
# player_1_age                          1     0.00002            0.0%
# player_1_ioc                          0     0.00000            0.0%
# best_of                               0     0.00000            0.0%
# surface                               0     0.00000            0.0%
# draw_size                             0     0.00000            0.0%
# tourney_level                         0     0.00000            0.0%
# tourney_date                          0     0.00000            0.0%
# match_num                             0     0.00000            0.0%
# winner                                0     0.00000            0.0%
# score                                 0     0.00000            0.0%
# round                                 0     0.00000            0.0%
# player_2_id                           0     0.00000            0.0%
# player_1                              0     0.00000            0.0%
# player_2                              0     0.00000            0.0%
# tourney_name                          0     0.00000            0.0%
# player_2_name                         0     0.00000            0.0%
# player_1_name                         0     0.00000            0.0%
# player_2_ioc                          0     0.00000            0.0%
# player_1_id                           0     0.00000            0.0%
# tourney_id                            0     0.00000            0.0%

# %%
df[df['player_1_first_serve_%'].isnull()]
# Out:
#                               tourney_id                 tourney_name surface  \
# 144                             1999-580              Australian Open    Hard
# 235                             1999-580              Australian Open    Hard
# 236                             1999-580              Australian Open    Hard
# 237                             1999-580              Australian Open    Hard
# 238                             1999-580              Australian Open    Hard
# ...                                  ...                          ...     ...
# 64283  2019-M-DC-2019-G2-AO-M-NZL-INA-01  Davis Cup G2 R1: NZL vs INA    Hard
# 64284  2019-M-DC-2019-G2-AO-M-NZL-INA-01  Davis Cup G2 R1: NZL vs INA    Hard
# 64285  2019-M-DC-2019-G2-AO-M-TPE-HKG-01  Davis Cup G2 R1: TPE vs HKG    Hard
# 64286  2019-M-DC-2019-G2-AO-M-TPE-HKG-01  Davis Cup G2 R1: TPE vs HKG    Hard
# 64287  2019-M-DC-2019-G2-AO-M-TPE-HKG-01  Davis Cup G2 R1: TPE vs HKG    Hard
#
#        draw_size tourney_level tourney_date  match_num  \
# 144          128             G   1999-01-18         22
# 235          128             G   1999-01-18        113
# 236          128             G   1999-01-18        114
# 237          128             G   1999-01-18        115
# 238          128             G   1999-01-18        116
# ...          ...           ...          ...        ...
# 64283          4             D   2019-09-14          2
# 64284          4             D   2019-09-14          4
# 64285          4             D   2019-09-14          1
# 64286          4             D   2019-09-14          2
# 64287          4             D   2019-09-14          4
#
#                            score  best_of round     minutes  \
# 144              2-6 6-3 6-3 6-3        5  R128  139.076271
# 235               7-6(3) 6-4 6-4        5   R16  139.076271
# 236    6-3 7-6(5) 6-7(5) 3-6 6-4        5   R16  139.076271
# 237                  6-2 6-3 7-5        5   R16  139.076271
# 238           6-1 7-5 6-7(3) 6-3        5   R16  139.076271
# ...                          ...      ...   ...         ...
# 64283                3-6 6-4 6-0        3    RR   94.612182
# 64284             6-3 2-6 [10-7]        3    RR   94.612182
# 64285                    6-1 6-2        3    RR   94.612182
# 64286                    6-3 6-2        3    RR   94.612182
# 64287                    6-2 7-5        3    RR   94.612182
#
#                     player_1            player_2  player_1_age  player_2_age  \
# 144           Sjeng Schalken       Thomas Muster     22.360027     31.296372
# 235              Todd Martin         Wayne Black     28.531143     25.177276
# 236             Andrei Pavel  Yevgeny Kafelnikov     24.974675     24.914442
# 237          Fabrice Santoro          Tommy Haas     26.108145     20.793977
# 238             Andre Agassi      Vincent Spadea     28.722793     24.501027
# ...                      ...                 ...           ...           ...
# 64283    David Agung Susanto       Rhett Purcell     28.136893     23.589322
# 64284              Ajeet Rai         Ari Fahresi     20.640657           NaN
# 64285  Chak Lam Coleman Wong          Jason Jung     15.258042     30.234086
# 64286         Pak Long Yeung         Tung Lin Wu     24.566735     21.327858
# 64287        Chun Hsin Tseng          Wai Yu Kai     18.086242     18.472279
#
#       player_1_entry player_2_entry player_1_hand player_2_hand  player_1_ht  \
# 144              NaN            NaN             R             L        193.0
# 235              NaN            NaN             R             R        198.0
# 236              NaN            NaN             R             R        183.0
# 237              NaN            NaN             R             R        178.0
# 238              NaN            NaN             R             R        180.0
# ...              ...            ...           ...           ...          ...
# 64283            NaN            NaN             U             R          NaN
# 64284            NaN            NaN             R             U          NaN
# 64285            NaN            NaN             R             R          NaN
# 64286            NaN            NaN             R             R          NaN
# 64287            NaN            NaN             R             R          NaN
#
#        player_2_ht  player_1_id  player_2_id player_1_ioc player_2_ioc  \
# 144          180.0       102854       101404          NED          AUT
# 235          170.0       101774       102286          USA          ZIM
# 236          190.0       102318       102338          ROU          RUS
# 237          188.0       102148       103163          FRA          GER
# 238          183.0       101736       102434          USA          USA
# ...            ...          ...          ...          ...          ...
# 64283          NaN       105812       144650          INA          GBR
# 64284          NaN       208055       209188          NZL          INA
# 64285          NaN       208597       105359          HKG          TPE
# 64286          NaN       106388       126555          HKG          TPE
# 64287          NaN       202358       207852          TPE          HKG
#
#                player_1_name       player_2_name  player_1_rank  \
# 144           Sjeng Schalken       Thomas Muster           49.0
# 235              Todd Martin         Wayne Black           13.0
# 236             Andrei Pavel  Yevgeny Kafelnikov           53.0
# 237          Fabrice Santoro          Tommy Haas           68.0
# 238             Andre Agassi      Vincent Spadea            6.0
# ...                      ...                 ...            ...
# 64283    David Agung Susanto       Rhett Purcell         1195.0
# 64284              Ajeet Rai         Ari Fahresi          744.0
# 64285  Chak Lam Coleman Wong          Jason Jung            NaN
# 64286         Pak Long Yeung         Tung Lin Wu         1107.0
# 64287        Chun Hsin Tseng          Wai Yu Kai          320.0
#
#        player_2_rank  player_1_rank_points  player_2_rank_points  \
# 144             24.0                 839.0                1470.0
# 235             97.0                1944.0                 518.0
# 236             10.0                 812.0                2515.0
# 237             33.0                 702.0                1161.0
# 238             44.0                2879.0                 897.0
# ...              ...                   ...                   ...
# 64283          922.0                   5.0                  13.0
# 64284            NaN                  22.0                   NaN
# 64285          132.0                   NaN                 417.0
# 64286          238.0                   7.0                 201.0
# 64287            NaN                 123.0                   NaN
#
#        player_1_seed  player_2_seed  player_1_aces  player_2_aces  \
# 144              NaN            NaN            NaN            NaN
# 235             15.0            NaN            NaN            NaN
# 236              NaN           10.0            NaN            NaN
# 237              NaN            NaN            NaN            NaN
# 238              5.0            NaN            NaN            NaN
# ...              ...            ...            ...            ...
# 64283            NaN            NaN            NaN            NaN
# 64284            NaN            NaN            NaN            NaN
# 64285            NaN            NaN            NaN            NaN
# 64286            NaN            NaN            NaN            NaN
# 64287            NaN            NaN            NaN            NaN
#
#        player_1_double_faults  player_2_double_faults  \
# 144                       NaN                     NaN
# 235                       NaN                     NaN
# 236                       NaN                     NaN
# 237                       NaN                     NaN
# 238                       NaN                     NaN
# ...                       ...                     ...
# 64283                     NaN                     NaN
# 64284                     NaN                     NaN
# 64285                     NaN                     NaN
# 64286                     NaN                     NaN
# 64287                     NaN                     NaN
#
#        player_1_service_points  player_2_service_points  \
# 144                        NaN                      NaN
# 235                        NaN                      NaN
# 236                        NaN                      NaN
# 237                        NaN                      NaN
# 238                        NaN                      NaN
# ...                        ...                      ...
# 64283                      NaN                      NaN
# 64284                      NaN                      NaN
# 64285                      NaN                      NaN
# 64286                      NaN                      NaN
# 64287                      NaN                      NaN
#
#        player_1_first_serves_in  player_2_first_serves_in  \
# 144                         NaN                       NaN
# 235                         NaN                       NaN
# 236                         NaN                       NaN
# 237                         NaN                       NaN
# 238                         NaN                       NaN
# ...                         ...                       ...
# 64283                       NaN                       NaN
# 64284                       NaN                       NaN
# 64285                       NaN                       NaN
# 64286                       NaN                       NaN
# 64287                       NaN                       NaN
#
#        player_1_first_serve_points_won  player_2_first_serve_points_won  \
# 144                                NaN                              NaN
# 235                                NaN                              NaN
# 236                                NaN                              NaN
# 237                                NaN                              NaN
# 238                                NaN                              NaN
# ...                                ...                              ...
# 64283                              NaN                              NaN
# 64284                              NaN                              NaN
# 64285                              NaN                              NaN
# 64286                              NaN                              NaN
# 64287                              NaN                              NaN
#
#        player_1_second_serve_points_won  player_2_second_serve_points_won  \
# 144                                 NaN                               NaN
# 235                                 NaN                               NaN
# 236                                 NaN                               NaN
# 237                                 NaN                               NaN
# 238                                 NaN                               NaN
# ...                                 ...                               ...
# 64283                               NaN                               NaN
# 64284                               NaN                               NaN
# 64285                               NaN                               NaN
# 64286                               NaN                               NaN
# 64287                               NaN                               NaN
#
#        player_1_service_game_total  player_2_service_game_total  \
# 144                            NaN                          NaN
# 235                            NaN                          NaN
# 236                            NaN                          NaN
# 237                            NaN                          NaN
# 238                            NaN                          NaN
# ...                            ...                          ...
# 64283                          NaN                          NaN
# 64284                          NaN                          NaN
# 64285                          NaN                          NaN
# 64286                          NaN                          NaN
# 64287                          NaN                          NaN
#
#        player_1_break_points_saved  player_2_break_points_saved  \
# 144                            NaN                          NaN
# 235                            NaN                          NaN
# 236                            NaN                          NaN
# 237                            NaN                          NaN
# 238                            NaN                          NaN
# ...                            ...                          ...
# 64283                          NaN                          NaN
# 64284                          NaN                          NaN
# 64285                          NaN                          NaN
# 64286                          NaN                          NaN
# 64287                          NaN                          NaN
#
#        player_1_break_points_faced  player_2_break_points_faced  \
# 144                            NaN                          NaN
# 235                            NaN                          NaN
# 236                            NaN                          NaN
# 237                            NaN                          NaN
# 238                            NaN                          NaN
# ...                            ...                          ...
# 64283                          NaN                          NaN
# 64284                          NaN                          NaN
# 64285                          NaN                          NaN
# 64286                          NaN                          NaN
# 64287                          NaN                          NaN
#
#                    winner  player_1_first_serve_%  player_2_first_serve_%  \
# 144        Sjeng Schalken                     NaN                     NaN
# 235           Todd Martin                     NaN                     NaN
# 236    Yevgeny Kafelnikov                     NaN                     NaN
# 237            Tommy Haas                     NaN                     NaN
# 238        Vincent Spadea                     NaN                     NaN
# ...                   ...                     ...                     ...
# 64283       Rhett Purcell                     NaN                     NaN
# 64284         Ari Fahresi                     NaN                     NaN
# 64285          Jason Jung                     NaN                     NaN
# 64286         Tung Lin Wu                     NaN                     NaN
# 64287     Chun Hsin Tseng                     NaN                     NaN
#
#        player_1_first_serve_win_%  player_2_first_serve_win_%  \
# 144                           NaN                         NaN
# 235                           NaN                         NaN
# 236                           NaN                         NaN
# 237                           NaN                         NaN
# 238                           NaN                         NaN
# ...                           ...                         ...
# 64283                         NaN                         NaN
# 64284                         NaN                         NaN
# 64285                         NaN                         NaN
# 64286                         NaN                         NaN
# 64287                         NaN                         NaN
#
#        player_1_break_points_won  player_2_break_points_won
# 144                          NaN                        NaN
# 235                          NaN                        NaN
# 236                          NaN                        NaN
# 237                          NaN                        NaN
# 238                          NaN                        NaN
# ...                          ...                        ...
# 64283                        NaN                        NaN
# 64284                        NaN                        NaN
# 64285                        NaN                        NaN
# 64286                        NaN                        NaN
# 64287                        NaN                        NaN
#
# [6081 rows x 58 columns]

# %%
df[df['player_1_first_serve_%'].isnull()].tourney_id.unique()
# Out:
# array(['1999-580', '1999-D027', '1999-424', ...,
#        '2019-M-DC-2019-G2-AM-M-MEX-PAR-01',
#        '2019-M-DC-2019-G2-AO-M-NZL-INA-01',
#        '2019-M-DC-2019-G2-AO-M-TPE-HKG-01'], dtype=object)

# %%
len(df[df['player_1_first_serve_%'].isnull()].tourney_id.unique())
# Out:
# 1596

# %% [markdown]
# ### some planning
#
# #### For tournaments with several, but not all, missing match time lengths
# * get list of tourney ids
# * generate average match time for tourney id
# * fill missing lengths with averages
#
#
# #### For tournaments with no match time lengths at all
# * gather best of 3 subset
# * gather best of 5 subset
#
# * gather surface type subsets for each
# * generate average match time length for each subset
# * fill missing lengths with averages

# %%
# assign variable to list of tourney ids that have missing minutes
missing_minutes = list(df[df.minutes.isnull()].tourney_id.unique())
# commence loop through list of tournaments with missing match lengths
for tourney in missing_minutes:
    # assign mean match length for tournament to variable
    mean_match_length = df[df.tourney_id == tourney].minutes.mean()
    # locate index where there are mml for the tournament, fill values with average match length
    df.loc[df[df.tourney_id == tourney].minutes.isnull().index, 'minutes'] = mean_match_length

# %%
calculate_column_nulls(df)
# Out:
#                                   nulls  null_ratio null_percentage
# player_1_entry                    54472     0.84086          84.09%
# player_2_entry                    54195     0.83659          83.66%
# player_1_seed                     44856     0.69243          69.24%
# player_2_seed                     43530     0.67196           67.2%
# minutes                            6452     0.09960           9.96%
# player_2_first_serve_win_%         6086     0.09395           9.39%
# player_2_first_serve_%             6084     0.09392           9.39%
# player_1_first_serve_win_%         6081     0.09387           9.39%
# player_1_first_serve_%             6081     0.09387           9.39%
# player_1_first_serve_points_won    6078     0.09382           9.38%
# player_1_aces                      6078     0.09382           9.38%
# player_2_aces                      6078     0.09382           9.38%
# player_1_double_faults             6078     0.09382           9.38%
# player_2_double_faults             6078     0.09382           9.38%
# player_1_service_points            6078     0.09382           9.38%
# player_2_service_points            6078     0.09382           9.38%
# player_1_first_serves_in           6078     0.09382           9.38%
# player_2_first_serves_in           6078     0.09382           9.38%
# player_1_second_serve_points_won   6078     0.09382           9.38%
# player_2_first_serve_points_won    6078     0.09382           9.38%
# player_1_break_points_won          6078     0.09382           9.38%
# player_2_second_serve_points_won   6078     0.09382           9.38%
# player_1_service_game_total        6078     0.09382           9.38%
# player_2_service_game_total        6078     0.09382           9.38%
# player_1_break_points_saved        6078     0.09382           9.38%
# player_2_break_points_saved        6078     0.09382           9.38%
# player_1_break_points_faced        6078     0.09382           9.38%
# player_2_break_points_faced        6078     0.09382           9.38%
# player_2_break_points_won          6078     0.09382           9.38%
# player_1_ht                        3470     0.05357           5.36%
# player_2_ht                        3361     0.05188           5.19%
# player_1_rank_points                986     0.01522           1.52%
# player_1_rank                       986     0.01522           1.52%
# player_2_rank_points                951     0.01468           1.47%
# player_2_rank                       951     0.01468           1.47%
# player_1_hand                        25     0.00039           0.04%
# player_2_hand                        19     0.00029           0.03%
# player_2_age                          5     0.00008           0.01%
# player_1_age                          1     0.00002            0.0%
# player_1_ioc                          0     0.00000            0.0%
# best_of                               0     0.00000            0.0%
# surface                               0     0.00000            0.0%
# draw_size                             0     0.00000            0.0%
# tourney_level                         0     0.00000            0.0%
# tourney_date                          0     0.00000            0.0%
# match_num                             0     0.00000            0.0%
# winner                                0     0.00000            0.0%
# score                                 0     0.00000            0.0%
# round                                 0     0.00000            0.0%
# player_2_id                           0     0.00000            0.0%
# player_1                              0     0.00000            0.0%
# player_2                              0     0.00000            0.0%
# tourney_name                          0     0.00000            0.0%
# player_2_name                         0     0.00000            0.0%
# player_1_name                         0     0.00000            0.0%
# player_2_ioc                          0     0.00000            0.0%
# player_1_id                           0     0.00000            0.0%
# tourney_id                            0     0.00000            0.0%

# %%
## generate subsets for data and group by match format and surface type

# best of 3
best_of_3_hard = df[(df.best_of == 3) & (df.surface == 'Hard')]
best_of_3_clay = df[(df.best_of == 3) & (df.surface == 'Clay')]
best_of_3_grass = df[(df.best_of == 3) & (df.surface == 'Grass')]
best_of_3_carpet = df[(df.best_of == 3) & (df.surface == 'Carpet')]

# best of 5
best_of_5_hard = df[(df.best_of == 5) & (df.surface == 'Hard')]
best_of_5_clay = df[(df.best_of == 5) & (df.surface == 'Clay')]
best_of_5_grass = df[(df.best_of == 5) & (df.surface == 'Grass')]
best_of_5_carpet = df[(df.best_of == 5) & (df.surface == 'Carpet')]

# %%
# check average match time for best of 3 grass matches
best_of_3_grass.minutes.mean()
# Out:
# 89.74187422733866

# %%
df[df.tourney_id == '1999-D026']
# Out:
#     tourney_id                 tourney_name surface  draw_size tourney_level  \
# 801  1999-D026  Davis Cup G1 PO: IND vs CHN   Grass          4             D
# 802  1999-D026  Davis Cup G1 PO: IND vs CHN   Grass          4             D
# 803  1999-D026  Davis Cup G1 PO: IND vs CHN   Grass          4             D
# 804  1999-D026  Davis Cup G1 PO: IND vs CHN   Grass          4             D
#
#     tourney_date  match_num              score  best_of round  minutes  \
# 801   1999-04-02          1        6-4 6-2 6-3        5    RR      NaN
# 802   1999-04-02          2     7-6(3) 6-3 6-4        5    RR      NaN
# 803   1999-04-02          4  6-7(5) 7-6(3) 6-3        3    RR      NaN
# 804   1999-04-02          5            6-3 6-3        3    RR      NaN
#
#             player_1         player_2  player_1_age  player_2_age  \
# 801     Leander Paes         Yu Zhang     25.779603     22.959617
# 802    Ben Qiang Zhu  Fazaluddin Syed     20.043806     24.443532
# 803    Ben Qiang Zhu     Leander Paes     20.043806     25.779603
# 804  Fazaluddin Syed       Shan Jiang     24.443532     18.469541
#
#     player_1_entry player_2_entry player_1_hand player_2_hand  player_1_ht  \
# 801            NaN            NaN             R             R        178.0
# 802            NaN            NaN             R             R          NaN
# 803            NaN            NaN             R             R          NaN
# 804            NaN            NaN             R             R          NaN
#
#      player_2_ht  player_1_id  player_2_id player_1_ioc player_2_ioc  \
# 801          NaN       102233       102772          IND          CHN
# 802          NaN       103337       102467          CHN          IND
# 803        178.0       103337       102233          CHN          IND
# 804          NaN       102467       103642          IND          CHN
#
#        player_1_name    player_2_name  player_1_rank  player_2_rank  \
# 801     Leander Paes         Yu Zhang          101.0          812.0
# 802    Ben Qiang Zhu  Fazaluddin Syed          792.0          575.0
# 803    Ben Qiang Zhu     Leander Paes          792.0          101.0
# 804  Fazaluddin Syed       Shan Jiang          575.0            NaN
#
#      player_1_rank_points  player_2_rank_points  player_1_seed  player_2_seed  \
# 801                 504.0                  13.0            NaN            NaN
# 802                  14.0                  34.0            NaN            NaN
# 803                  14.0                 504.0            NaN            NaN
# 804                  34.0                   NaN            NaN            NaN
#
#      player_1_aces  player_2_aces  player_1_double_faults  \
# 801            NaN            NaN                     NaN
# 802            NaN            NaN                     NaN
# 803            NaN            NaN                     NaN
# 804            NaN            NaN                     NaN
#
#      player_2_double_faults  player_1_service_points  player_2_service_points  \
# 801                     NaN                      NaN                      NaN
# 802                     NaN                      NaN                      NaN
# 803                     NaN                      NaN                      NaN
# 804                     NaN                      NaN                      NaN
#
#      player_1_first_serves_in  player_2_first_serves_in  \
# 801                       NaN                       NaN
# 802                       NaN                       NaN
# 803                       NaN                       NaN
# 804                       NaN                       NaN
#
#      player_1_first_serve_points_won  player_2_first_serve_points_won  \
# 801                              NaN                              NaN
# 802                              NaN                              NaN
# 803                              NaN                              NaN
# 804                              NaN                              NaN
#
#      player_1_second_serve_points_won  player_2_second_serve_points_won  \
# 801                               NaN                               NaN
# 802                               NaN                               NaN
# 803                               NaN                               NaN
# 804                               NaN                               NaN
#
#      player_1_service_game_total  player_2_service_game_total  \
# 801                          NaN                          NaN
# 802                          NaN                          NaN
# 803                          NaN                          NaN
# 804                          NaN                          NaN
#
#      player_1_break_points_saved  player_2_break_points_saved  \
# 801                          NaN                          NaN
# 802                          NaN                          NaN
# 803                          NaN                          NaN
# 804                          NaN                          NaN
#
#      player_1_break_points_faced  player_2_break_points_faced  \
# 801                          NaN                          NaN
# 802                          NaN                          NaN
# 803                          NaN                          NaN
# 804                          NaN                          NaN
#
#               winner  player_1_first_serve_%  player_2_first_serve_%  \
# 801     Leander Paes                     NaN                     NaN
# 802  Fazaluddin Syed                     NaN                     NaN
# 803     Leander Paes                     NaN                     NaN
# 804  Fazaluddin Syed                     NaN                     NaN
#
#      player_1_first_serve_win_%  player_2_first_serve_win_%  \
# 801                         NaN                         NaN
# 802                         NaN                         NaN
# 803                         NaN                         NaN
# 804                         NaN                         NaN
#
#      player_1_break_points_won  player_2_break_points_won
# 801                        NaN                        NaN
# 802                        NaN                        NaN
# 803                        NaN                        NaN
# 804                        NaN                        NaN

# %%
# review records where best of 3 grass matches have missing values
best_of_3_grass[best_of_3_grass.minutes.isnull()]
# Out:
#       tourney_id                 tourney_name surface  draw_size  \
# 803    1999-D026  Davis Cup G1 PO: IND vs CHN   Grass          4
# 804    1999-D026  Davis Cup G1 PO: IND vs CHN   Grass          4
# 2814   1999-D006  Davis Cup WG SF: AUS vs RUS   Grass          4
# 3665   2000-D076  Davis Cup G1 QF: IND vs LIB   Grass          4
# 4259   2000-D004  Davis Cup WG QF: AUS vs GER   Grass          4
# ...          ...                          ...     ...        ...
# 52186   2015-315                      Newport   Grass         32
# 52187   2015-315                      Newport   Grass         32
# 52188   2015-315                      Newport   Grass         32
# 52189   2015-315                      Newport   Grass         32
# 52190   2015-315                      Newport   Grass         32
#
#       tourney_level tourney_date  match_num              score  best_of round  \
# 803               D   1999-04-02          4  6-7(5) 7-6(3) 6-3        3    RR
# 804               D   1999-04-02          5            6-3 6-3        3    RR
# 2814              D   1999-09-24          5            6-3 6-2        3    RR
# 3665              D   2000-02-04          5        2-6 7-5 6-1        3    RR
# 4259              D   2000-04-07          4        2-6 6-3 6-4        3    RR
# ...             ...          ...        ...                ...      ...   ...
# 52186             A   2015-07-13         27            0-1 RET        3    QF
# 52187             A   2015-07-13         28         7-6(3) 6-3        3    QF
# 52188             A   2015-07-13         29         6-4 7-6(4)        3    SF
# 52189             A   2015-07-13         30         7-6(3) 6-4        3    SF
# 52190             A   2015-07-13         31  7-6(5) 5-7 7-6(2)        3     F
#
#        minutes            player_1           player_2  player_1_age  \
# 803        NaN       Ben Qiang Zhu       Leander Paes     20.043806
# 804        NaN     Fazaluddin Syed         Shan Jiang     24.443532
# 2814       NaN         Marat Safin      Wayne Arthurs     19.646817
# 3665       NaN         Ali Hamadeh    Fazaluddin Syed     25.404517
# 4259       NaN      Lleyton Hewitt  Rainer Schuettler     19.104723
# ...        ...                 ...                ...           ...
# 52186      NaN           Jack Sock        Jan Hernych     22.798084
# 52187      NaN        Dustin Brown       Ivo Karlovic     30.592745
# 52188      NaN  John Patrick Smith         Rajeev Ram     25.604381
# 52189      NaN        Ivo Karlovic          Jack Sock     36.369610
# 52190      NaN        Ivo Karlovic         Rajeev Ram     36.369610
#
#        player_2_age player_1_entry player_2_entry player_1_hand player_2_hand  \
# 803       25.779603            NaN            NaN             R             R
# 804       18.469541            NaN            NaN             R             R
# 2814      28.509240            NaN            NaN             R             L
# 3665      25.286790            NaN            NaN             R             R
# 4259      23.939767            NaN            NaN             R             R
# ...             ...            ...            ...           ...           ...
# 52186     36.016427            NaN              Q             R             R
# 52187     36.369610            NaN            NaN             R             R
# 52188     31.318275            NaN            NaN             L             R
# 52189     22.798084            NaN            NaN             R             R
# 52190     31.318275            NaN            NaN             R             R
#
#        player_1_ht  player_2_ht  player_1_id  player_2_id player_1_ioc  \
# 803            NaN        178.0       103337       102233          CHN
# 804            NaN          NaN       102467       103642          IND
# 2814         193.0        190.0       103498       101885          RUS
# 3665           NaN          NaN       102448       102467          LIB
# 4259         180.0        180.0       103720       102783          AUS
# ...            ...          ...          ...          ...          ...
# 52186        185.0        190.0       106058       103401          USA
# 52187        196.0        208.0       104460       103333          GER
# 52188          NaN        193.0       105441       104330          AUS
# 52189        208.0        185.0       103333       106058          CRO
# 52190        208.0        193.0       103333       104330          CRO
#
#       player_2_ioc       player_1_name      player_2_name  player_1_rank  \
# 803            IND       Ben Qiang Zhu       Leander Paes          792.0
# 804            CHN     Fazaluddin Syed         Shan Jiang          575.0
# 2814           AUS         Marat Safin      Wayne Arthurs           36.0
# 3665           IND         Ali Hamadeh    Fazaluddin Syed            NaN
# 4259           GER      Lleyton Hewitt  Rainer Schuettler           11.0
# ...            ...                 ...                ...            ...
# 52186          CZE           Jack Sock        Jan Hernych           39.0
# 52187          CRO        Dustin Brown       Ivo Karlovic           80.0
# 52188          USA  John Patrick Smith         Rajeev Ram          156.0
# 52189          USA        Ivo Karlovic          Jack Sock           24.0
# 52190          USA        Ivo Karlovic         Rajeev Ram           24.0
#
#        player_2_rank  player_1_rank_points  player_2_rank_points  \
# 803            101.0                  14.0                 504.0
# 804              NaN                  34.0                   NaN
# 2814            91.0                1094.0                 534.0
# 3665           435.0                   NaN                  56.0
# 4259            61.0                1670.0                 699.0
# ...              ...                   ...                   ...
# 52186          237.0                1090.0                 203.0
# 52187           24.0                 614.0                1450.0
# 52188          161.0                 329.0                 320.0
# 52189           39.0                1450.0                1090.0
# 52190          161.0                1450.0                 320.0
#
#        player_1_seed  player_2_seed  player_1_aces  player_2_aces  \
# 803              NaN            NaN            NaN            NaN
# 804              NaN            NaN            NaN            NaN
# 2814             NaN            NaN            NaN            NaN
# 3665             NaN            NaN            NaN            NaN
# 4259             NaN            NaN            NaN            NaN
# ...              ...            ...            ...            ...
# 52186            4.0            NaN            0.0            0.0
# 52187            NaN            2.0            5.0           23.0
# 52188            NaN            NaN            6.0            6.0
# 52189            2.0            4.0           14.0            4.0
# 52190            2.0            NaN           19.0           17.0
#
#        player_1_double_faults  player_2_double_faults  \
# 803                       NaN                     NaN
# 804                       NaN                     NaN
# 2814                      NaN                     NaN
# 3665                      NaN                     NaN
# 4259                      NaN                     NaN
# ...                       ...                     ...
# 52186                     0.0                     0.0
# 52187                     3.0                     2.0
# 52188                     1.0                     4.0
# 52189                     2.0                     6.0
# 52190                     4.0                     2.0
#
#        player_1_service_points  player_2_service_points  \
# 803                        NaN                      NaN
# 804                        NaN                      NaN
# 2814                       NaN                      NaN
# 3665                       NaN                      NaN
# 4259                       NaN                      NaN
# ...                        ...                      ...
# 52186                      5.0                      2.0
# 52187                     57.0                     63.0
# 52188                     76.0                     68.0
# 52189                     61.0                     72.0
# 52190                    108.0                    115.0
#
#        player_1_first_serves_in  player_2_first_serves_in  \
# 803                         NaN                       NaN
# 804                         NaN                       NaN
# 2814                        NaN                       NaN
# 3665                        NaN                       NaN
# 4259                        NaN                       NaN
# ...                         ...                       ...
# 52186                       5.0                       0.0
# 52187                      40.0                      43.0
# 52188                      49.0                      37.0
# 52189                      37.0                      38.0
# 52190                      73.0                      71.0
#
#        player_1_first_serve_points_won  player_2_first_serve_points_won  \
# 803                                NaN                              NaN
# 804                                NaN                              NaN
# 2814                               NaN                              NaN
# 3665                               NaN                              NaN
# 4259                               NaN                              NaN
# ...                                ...                              ...
# 52186                              4.0                              0.0
# 52187                             31.0                             38.0
# 52188                             32.0                             31.0
# 52189                             33.0                             26.0
# 52190                             63.0                             60.0
#
#        player_1_second_serve_points_won  player_2_second_serve_points_won  \
# 803                                 NaN                               NaN
# 804                                 NaN                               NaN
# 2814                                NaN                               NaN
# 3665                                NaN                               NaN
# 4259                                NaN                               NaN
# ...                                 ...                               ...
# 52186                               0.0                               2.0
# 52187                              10.0                              12.0
# 52188                              14.0                              17.0
# 52189                              15.0                              21.0
# 52190                              20.0                              26.0
#
#        player_1_service_game_total  player_2_service_game_total  \
# 803                            NaN                          NaN
# 804                            NaN                          NaN
# 2814                           NaN                          NaN
# 3665                           NaN                          NaN
# 4259                           NaN                          NaN
# ...                            ...                          ...
# 52186                          1.0                          0.0
# 52187                         10.0                         11.0
# 52188                         11.0                         11.0
# 52189                         11.0                         11.0
# 52190                         18.0                         18.0
#
#        player_1_break_points_saved  player_2_break_points_saved  \
# 803                            NaN                          NaN
# 804                            NaN                          NaN
# 2814                           NaN                          NaN
# 3665                           NaN                          NaN
# 4259                           NaN                          NaN
# ...                            ...                          ...
# 52186                          0.0                          0.0
# 52187                          1.0                          0.0
# 52188                          1.0                          2.0
# 52189                          2.0                          6.0
# 52190                          1.0                          3.0
#
#        player_1_break_points_faced  player_2_break_points_faced  \
# 803                            NaN                          NaN
# 804                            NaN                          NaN
# 2814                           NaN                          NaN
# 3665                           NaN                          NaN
# 4259                           NaN                          NaN
# ...                            ...                          ...
# 52186                          0.0                          0.0
# 52187                          2.0                          0.0
# 52188                          3.0                          3.0
# 52189                          3.0                          8.0
# 52190                          1.0                          4.0
#
#                   winner  player_1_first_serve_%  player_2_first_serve_%  \
# 803         Leander Paes                     NaN                     NaN
# 804      Fazaluddin Syed                     NaN                     NaN
# 2814       Wayne Arthurs                     NaN                     NaN
# 3665         Ali Hamadeh                     NaN                     NaN
# 4259   Rainer Schuettler                     NaN                     NaN
# ...                  ...                     ...                     ...
# 52186          Jack Sock                1.000000                0.000000
# 52187       Ivo Karlovic                0.701754                0.682540
# 52188         Rajeev Ram                0.644737                0.544118
# 52189       Ivo Karlovic                0.606557                0.527778
# 52190         Rajeev Ram                0.675926                0.617391
#
#        player_1_first_serve_win_%  player_2_first_serve_win_%  \
# 803                           NaN                         NaN
# 804                           NaN                         NaN
# 2814                          NaN                         NaN
# 3665                          NaN                         NaN
# 4259                          NaN                         NaN
# ...                           ...                         ...
# 52186                    0.800000                         NaN
# 52187                    0.775000                    0.883721
# 52188                    0.653061                    0.837838
# 52189                    0.891892                    0.684211
# 52190                    0.863014                    0.845070
#
#        player_1_break_points_won  player_2_break_points_won
# 803                          NaN                        NaN
# 804                          NaN                        NaN
# 2814                         NaN                        NaN
# 3665                         NaN                        NaN
# 4259                         NaN                        NaN
# ...                          ...                        ...
# 52186                        0.0                        0.0
# 52187                        0.0                        1.0
# 52188                        1.0                        2.0
# 52189                        2.0                        1.0
# 52190                        1.0                        0.0
#
# [179 rows x 58 columns]

# %%
# check sanity
df.iloc[803]
# Out:
# tourney_id                                            1999-D026
# tourney_name                        Davis Cup G1 PO: IND vs CHN
# surface                                                   Grass
# draw_size                                                     4
# tourney_level                                                 D
# tourney_date                                1999-04-02 00:00:00
# match_num                                                     4
# score                                         6-7(5) 7-6(3) 6-3
# best_of                                                       3
# round                                                        RR
# minutes                                               89.741874
# player_1                                          Ben Qiang Zhu
# player_2                                           Leander Paes
# player_1_age                                          20.043806
# player_2_age                                          25.779603
# player_1_entry                                              NaN
# player_2_entry                                              NaN
# player_1_hand                                                 R
# player_2_hand                                                 R
# player_1_ht                                                 NaN
# player_2_ht                                               178.0
# player_1_id                                              103337
# player_2_id                                              102233
# player_1_ioc                                                CHN
# player_2_ioc                                                IND
# player_1_name                                     Ben Qiang Zhu
# player_2_name                                      Leander Paes
# player_1_rank                                             792.0
# player_2_rank                                             101.0
# player_1_rank_points                                       14.0
# player_2_rank_points                                      504.0
# player_1_seed                                               NaN
# player_2_seed                                               NaN
# player_1_aces                                               NaN
# player_2_aces                                               NaN
# player_1_double_faults                                      NaN
# player_2_double_faults                                      NaN
# player_1_service_points                                     NaN
# player_2_service_points                                     NaN
# player_1_first_serves_in                                    NaN
# player_2_first_serves_in                                    NaN
# player_1_first_serve_points_won                             NaN
# player_2_first_serve_points_won                             NaN
# player_1_second_serve_points_won                            NaN
# player_2_second_serve_points_won                            NaN
# player_1_service_game_total                                 NaN
# player_2_service_game_total                                 NaN
# player_1_break_points_saved                                 NaN
# player_2_break_points_saved                                 NaN
# player_1_break_points_faced                                 NaN
# player_2_break_points_faced                                 NaN
# winner                                             Leander Paes
# player_1_first_serve_%                                      NaN
# player_2_first_serve_%                                      NaN
# player_1_first_serve_win_%                                  NaN
# player_2_first_serve_win_%                                  NaN
# player_1_break_points_won                                   NaN
# player_2_break_points_won                                   NaN
# Name: 803, dtype: object

# %%
# list subsets for a good ole fashion loop
subsets = [best_of_3_hard,
           best_of_3_clay,
           best_of_3_grass,
           best_of_3_carpet,
           best_of_5_hard,
           best_of_5_clay,
           best_of_5_grass,
           best_of_5_carpet
          ]

# %%
# loop through subsets
for subset in subsets:
    # generate average match time length
    mean_match_length = subset.minutes.mean()
    print(mean_match_length)
    # locate indexes where there are mtls
    ss_idx = subset[subset.minutes.isnull()].index
    print(ss_idx)
    # fill missing minutes
    df.loc[ss_idx, 'minutes'] = mean_match_length
# Out:
# 94.61218227182077
# Int64Index([  379,   380,   395,   396,   403,   404,   407,   408,   412,
#               780,
#             ...
#             64270, 64271, 64272, 64273, 64282, 64283, 64284, 64285, 64286,
#             64287],
#            dtype='int64', length=1368)
# 97.80815297032622
# Int64Index([  388,   392,   399,   400,   784,   796,   799,   800,   811,
#               812,
#             ...
#             64262, 64263, 64274, 64275, 64276, 64277, 64278, 64279, 64280,
#             64281],
#            dtype='int64', length=757)
# 89.74187422733866
# Int64Index([  803,   804,  2814,  3665,  4259,  4260,  4278,  5338,  5339,
#              7026,
#             ...
#             52181, 52182, 52183, 52184, 52185, 52186, 52187, 52188, 52189,
#             52190],
#            dtype='int64', length=179)
# 91.96229655722114
# Int64Index([  824,   843,   844,   872,  1268,  1269,  1277,  1287,  1288,
#              2038,
#             ...
#             36235, 37412, 37413, 39201, 40431, 41979, 41997, 41998, 42540,
#             42541],
#            dtype='int64', length=174)
# 148.40521794129475
# Int64Index([  281,   282,   283,   284,   377,   378,   393,   394,   401,
#               402,
#             ...
#             52876, 52877, 52878, 52883, 52884, 52885, 52886, 53253, 53254,
#             53255],
#            dtype='int64', length=1867)
# 149.59291889789256
# Int64Index([  385,   386,   387,   389,   390,   391,   397,   398,   781,
#               782,
#             ...
#             52875, 52880, 52881, 52882, 53319, 53320, 53321, 53973, 53974,
#             53976],
#            dtype='int64', length=1524)
# 141.64797280609505
# Int64Index([  801,   802,  2811,  2812,  2813,  3662,  3663,  3664,  4257,
#              4258,
#             ...
#             45509, 49934, 49935, 52194, 52195, 52196, 52197, 52198, 52199,
#             52200],
#            dtype='int64', length=116)
# 148.22188905547227
# Int64Index([  381,   382,   383,   384,   821,   822,   823,   833,   834,
#               835,
#             ...
#             42533, 42538, 42539, 47847, 47848, 47849, 49976, 49977, 49978,
#             49979],
#            dtype='int64', length=467)

# %%
# why was that so fast pandas
df[df.minutes.isnull()]
# Out:
# Empty DataFrame
# Columns: [tourney_id, tourney_name, surface, draw_size, tourney_level, tourney_date, match_num, score, best_of, round, minutes, player_1, player_2, player_1_age, player_2_age, player_1_entry, player_2_entry, player_1_hand, player_2_hand, player_1_ht, player_2_ht, player_1_id, player_2_id, player_1_ioc, player_2_ioc, player_1_name, player_2_name, player_1_rank, player_2_rank, player_1_rank_points, player_2_rank_points, player_1_seed, player_2_seed, player_1_aces, player_2_aces, player_1_double_faults, player_2_double_faults, player_1_service_points, player_2_service_points, player_1_first_serves_in, player_2_first_serves_in, player_1_first_serve_points_won, player_2_first_serve_points_won, player_1_second_serve_points_won, player_2_second_serve_points_won, player_1_service_game_total, player_2_service_game_total, player_1_break_points_saved, player_2_break_points_saved, player_1_break_points_faced, player_2_break_points_faced, winner, player_1_first_serve_%, player_2_first_serve_%, player_1_first_serve_win_%, player_2_first_serve_win_%, player_1_break_points_won, player_2_break_points_won]
# Index: []

# %%
df.iloc[388]
# Out:
# tourney_id                                            1999-D023
# tourney_name                        Davis Cup G1 QF: COL vs CAN
# surface                                                    Clay
# draw_size                                                     4
# tourney_level                                                 D
# tourney_date                                1999-02-12 00:00:00
# match_num                                                     5
# score                                               4-6 6-1 6-4
# best_of                                                       3
# round                                                        RR
# minutes                                               97.808153
# player_1                                         Eduardo Rincon
# player_2                                           Simon Larose
# player_1_age                                          22.882957
# player_2_age                                          20.616016
# player_1_entry                                              NaN
# player_2_entry                                              NaN
# player_1_hand                                                 R
# player_2_hand                                                 R
# player_1_ht                                                 NaN
# player_2_ht                                               190.0
# player_1_id                                              102756
# player_2_id                                              103225
# player_1_ioc                                                COL
# player_2_ioc                                                CAN
# player_1_name                                    Eduardo Rincon
# player_2_name                                      Simon Larose
# player_1_rank                                             839.0
# player_2_rank                                               NaN
# player_1_rank_points                                       12.0
# player_2_rank_points                                        NaN
# player_1_seed                                               NaN
# player_2_seed                                               NaN
# player_1_aces                                               NaN
# player_2_aces                                               NaN
# player_1_double_faults                                      NaN
# player_2_double_faults                                      NaN
# player_1_service_points                                     NaN
# player_2_service_points                                     NaN
# player_1_first_serves_in                                    NaN
# player_2_first_serves_in                                    NaN
# player_1_first_serve_points_won                             NaN
# player_2_first_serve_points_won                             NaN
# player_1_second_serve_points_won                            NaN
# player_2_second_serve_points_won                            NaN
# player_1_service_game_total                                 NaN
# player_2_service_game_total                                 NaN
# player_1_break_points_saved                                 NaN
# player_2_break_points_saved                                 NaN
# player_1_break_points_faced                                 NaN
# player_2_break_points_faced                                 NaN
# winner                                             Simon Larose
# player_1_first_serve_%                                      NaN
# player_2_first_serve_%                                      NaN
# player_1_first_serve_win_%                                  NaN
# player_2_first_serve_win_%                                  NaN
# player_1_break_points_won                                   NaN
# player_2_break_points_won                                   NaN
# Name: 388, dtype: object

# %%
# omg lol look at all these best of 5 carpet matches
best_of_5_carpet = df[(df.best_of == 5) & (df.surface == 'Carpet')]
best_of_5_carpet
# Out:
#                                tourney_id                 tourney_name  \
# 381                             1999-D018  Davis Cup G1 R1: UKR vs BLR
# 382                             1999-D018  Davis Cup G1 R1: UKR vs BLR
# 383                             1999-D018  Davis Cup G1 R1: UKR vs BLR
# 384                             1999-D018  Davis Cup G1 R1: UKR vs BLR
# 821                             1999-D044  Davis Cup G1 QF: FIN vs ISR
# ...                                   ...                          ...
# 56574  2017-M-DC-2017-G2-EPA-M-FIN-GEO-01  Davis Cup G2 R1: FIN vs GEO
# 56575  2017-M-DC-2017-G2-EPA-M-FIN-GEO-01  Davis Cup G2 R1: FIN vs GEO
# 56580  2017-M-DC-2017-G2-EPA-M-MAR-DEN-01  Davis Cup G2 R1: MAR vs DEN
# 56581  2017-M-DC-2017-G2-EPA-M-MAR-DEN-01  Davis Cup G2 R1: MAR vs DEN
# 56582  2017-M-DC-2017-G2-EPA-M-MAR-DEN-01  Davis Cup G2 R1: MAR vs DEN
#
#       surface  draw_size tourney_level tourney_date  match_num  \
# 381    Carpet          4             D   1999-02-12          1
# 382    Carpet          4             D   1999-02-12          2
# 383    Carpet          4             D   1999-02-12          4
# 384    Carpet          4             D   1999-02-12          5
# 821    Carpet          4             D   1999-04-02          1
# ...       ...        ...           ...          ...        ...
# 56574  Carpet          4             D   2017-02-03          4
# 56575  Carpet          4             D   2017-02-03          5
# 56580  Carpet          4             D   2017-02-03          1
# 56581  Carpet          4             D   2017-02-03          2
# 56582  Carpet          4             D   2017-02-03          4
#
#                         score  best_of round     minutes          player_1  \
# 381               6-2 6-3 7-5        5    RR  148.221889    Andrei Rybalko
# 382        3-6 6-3 7-6(4) 7-5        5    RR  148.221889   Andrei Medvedev
# 383           5-7 6-3 6-3 6-3        5    RR  148.221889   Andrei Medvedev
# 384           6-3 6-0 3-6 6-3        5    RR  148.221889    Andrei Rybalko
# 821               6-3 6-2 6-4        5    RR  148.221889          Eyal Ran
# ...                       ...      ...   ...         ...               ...
# 56574             6-2 6-4 6-4        5    RR  113.000000   Emil Ruusuvuori
# 56575  6-4 7-5 5-7 0-6 7-6(5)        5    RR  113.000000   George Tsivadze
# 56580             6-1 6-3 6-3        5    RR   80.000000      Amine Ahouda
# 56581      6-2 3-6 6-2 7-6(5)        5    RR  146.000000    Reda El Amrani
# 56582         6-2 3-6 6-3 6-4        5    RR  127.000000  Frederik Nielsen
#
#                      player_2  player_1_age  player_2_age player_1_entry  \
# 381        Vladimir Voltchkov     26.677618     20.840520            NaN
# 382                Max Mirnyi     24.440794     21.593429            NaN
# 383        Vladimir Voltchkov     24.440794     20.840520            NaN
# 384                Max Mirnyi     26.677618     21.593429            NaN
# 821             Tuomas Ketola     26.349076     24.098563            NaN
# ...                       ...           ...           ...            ...
# 56574    Nikoloz Basilashvili     17.831622     24.936345            NaN
# 56575  Patrik Niklas Salminen     24.076660     19.906913            NaN
# 56580        Frederik Nielsen     19.386721     33.429158            NaN
# 56581       Soren Hess Olesen     28.700890     26.058864            NaN
# 56582          Reda El Amrani     33.429158     28.700890            NaN
#
#       player_2_entry player_1_hand player_2_hand  player_1_ht  player_2_ht  \
# 381              NaN             R             R        180.0        180.0
# 382              NaN             R             R        193.0        196.0
# 383              NaN             R             R        193.0        180.0
# 384              NaN             R             R        180.0        196.0
# 821              NaN             R             R        183.0        185.0
# ...              ...           ...           ...          ...          ...
# 56574            NaN             R             R        188.0        185.0
# 56575            NaN             U             L          NaN          NaN
# 56580            NaN             U             R          NaN        190.0
# 56581            NaN             R             R        185.0          NaN
# 56582            NaN             R             R        190.0        185.0
#
#        player_1_id  player_2_id player_1_ioc player_2_ioc     player_1_name  \
# 381         102069       103166          UKR          BLR    Andrei Rybalko
# 382         102446       103018          UKR          BLR   Andrei Medvedev
# 383         102446       103166          UKR          BLR   Andrei Medvedev
# 384         102069       103018          UKR          BLR    Andrei Rybalko
# 821         102139       102538          ISR          FIN          Eyal Ran
# ...            ...          ...          ...          ...               ...
# 56574       200325       105932          FIN          GEO   Emil Ruusuvuori
# 56575       106106       126609          GEO          FIN   George Tsivadze
# 56580       144760       104233          MAR          DEN      Amine Ahouda
# 56581       105149       126526          MAR          DEN    Reda El Amrani
# 56582       104233       105149          DEN          MAR  Frederik Nielsen
#
#                 player_2_name  player_1_rank  player_2_rank  \
# 381        Vladimir Voltchkov          405.0          131.0
# 382                Max Mirnyi           81.0            NaN
# 383        Vladimir Voltchkov           81.0          131.0
# 384                Max Mirnyi          405.0            NaN
# 821             Tuomas Ketola          217.0          187.0
# ...                       ...            ...            ...
# 56574    Nikoloz Basilashvili         1511.0           89.0
# 56575  Patrik Niklas Salminen          819.0          745.0
# 56580        Frederik Nielsen          861.0          408.0
# 56581       Soren Hess Olesen          682.0            NaN
# 56582          Reda El Amrani          408.0          682.0
#
#        player_1_rank_points  player_2_rank_points  player_1_seed  \
# 381                    73.0                 354.0            NaN
# 382                   615.0                   NaN            NaN
# 383                   615.0                 354.0            NaN
# 384                    73.0                   NaN            NaN
# 821                   209.0                 249.0            NaN
# ...                     ...                   ...            ...
# 56574                   2.0                 630.0            NaN
# 56575                  21.0                  28.0            NaN
# 56580                  18.0                 104.0            NaN
# 56581                  36.0                   NaN            NaN
# 56582                 104.0                  36.0            NaN
#
#        player_2_seed  player_1_aces  player_2_aces  player_1_double_faults  \
# 381              NaN            NaN            NaN                     NaN
# 382              NaN            NaN            NaN                     NaN
# 383              NaN            NaN            NaN                     NaN
# 384              NaN            NaN            NaN                     NaN
# 821              NaN            NaN            NaN                     NaN
# ...              ...            ...            ...                     ...
# 56574            NaN            1.0            1.0                     3.0
# 56575            NaN            0.0            0.0                     0.0
# 56580            NaN            1.0            2.0                     3.0
# 56581            NaN            8.0            4.0                     7.0
# 56582            NaN           12.0            8.0                     5.0
#
#        player_2_double_faults  player_1_service_points  \
# 381                       NaN                      NaN
# 382                       NaN                      NaN
# 383                       NaN                      NaN
# 384                       NaN                      NaN
# 821                       NaN                      NaN
# ...                       ...                      ...
# 56574                     5.0                     93.0
# 56575                     0.0                      0.0
# 56580                     2.0                     76.0
# 56581                     4.0                    122.0
# 56582                    10.0                    118.0
#
#        player_2_service_points  player_1_first_serves_in  \
# 381                        NaN                       NaN
# 382                        NaN                       NaN
# 383                        NaN                       NaN
# 384                        NaN                       NaN
# 821                        NaN                       NaN
# ...                        ...                       ...
# 56574                     91.0                      54.0
# 56575                      1.0                       0.0
# 56580                     63.0                      43.0
# 56581                    132.0                      72.0
# 56582                    111.0                      76.0
#
#        player_2_first_serves_in  player_1_first_serve_points_won  \
# 381                         NaN                              NaN
# 382                         NaN                              NaN
# 383                         NaN                              NaN
# 384                         NaN                              NaN
# 821                         NaN                              NaN
# ...                         ...                              ...
# 56574                      53.0                             31.0
# 56575                       1.0                              0.0
# 56580                      34.0                             28.0
# 56581                      82.0                             56.0
# 56582                      61.0                             55.0
#
#        player_2_first_serve_points_won  player_1_second_serve_points_won  \
# 381                                NaN                               NaN
# 382                                NaN                               NaN
# 383                                NaN                               NaN
# 384                                NaN                               NaN
# 821                                NaN                               NaN
# ...                                ...                               ...
# 56574                             39.0                              17.0
# 56575                              0.0                               0.0
# 56580                             30.0                              14.0
# 56581                             54.0                              23.0
# 56582                             46.0                              25.0
#
#        player_2_second_serve_points_won  player_1_service_game_total  \
# 381                                 NaN                          NaN
# 382                                 NaN                          NaN
# 383                                 NaN                          NaN
# 384                                 NaN                          NaN
# 821                                 NaN                          NaN
# ...                                 ...                          ...
# 56574                              22.0                         14.0
# 56575                               0.0                         26.0
# 56580                              22.0                         12.0
# 56581                              24.0                         19.0
# 56582                              23.0                         18.0
#
#        player_2_service_game_total  player_1_break_points_saved  \
# 381                            NaN                          NaN
# 382                            NaN                          NaN
# 383                            NaN                          NaN
# 384                            NaN                          NaN
# 821                            NaN                          NaN
# ...                            ...                          ...
# 56574                         14.0                          6.0
# 56575                         26.0                          0.0
# 56580                         13.0                          3.0
# 56581                         18.0                          6.0
# 56582                         18.0                          7.0
#
#        player_2_break_points_saved  player_1_break_points_faced  \
# 381                            NaN                          NaN
# 382                            NaN                          NaN
# 383                            NaN                          NaN
# 384                            NaN                          NaN
# 821                            NaN                          NaN
# ...                            ...                          ...
# 56574                          7.0                         12.0
# 56575                          0.0                          0.0
# 56580                          0.0                          8.0
# 56581                          9.0                          9.0
# 56582                          4.0                          8.0
#
#        player_2_break_points_faced                winner  \
# 381                            NaN    Vladimir Voltchkov
# 382                            NaN       Andrei Medvedev
# 383                            NaN       Andrei Medvedev
# 384                            NaN            Max Mirnyi
# 821                            NaN              Eyal Ran
# ...                            ...                   ...
# 56574                          9.0  Nikoloz Basilashvili
# 56575                          0.0       George Tsivadze
# 56580                          0.0      Frederik Nielsen
# 56581                         15.0        Reda El Amrani
# 56582                          8.0      Frederik Nielsen
#
#        player_1_first_serve_%  player_2_first_serve_%  \
# 381                       NaN                     NaN
# 382                       NaN                     NaN
# 383                       NaN                     NaN
# 384                       NaN                     NaN
# 821                       NaN                     NaN
# ...                       ...                     ...
# 56574                0.580645                0.582418
# 56575                     NaN                1.000000
# 56580                0.565789                0.539683
# 56581                0.590164                0.621212
# 56582                0.644068                0.549550
#
#        player_1_first_serve_win_%  player_2_first_serve_win_%  \
# 381                           NaN                         NaN
# 382                           NaN                         NaN
# 383                           NaN                         NaN
# 384                           NaN                         NaN
# 821                           NaN                         NaN
# ...                           ...                         ...
# 56574                    0.574074                    0.735849
# 56575                         NaN                    0.000000
# 56580                    0.651163                    0.882353
# 56581                    0.777778                    0.658537
# 56582                    0.723684                    0.754098
#
#        player_1_break_points_won  player_2_break_points_won
# 381                          NaN                        NaN
# 382                          NaN                        NaN
# 383                          NaN                        NaN
# 384                          NaN                        NaN
# 821                          NaN                        NaN
# ...                          ...                        ...
# 56574                        2.0                        6.0
# 56575                        0.0                        0.0
# 56580                        0.0                        5.0
# 56581                        6.0                        3.0
# 56582                        4.0                        1.0
#
# [496 rows x 58 columns]

# %%
print(f'0 |{len(df)}')                                       # MIRA GUEY

# create target variable 
df['player_1_wins'] = np.where(df['winner'] == df['player_1'], True, False)

# drop all walkovers (no useful stats) and best of 1 matches (extremely rare format)
df = df.drop(df[df.score == 'W/O'].index)
df = df.drop(df[df.best_of == 1].index)

print(f'1 |{len(df)}')                                       # MIRA GUEY

# drop janky records
df = df[df['player_1_first_serve_%'].notnull()]
df = df[df['player_2_first_serve_%'].notnull()]
df = df[df['player_2_first_serve_win_%'].notnull()]

print(f'2 |{len(df)}')                                       # MIRA GUEY

# gather all players in two sets
players = set(list(df.player_1.unique()))
players2 = set(list(df.player_2.unique()))

# combine, drop duplicates, convert set to list type and sort for fun 
players = players.union(players2)
players = list(players)
players.sort()

# set an empty list to fill
less_than_50 = []

# use a for-loop to run through the list of players
for player in players:
    # set up if-conditional to see if the length of records where a player shows up in the dataframe is less than 50
    if len(df[(df.player_1 == player) | (df.player_2 == player)]) < 50:
        # if there are less than 50 records, add the player's name to the list
        less_than_50.append(player)
# sort list
less_than_50.sort()

# run through loop of list of players with less than 50 matches
for player in less_than_50:
    # set dataframe to records where these players are not present
    df = df[df.player_1 != player]
    df = df[df.player_2 != player]

print(f'3 |{len(df)}')                                       # MIRA GUEY
# drop player entry columns, verify
df = df.drop(columns = ['player_1_entry', 'player_2_entry'])

# assign variable to index
jd_p1_index = list(df[df.player_1 == 'Jared Donaldson'].index)
# review index where Jared is player 2, assign to variable
jd_p2_index = df[df.player_2 == 'Jared Donaldson'].index
# fill all his heights with 188 cm
df.loc[jd_p1_index, 'player_1_ht'] = 188
# fill all his heights with 188
df.loc[jd_p2_index, 'player_2_ht'] = 188

# fill dem missing heights
max_mar_idx = df[df.player_1 == 'Maximilian Marterer'].index
max_mar_idx2 = df[df.player_2 == 'Maximilian Marterer'].index
df.loc[max_mar_idx, 'player_1_ht'] = 188
df.loc[max_mar_idx2, 'player_2_ht'] = 188

bjorn_frat_idx = df[df.player_1 == 'Bjorn Fratangelo']
bjorn_frat_idx2 = df[df.player_2 == 'Bjorn Fratangelo']
df.loc[bjorn_frat_idx, 'player_1_ht'] = 183
df.loc[bjorn_frat_idx2, 'player_2_ht'] = 183

# assign variable to index where AG is ready player1
ag_p1_index = df[df.player_1 == 'Alejandro Gonzalez'].index
# fill his heights 191
df.loc[ag_p1_index, 'player_1_ht'] = 191
# assign variable to indexes where AG is player2
ag_p2_index = df[df.player_2 == 'Alejandro Gonzalez'].index
# fill his heights 191
df.loc[ag_p2_index, 'player_2_ht'] = 191

# assign variables to indexes where Thomas is player 1 or player 2
tf_p1_index = df[df.player_1 == 'Thomas Fabbiano'].index
tf_p2_index = df[df.player_2 == 'Thomas Fabbiano'].index
# fill his heights with 173 cm
df.loc[tf_p1_index, 'player_1_ht'] = 173
df.loc[tf_p2_index, 'player_2_ht'] = 173

# assign variable to list of tourney ids that have missing minutes
missing_minutes = list(df[df.minutes.isnull()].tourney_id.unique())
# commence loop through list of tournaments with missing match lengths
for tourney in missing_minutes:
    # assign mean match length for tournament to variable
    mean_match_length = df[df.tourney_id == tourney].minutes.mean()
    # locate index where there are mml for the tournament, fill values with average match length
    df.loc[df[df.tourney_id == tourney].minutes.isnull().index, 'minutes'] = mean_match_length

# create columns (engineer categorical feature) to determine if players are seeded
df['player_1_seeded'] = df.player_1_seed.apply(lambda x: x > 0)
df['player_2_seeded'] = df.player_2_seed.apply(lambda x: x > 0)

# assign variable to all of best of 3 matches 
best_of_3 = df[df.best_of == 3]
# generate index for nulls
mm_index = df[df.minutes.isnull()].index
# fill nulls with best of 3 average match length time for our data (these tournaments are all best of 3) (this is a 'quick fix')
df.loc[mm_index, 'minutes'] = best_of_3.minutes.mean()

# fill seed nulls with string 'Unseeded'
# df.player_1_seed = df.player_1_seed.fillna('Unseeded')
# df.player_2_seed = df.player_2_seed.fillna('Unseeded')

# fill rank points with 0, brand new on the tour
jg_rnull_idx = df[(df.player_1 == 'Justin Gimelstob') & (df.player_1_rank_points.isnull())].index
df.loc[jg_rnull_idx, 'player_1_rank_points'] = 0
jj_1rnull_idx = df[df.player_1 == 'Joachim Johansson'].index[0]
df.loc[jj_1rnull_idx, 'player_1_rank_points'] = 0

# fill rank points manually with inferred values
jj_2rnull_idx = df[df.player_1 == 'Joachim Johansson'].index[-1]
df.loc[jj_2rnull_idx, 'player_1_rank_points'] = 0
jj_3rnull_idx = df[(df.player_2 == 'Joachim Johansson') & (df.player_2_rank_points.isnull())].index
df.loc[jj_3rnull_idx, 'player_2_rank_points'] = 0
kc_rnull_idx = df[(df.player_1 == 'Kenneth Carlsen') & (df.player_1_rank.isnull())].index
df.loc[kc_rnull_idx, 'player_1_rank'] = 46
df.loc[kc_rnull_idx, 'player_1_rank_points'] = 880

# fill remaining rank point nulls with 0
df.player_1_rank_points = df.player_1_rank_points.fillna(0)
df.player_2_rank_points = df.player_2_rank_points.fillna(0)

# infer ranks from last match plus pentalties 
th_r2null_idx = df[(df.player_2 == 'Tommy Haas') & (df.player_2_rank.isnull())].index[:2]
df.loc[th_r2null_idx, 'player_2_rank'] = 33
th_r1null_idx = df[(df.player_1 == 'Tommy Haas') & (df.player_1_rank.isnull())].index
df.loc[th_r1null_idx, 'player_1_rank'] = 33
th_r3null_idx = df[(df.player_2 == 'Tommy Haas') & (df.player_2_rank.isnull())].index
df.loc[th_r3null_idx, 'player_2_rank'] = 490

# 'fix'
mrp2_idx = df[df.player_2_rank.isnull()].index
mrp1_idx = df[df.player_1_rank.isnull()].index
df.loc[mrp2_idx, 'player_2_rank'] = 300
df.loc[mrp1_idx, 'player_1_rank'] = 300

# reset index to tourney date
df = df.set_index('tourney_date')

print(f'4 |{len(df)}')                                       # MIRA GUEY

# drop superfluous
# df = df.drop(columns = ['player_1', 'player_2'])

df_clean = df = df.dropna(subset=['player_1_aces'])


print(f'5 |{len(df)}')                                       # MIRA GUEY

# create dummy columns for surface, level, hand, and round 
dummy_df = pd.get_dummies(df[['surface', 'tourney_level', 'player_1_hand', 'player_2_hand', 'round']], dummy_na = False, drop_first = False)
# concat dummy columns to df
df = pd.concat([df, dummy_df], axis = 1)


df.info()
# Out:
# "\n\nprint(f'0 |{len(df)}')                                       # MIRA GUEY\n\n# create target variable \ndf['player_1_wins'] = np.where(df['winner'] == df['player_1'], True, False)\n\n# drop all walkovers (no useful stats) and best of 1 matches (extremely rare format)\ndf = df.drop(df[df.score == 'W/O'].index)\ndf = df.drop(df[df.best_of == 1].index)\n\nprint(f'1 |{len(df)}')                                       # MIRA GUEY\n\n# drop janky records\ndf = df[df['player_1_first_serve_%'].notnull()]\ndf = df[df['player_2_first_serve_%'].notnull()]\ndf = df[df['player_2_first_serve_win_%'].notnull()]\n\nprint(f'2 |{len(df)}')                                       # MIRA GUEY\n\n# gather all players in two sets\nplayers = set(list(df.player_1.unique()))\nplayers2 = set(list(df.player_2.unique()))\n\n# combine, drop duplicates, convert set to list type and sort for fun \nplayers = players.union(players2)\nplayers = list(players)\nplayers.sort()\n\n# set an empty list to fill\nless_than_50 = []\n\n# use a for-loop to run through the list of players\nfor player in players:\n    # set up if-conditional to see if the length of records where a player shows up in the dataframe is less than 50\n    if len(df[(df.player_1 == player) | (df.player_2 == player)]) < 50:\n        # if there are less than 50 records, add the player's name to the list\n        less_than_50.append(player)\n# sort list\nless_than_50.sort()\n\n# run through loop of list of players with less than 50 matches\nfor player in less_than_50:\n    # set dataframe to records where these players are not present\n    df = df[df.player_1 != player]\n    df = df[df.player_2 != player]\n\nprint(f'3 |{len(df)}')                                       # MIRA GUEY\n# drop player entry columns, verify\ndf = df.drop(columns = ['player_1_entry', 'player_2_entry'])\n\n# assign variable to index\njd_p1_index = list(df[df.player_1 == 'Jared Donaldson'].index)\n# review index where Jared is player 2, assign to variable\njd_p2_index = df[df.player_2 == 'Jared Donaldson'].index\n# fill all his heights with 188 cm\ndf.loc[jd_p1_index, 'player_1_ht'] = 188\n# fill all his heights with 188\ndf.loc[jd_p2_index, 'player_2_ht'] = 188\n\n# fill dem missing heights\nmax_mar_idx = df[df.player_1 == 'Maximilian Marterer'].index\nmax_mar_idx2 = df[df.player_2 == 'Maximilian Marterer'].index\ndf.loc[max_mar_idx, 'player_1_ht'] = 188\ndf.loc[max_mar_idx2, 'player_2_ht'] = 188\n\nbjorn_frat_idx = df[df.player_1 == 'Bjorn Fratangelo']\nbjorn_frat_idx2 = df[df.player_2 == 'Bjorn Fratangelo']\ndf.loc[bjorn_frat_idx, 'player_1_ht'] = 183\ndf.loc[bjorn_frat_idx2, 'player_2_ht'] = 183\n\n# assign variable to index where AG is ready player1\nag_p1_index = df[df.player_1 == 'Alejandro Gonzalez'].index\n# fill his heights 191\ndf.loc[ag_p1_index, 'player_1_ht'] = 191\n# assign variable to indexes where AG is player2\nag_p2_index = df[df.player_2 == 'Alejandro Gonzalez'].index\n# fill his heights 191\ndf.loc[ag_p2_index, 'player_2_ht'] = 191\n\n# assign variables to indexes where Thomas is player 1 or player 2\ntf_p1_index = df[df.player_1 == 'Thomas Fabbiano'].index\ntf_p2_index = df[df.player_2 == 'Thomas Fabbiano'].index\n# fill his heights with 173 cm\ndf.loc[tf_p1_index, 'player_1_ht'] = 173\ndf.loc[tf_p2_index, 'player_2_ht'] = 173\n\n# assign variable to list of tourney ids that have missing minutes\nmissing_minutes = list(df[df.minutes.isnull()].tourney_id.unique())\n# commence loop through list of tournaments with missing match lengths\nfor tourney in missing_minutes:\n    # assign mean match length for tournament to variable\n    mean_match_length = df[df.tourney_id == tourney].minutes.mean()\n    # locate index where there are mml for the tournament, fill values with average match length\n    df.loc[df[df.tourney_id == tourney].minutes.isnull().index, 'minutes'] = mean_match_length\n\n# create columns (engineer categorical feature) to determine if players are seeded\ndf['player_1_seeded'] = df.player_1_ ...

# %%
df.head(3)
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level tourney_date  \
# 0   1999-339     Adelaide    Hard         32             A   1999-01-04
# 1   1999-339     Adelaide    Hard         32             A   1999-01-04
# 2   1999-339     Adelaide    Hard         32             A   1999-01-04
#
#    match_num    score  best_of round  minutes        player_1       player_2  \
# 0          1  6-3 6-0        3   R32     54.0  Patrick Rafter   Takao Suzuki
# 1          2  7-5 6-3        3   R32     71.0     Jim Courier  Slava Dosedel
# 2          3  6-2 6-1        3   R32     45.0     Andrew Ilie     Jiri Novak
#
#    player_1_age  player_2_age player_1_entry player_2_entry player_1_hand  \
# 0     26.017796     22.288843            NaN              Q             R
# 1     28.383299     28.391513            NaN            NaN             R
# 2     22.713210     23.789185            NaN            NaN             R
#
#   player_2_hand  player_1_ht  player_2_ht  player_1_id  player_2_id  \
# 0             R        185.0        175.0       102158       102863
# 1             R        185.0        183.0       101793       101792
# 2             R        180.0        190.0       102776       102562
#
#   player_1_ioc player_2_ioc   player_1_name  player_2_name  player_1_rank  \
# 0          AUS          JPN  Patrick Rafter   Takao Suzuki            4.0
# 1          USA          CZE     Jim Courier  Slava Dosedel           77.0
# 2          AUS          CZE     Andrew Ilie     Jiri Novak           59.0
#
#    player_2_rank  player_1_rank_points  player_2_rank_points  player_1_seed  \
# 0          115.0                3315.0                 415.0            1.0
# 1           64.0                 635.0                 723.0            NaN
# 2           75.0                 757.0                 669.0            NaN
#
#    player_2_seed  player_1_aces  player_2_aces  player_1_double_faults  \
# 0            NaN            4.0            2.0                     3.0
# 1            NaN            3.0            5.0                     2.0
# 2            NaN            2.0            1.0                     4.0
#
#    player_2_double_faults  player_1_service_points  player_2_service_points  \
# 0                     2.0                     55.0                     36.0
# 1                     0.0                     71.0                     53.0
# 2                     2.0                     47.0                     41.0
#
#    player_1_first_serves_in  player_2_first_serves_in  \
# 0                      36.0                      28.0
# 1                      41.0                      37.0
# 2                      22.0                      24.0
#
#    player_1_first_serve_points_won  player_2_first_serve_points_won  \
# 0                             29.0                             14.0
# 1                             31.0                             29.0
# 2                             12.0                             19.0
#
#    player_1_second_serve_points_won  player_2_second_serve_points_won  \
# 0                               9.0                               4.0
# 1                              12.0                              12.0
# 2                               8.0                              11.0
#
#    player_1_service_game_total  player_2_service_game_total  \
# 0                          8.0                          7.0
# 1                         11.0                         10.0
# 2                          8.0                          7.0
#
#    player_1_break_points_saved  player_2_break_points_saved  \
# 0                          8.0                          3.0
# 1                          5.0                          1.0
# 2                          3.0                          0.0
#
#    player_1_break_points_faced  player_2_break_points_faced          winner  \
# 0                          8.0                          7.0  Patrick Rafter
# 1                          8.0                          1.0   Slava Dosedel
# 2                          8.0                          0.0      Jiri Novak
#
#    player_1_first_serve_%  player_2_first_serve_%  player_1_first_serve_win_%  \
# 0                0.654545                0.777778                    0.805556
# 1                0.577465                0.698113                    0.756098
# 2                0.468085                0.585366                    0.545455
#
#    player_2_first_serve_win_%  player_1_break_points_won  \
# 0                    0.500000                        4.0
# 1                    0.783784                        0.0
# 2                    0.791667                        0.0
#
#    player_2_break_points_won
# 0                        0.0
# 1                        3.0
# 2                        5.0

# %%
df.tail(3)
# Out:
#                             tourney_id                     tourney_name  \
# 64778  2019-M-DC-2019-FLS-M-RUS-CAN-01  Davis Cup Finals SF: RUS vs CAN
# 64779  2019-M-DC-2019-FLS-M-CAN-ESP-01   Davis Cup Finals F: CAN vs ESP
# 64780  2019-M-DC-2019-FLS-M-CAN-ESP-01   Davis Cup Finals F: CAN vs ESP
#
#       surface  draw_size tourney_level tourney_date  match_num        score  \
# 64778    Hard          4             D   2019-11-23          2  6-4 4-6 6-4
# 64779    Hard          4             D   2019-11-24          1   7-6(3) 6-3
# 64780    Hard          4             D   2019-11-24          2   6-3 7-6(7)
#
#        best_of round  minutes               player_1               player_2  \
# 64778        3    RR    110.0       Denis Shapovalov        Karen Khachanov
# 64779        3    RR    109.0  Felix Auger Aliassime  Roberto Bautista Agut
# 64780        3    RR    115.0       Denis Shapovalov           Rafael Nadal
#
#        player_1_age  player_2_age player_1_entry player_2_entry player_1_hand  \
# 64778     20.594114     23.493498            NaN            NaN             L
# 64779     19.277207     31.594798            NaN            NaN             R
# 64780     20.594114     33.459274            NaN            NaN             L
#
#       player_2_hand  player_1_ht  player_2_ht  player_1_id  player_2_id  \
# 64778             R        185.0        198.0       133430       111575
# 64779             R        193.0        183.0       200000       105138
# 64780             L        185.0        185.0       133430       104745
#
#       player_1_ioc player_2_ioc          player_1_name          player_2_name  \
# 64778          CAN          RUS       Denis Shapovalov        Karen Khachanov
# 64779          CAN          ESP  Felix Auger Aliassime  Roberto Bautista Agut
# 64780          CAN          ESP       Denis Shapovalov           Rafael Nadal
#
#        player_1_rank  player_2_rank  player_1_rank_points  \
# 64778           15.0           17.0                2050.0
# 64779           21.0            9.0                1636.0
# 64780           15.0            1.0                2050.0
#
#        player_2_rank_points  player_1_seed  player_2_seed  player_1_aces  \
# 64778                1840.0            NaN            NaN           11.0
# 64779                2540.0            NaN            NaN            4.0
# 64780                9985.0            NaN            NaN            4.0
#
#        player_2_aces  player_1_double_faults  player_2_double_faults  \
# 64778            5.0                     6.0                     2.0
# 64779            1.0                     6.0                     1.0
# 64780            7.0                     1.0                     1.0
#
#        player_1_service_points  player_2_service_points  \
# 64778                     93.0                     85.0
# 64779                     68.0                     68.0
# 64780                     76.0                     74.0
#
#        player_1_first_serves_in  player_2_first_serves_in  \
# 64778                      58.0                      59.0
# 64779                      36.0                      49.0
# 64780                      49.0                      51.0
#
#        player_1_first_serve_points_won  player_2_first_serve_points_won  \
# 64778                             46.0                             42.0
# 64779                             28.0                             38.0
# 64780                             38.0                             42.0
#
#        player_1_second_serve_points_won  player_2_second_serve_points_won  \
# 64778                              14.0                              14.0
# 64779                              15.0                              14.0
# 64780                              10.0                              13.0
#
#        player_1_service_game_total  player_2_service_game_total  \
# 64778                         15.0                         15.0
# 64779                         10.0                         11.0
# 64780                         10.0                         11.0
#
#        player_1_break_points_saved  player_2_break_points_saved  \
# 64778                          5.0                          2.0
# 64779                          3.0                          3.0
# 64780                          5.0                          1.0
#
#        player_1_break_points_faced  player_2_break_points_faced  \
# 64778                          7.0                          5.0
# 64779                          5.0                          4.0
# 64780                          6.0                          1.0
#
#                       winner  player_1_first_serve_%  player_2_first_serve_%  \
# 64778       Denis Shapovalov                0.623656                0.694118
# 64779  Roberto Bautista Agut                0.529412                0.720588
# 64780           Rafael Nadal                0.644737                0.689189
#
#        player_1_first_serve_win_%  player_2_first_serve_win_%  \
# 64778                    0.793103                    0.711864
# 64779                    0.777778                    0.775510
# 64780                    0.775510                    0.823529
#
#        player_1_break_points_won  player_2_break_points_won
# 64778                        3.0                        2.0
# 64779                        1.0                        2.0
# 64780                        0.0                        1.0

# %%
calculate_column_nulls(df)
# Out:
#                                   nulls  null_ratio null_percentage
# player_1_entry                    54472     0.84086          84.09%
# player_2_entry                    54195     0.83659          83.66%
# player_1_seed                     44856     0.69243          69.24%
# player_2_seed                     43530     0.67196           67.2%
# player_2_first_serve_win_%         6086     0.09395           9.39%
# player_2_first_serve_%             6084     0.09392           9.39%
# player_1_first_serve_win_%         6081     0.09387           9.39%
# player_1_first_serve_%             6081     0.09387           9.39%
# player_1_aces                      6078     0.09382           9.38%
# player_2_aces                      6078     0.09382           9.38%
# player_1_double_faults             6078     0.09382           9.38%
# player_2_double_faults             6078     0.09382           9.38%
# player_1_service_points            6078     0.09382           9.38%
# player_2_service_points            6078     0.09382           9.38%
# player_1_first_serves_in           6078     0.09382           9.38%
# player_2_first_serves_in           6078     0.09382           9.38%
# player_1_first_serve_points_won    6078     0.09382           9.38%
# player_2_first_serve_points_won    6078     0.09382           9.38%
# player_1_break_points_won          6078     0.09382           9.38%
# player_1_second_serve_points_won   6078     0.09382           9.38%
# player_2_second_serve_points_won   6078     0.09382           9.38%
# player_1_service_game_total        6078     0.09382           9.38%
# player_2_service_game_total        6078     0.09382           9.38%
# player_1_break_points_saved        6078     0.09382           9.38%
# player_2_break_points_saved        6078     0.09382           9.38%
# player_1_break_points_faced        6078     0.09382           9.38%
# player_2_break_points_faced        6078     0.09382           9.38%
# player_2_break_points_won          6078     0.09382           9.38%
# player_1_ht                        3470     0.05357           5.36%
# player_2_ht                        3361     0.05188           5.19%
# player_1_rank_points                986     0.01522           1.52%
# player_1_rank                       986     0.01522           1.52%
# player_2_rank_points                951     0.01468           1.47%
# player_2_rank                       951     0.01468           1.47%
# player_1_hand                        25     0.00039           0.04%
# player_2_hand                        19     0.00029           0.03%
# player_2_age                          5     0.00008           0.01%
# player_1_age                          1     0.00002            0.0%
# player_1_ioc                          0     0.00000            0.0%
# player_2_id                           0     0.00000            0.0%
# surface                               0     0.00000            0.0%
# draw_size                             0     0.00000            0.0%
# tourney_level                         0     0.00000            0.0%
# tourney_date                          0     0.00000            0.0%
# match_num                             0     0.00000            0.0%
# winner                                0     0.00000            0.0%
# score                                 0     0.00000            0.0%
# best_of                               0     0.00000            0.0%
# round                                 0     0.00000            0.0%
# minutes                               0     0.00000            0.0%
# player_1                              0     0.00000            0.0%
# player_2                              0     0.00000            0.0%
# tourney_name                          0     0.00000            0.0%
# player_2_name                         0     0.00000            0.0%
# player_1_name                         0     0.00000            0.0%
# player_2_ioc                          0     0.00000            0.0%
# player_1_id                           0     0.00000            0.0%
# tourney_id                            0     0.00000            0.0%

# %%
# review null values for physical player heights
missing_heights = set(list(df[df.player_1_ht.isnull()].player_1.unique()))
missing_heights2 = set(list(df[df.player_2_ht.isnull()].player_2.unique()))
missing_heights = missing_heights.union(missing_heights2)
missing_heights = list(missing_heights)
missing_heights
# Out:
# ['Fredrik Ask',
#  'Pavel Chekhov',
#  'Rabie Chaki',
#  'Gleb Sakharov',
#  'Dmitriy Makeyev',
#  'Carlos Gomez Herrera',
#  'Jesus Bandres',
#  'Taras Demyanekno',
#  'Ando Rasolomalala',
#  'Kepler Orellana',
#  'Petar Jelenic',
#  'Diadji Ka',
#  'Aymeric Mara',
#  'Jeevan Nedunchezhiyan',
#  'Jose Benitez',
#  'N Vijay Sundar Prashanth',
#  'Daouda Ndiaye',
#  'Adel Al Shatti',
#  'Philip Henning',
#  'Nuno Matias',
#  'Yasir Khan',
#  'Altug Celikbilek',
#  'Juan Andres Gomez',
#  'Luis Diego Chavez Villalpando',
#  'Alberto Lim',
#  'Mohamed Mamoun',
#  'Federico Dondo',
#  'Jalil Khan',
#  'Christophe Bosio',
#  'John El Khoury',
#  'Rameez Junaid',
#  'Marco Trungelliti',
#  'Julian Lenz',
#  'Yazan Al Kasim',
#  'Juan Sebastian Vivanco',
#  'Alejandro Gomez Gb42',
#  'Rodrigo Arus',
#  'Abdulrahman Alawadhi',
#  'Cayetano March',
#  'Sergey Makashin',
#  'Faisal Aidil',
#  'Johann Coles',
#  'Gilles Kremer',
#  'Mathias Bourgue',
#  'Tai Wei Liu',
#  'Solon Peppas',
#  'Alti Vahkal',
#  'Steven Korteling',
#  'Vishal Uppal',
#  'Murad Inoyatov',
#  'Vasilly Kazhera',
#  'Adrian Bohane',
#  'Michael Massih',
#  'Eddy Gonzalez Gonzalez',
#  'Gilbert Wong',
#  'Alexandr Zotov',
#  'Eric Nunez',
#  'Vishal Punna',
#  'Jun Chao Xu',
#  'Guillermo Olaso',
#  'Christian Garay',
#  'David Luque Velasco',
#  'Karim Mohamed Maamoun',
#  'Alex Bolt',
#  'Vijayant Malik',
#  'Todor Enev',
#  'Fitriadi M Rifqi',
#  'Simen Sunde Bratholm',
#  'Karim Maamoun',
#  'Patrik Niklas Salminen',
#  'Ayed Zatar',
#  'Sunil Kumar',
#  'Wishaya Trongcharoenchaikul',
#  'Lorenzo Giustino',
#  'Juho Paukku',
#  'Diego Hidalgo',
#  'Mitchell Krueger',
#  'Maxime Hamou',
#  'Seung Bok Baek',
#  'Evghenii Plugariov',
#  'Agustin Velotti',
#  'Adam Jaya',
#  'Alexey Vatutin',
#  'Romain Arneodo',
#  'Amaury Gomez',
#  'Marat Deviatiarov',
#  'Wen Lung Chang',
#  'Abdulhamid Mubarak',
#  'Alexander Shvec',
#  'Christopher Lawson',
#  'Andres Pedroso',
#  'Francis Casey Alcantara',
#  'Danylo Kalenichenko',
#  'Zachary Svajda',
#  'Dannio Yahya',
#  'Tom Kocevar Desman',
#  'Ya Nan Ma',
#  'Antoine Hoang',
#  'Jing Zhu Yang',
#  'Dragos Dima',
#  'Moez Echargui',
#  'Igor Chaldounov',
#  'Adrian Andreev',
#  'Maxime Koffi',
#  'Andis Juska',
#  'Marvin Moeller',
#  'Jorge Catala',
#  'Illia Biloborodko',
#  'Damion Johnson',
#  'Mohammed Al Nabhani',
#  'Sebastian Moreno',
#  'Jean Andersen',
#  'Dmitry Popko',
#  'Iphton Louis',
#  'Arthur De Greef',
#  'Henry So',
#  'Alvaro Raposo De Oliveira',
#  'Julian Saborio',
#  'Wing Luen Wong',
#  'Michael Mmoh',
#  'Radovan Svetlik',
#  'Daniel Cukierman',
#  'Christian Sigsgaard',
#  'Nour Nehme',
#  'Krystian Pfeiffer',
#  'Petros Baghdatis',
#  'Michael Lai',
#  'George Khrikadze',
#  'Razlan Rawi',
#  'Bostjan Osabnik',
#  'Augusto Sanabria',
#  'Yshai Oliel',
#  'Anthony Susanto',
#  'Anton Tsymbalov',
#  'Bertrand Madsen',
#  'Giorgi Javakhishvili',
#  'Soren Wedege',
#  'Pavel Katliarov',
#  'Duilio Beretta',
#  'Jorge Tejada',
#  'Lucas Catarina',
#  'Andres Artunedo Martinavarro',
#  'Christian Saravia',
#  'Markos Kalovelonis',
#  'Roman Margoulis',
#  'Pablo Bianchi',
#  'Nicolas Mejia',
#  'Ari Fahresi',
#  'Johnny Arcilla',
#  'Martins Podzus',
#  'Aqeel Khan',
#  'Dac Tien Nguyen',
#  'Tomislav Peric',
#  'Hicham Khaddari',
#  'Ronaldo Carvalho',
#  'Yordan Kanev',
#  'Sunu Wahyu Trijati',
#  'Alberto Emmanuel Alvarado Larin',
#  'Mads Gottlieb',
#  'Gwinyai Chingoka',
#  'Amir Hossein Badi',
#  'Christopher Koutrouzas',
#  'F Egyir',
#  'Ian Flanagan',
#  'Mikhail Filima',
#  'Goran Tosic',
#  'Joao Pedro Sorgi',
#  'Walid Jallali',
#  'Muzammil Murtaza',
#  'Kenneth Tuilier Curco',
#  'Maxime Teixeira',
#  'Yasitha De Silva',
#  'Guillermo Hormazabal',
#  'Todd Widom',
#  'Gabriel Donev',
#  'Jc Aragone',
#  'John Hui',
#  'Andres Bucaro',
#  'Patrik Langvardt',
#  'Asim Shafik',
#  'Javier Marti',
#  'Young Jun Kim',
#  'Martin Stiegwardt',
#  'Augustin Gensse',
#  'Marcelo Demoliner',
#  'Zach Dailey',
#  'Charles Irie',
#  'Elbert Sie',
#  'Dimitar Grabuloski',
#  'Juan Carlos Saez',
#  'Hyun Joon Kim',
#  'Roman Hassanov',
#  'Daniel Michalski',
#  'Dovydas Sakinis',
#  'Sergey Betov',
#  'Sergei Yaroshenko',
#  'Spencer Newman',
#  'Pak Long Yeung',
#  'Pedro Braga',
#  'Sanjar Fayziev',
#  'Slimane Saoudi',
#  'Nicolae Frunza',
#  'Pedro Cachin',
#  'Noah Rubin',
#  'Mubarak Al Tobaishi',
#  'Abdulla Hajji',
#  'Joris De Loore',
#  'Kristijan Mesaros',
#  'Yong Kyu Lim',
#  'Luis Perez Chete',
#  'Matthew Foster Estwick',
#  'Seong Chan Hong',
#  'Samir Saadeldin',
#  'Jack Mingjie Lin',
#  'Mehdi Jdi',
#  'Artem Smirnov',
#  'Isak Arvidsson',
#  'Sherif Sabry',
#  'Jonathan Chu',
#  'Revaz Osadze',
#  'Russell Moseley',
#  'Rudolf Molleker',
#  'Emin Agaev',
#  'Dawood Sayed Hashim',
#  'Mauricio Doria Medina',
#  'Jhonson Garcia',
#  'Jurij Rodionov',
#  'Dario Acosta',
#  'Zoran Sevcenko',
#  'Radoslav Lukaev',
#  'Patrick Osnua',
#  'Selvam Veerasingam',
#  'Dennis Lajola',
#  'Nicholas Sayer',
#  'Bjorn Munroe',
#  'Adrien Bossel',
#  'William Kirkman',
#  'Adam Kennedy',
#  'Rasid Winklaar',
#  'Roman Safiullin',
#  'Matt Reid',
#  'Valentin Rahmine',
#  'Stefano Ianni',
#  'Thierno Ly',
#  'Rok Jarc',
#  'Nejc Podkrajsek',
#  'Jamal Darmadi',
#  'Sacha Thoma',
#  'Jacobo Chavez',
#  'George Tsivadze',
#  'Hendri Susilo Pramono',
#  'Federico Gaio',
#  'Nutthanon Kadchapanan',
#  'Francisco Cerundolo',
#  'Daniel Munoz de la Nava',
#  'Yew Ming Si',
#  'Edward Corrie',
#  'Syed Mohd Agil Syed Naguib',
#  'Andrea Basso',
#  'William Ward',
#  'Guillermo Carter',
#  'Minhtuan Pham',
#  'Rodrigo Senattore',
#  'Max Purcell',
#  'Xavier Lawrence',
#  'Ainius Sabaliauskas',
#  'Mark Chigaazira',
#  'Ilija Martinoski',
#  'Takahiro Terachi',
#  'Jacob Adaktusson',
#  'Nodar Itonishvili',
#  'Nigel Badza',
#  'Zoltan Boroczky',
#  'Sergis Kyratzis',
#  'Photos Kallias',
#  'Tom Spinks',
#  'Stephen Nugent',
#  'Nick Van Der Meer',
#  'Gabriel Flores Ruiz',
#  'Oskar Saarne',
#  'Kristian Mitrovski',
#  'Dong Hyun Kim',
#  'Alexander Vasquez',
#  'Gunther Darkey',
#  'John Morrissey',
#  'Henry Estrella',
#  'Cesar Escobar Serrano',
#  'Youssef Hossam',
#  'Alberto Brizzi',
#  'Patrick Ciorcila',
#  'Federico Rodriguez',
#  'Alex Witt',
#  'Sergei Petrouchevsky',
#  'Vladimir Ivanov',
#  'Diego Galeano',
#  'Siu Fai Kelvin Lam',
#  'Deniss Pavlovs',
#  'Owen Casey',
#  'Slim Hamza',
#  'Jean Kome Loglo',
#  'Chase Buchanan',
#  'Nikola Gnjatovic',
#  'Constantinos Ioannides',
#  'Tomislav Ternar',
#  'Kirill Ivanov Smolensky',
#  'Davit Babayan',
#  'Abd Hazli Bin Zainuddin',
#  'Ali Ismaeel',
#  'Aditya Hari Sasongko',
#  'Steven Diez',
#  'Pablo Nunez',
#  'Aziz Avganov',
#  'Guido Andreozzi',
#  'Tim Goransson',
#  'Stanislav Bykov',
#  'Jose De Armas',
#  'Emmanuel Heussner',
#  'Alejandro Gonzalez',
#  'Rudolfs Mednis',
#  'David Agung Susanto',
#  'Jenson Brooksby',
#  'Philippe Moggio',
#  'Thiago Seyboth Wild',
#  'Juan Carlos Gonzalez',
#  'Nils Langer',
#  'Renouk Wijemanne',
#  'Filip Veger',
#  'Sandor Martinez Breijo',
#  'Javier Garcia Sintes',
#  'Chun Hsin Tseng',
#  'Jocelyn Robichaud',
#  'Lee Childs',
#  'Mauricio Estivariz',
#  'Rhyne Williams',
#  'Prima Simpatiaji',
#  'M Abid Ali Khan Akbar',
#  'Alexander Blom',
#  'Mahmoud Nader Al Baloushi',
#  'Vimuktha De Alwis',
#  'Goran Sterijovski',
#  'Ernesto Escobedo',
#  'Kevin Kung',
#  'Yassir Kilani',
#  'Ahmad Rabeea Muhammad',
#  'Matt Klinger',
#  'Chieh Fu Wang',
#  'Jaroslav Pospisil',
#  'Talal Ouahabi',
#  'Yannick Mertens',
#  'Gianluca Naso',
#  'Luis Diaz Barriga',
#  'Ruan Roelofse',
#  'Lays Salim',
#  'Wilfredo Gonzalez',
#  'Min Hyoek Cho',
#  'Tilen Zitnik',
#  'Gonzales Austin',
#  'Pascal Schaul',
#  'Tigran Martirosyan',
#  'Tung Lin Wu',
#  'Alexandre Muller',
#  'Mounir El Aarej',
#  'Gustavo Ramirez',
#  'Christopher Eubanks',
#  'Carlos Palencia',
#  'Tomas Vaise',
#  'Karlis Lejnieks',
#  'Augusto Ricciardi Castelli',
#  'Bassam Beidas',
#  'Marcelo Barboza',
#  'Rihards Emulins',
#  'Simon Shen',
#  'Hyun Woo Nam',
#  'Kyle Johnson',
#  'Botic Van De Zandschulp',
#  'Jose Zunino',
#  'Matthew Breen',
#  'Balazs Veress',
#  'Jan Weinzierl',
#  'Marius Tangen',
#  'Benjamin Lock',
#  'Jean Segodo',
#  'Ognian Kolev',
#  'Jonathan Printzlau',
#  'Rayane Roumane',
#  'Henrik Andersson',
#  'Niko Karagiannis',
#  'Chun Hun Wong',
#  'Mate Valkusz',
#  'Clement Morel',
#  'Ayrton Wibowo',
#  'Timothy Neilly',
#  'Wahib Maknieh',
#  'N Sriram Balaji',
#  'Abdullah Maqdas',
#  'Jui Chen Hung',
#  'Ante Pavic',
#  'Rafael Avalos Brenes',
#  'Juan Francisco Barragan',
#  'Jakub Herm Zahlava',
#  'Sebastian Dominguez',
#  'Julius Tverijonas',
#  'Mariano Sanchez',
#  'Adolfo Daniel Vallejo',
#  'Patricio Arquez',
#  'Radoslaw Nijaki',
#  'Courtney John Lock',
#  'Jonathan Mridha',
#  'Peter Handoyo',
#  'Markus Kerner',
#  'Doug Bohaboy',
#  'Adrians Zguns',
#  'Mantas Bugailiskis',
#  'Daniel Willman',
#  'Adam Moundir',
#  'Rene Busch',
#  'Sam Barry',
#  'Chris Brandi',
#  'Jicham Zaatini',
#  'Syed Nasir Sherazi',
#  'Mikael Torpegaard',
#  'Arjun Kadhe',
#  'Pablo Galdon',
#  'Andrei Daescu',
#  'Warit Sornbutnark',
#  'Edgar Hernandez Perez',
#  'Linh Giang Trinh',
#  'Vadim Davletshin',
#  'Rodrigo Vallejo',
#  'Jad Ayoub',
#  'Ekkarin Pisuth Arnonth',
#  'Hao Lu',
#  'Chu Huan Yi',
#  'Omar Awadhy',
#  'Goudjo Gbedey',
#  'Robin Kern',
#  'David Vega Hernandez',
#  'Erhan Oral',
#  'Helge Koll Frafjord',
#  'Oscar Otte',
#  'Shahab Hassani Nafez',
#  'Christopher Diaz Figueroa',
#  'Kwasi Ahenkora',
#  'Rogelio Siller',
#  'Gabor Jaross',
#  'Rares Cuzdriorean',
#  'Jaan Kononov',
#  'Serguei Tarasevitch',
#  'Claudio Dias Conduto',
#  'Martin Vaisse',
#  'Roberto Cid',
#  'Gert Vilms',
#  'Luis Manuel Flores',
#  'Eleftherios Christou',
#  'Alessandro Bega',
#  'Michael Ray Pallares Gonzalez',
#  'Luke Saville',
#  'Ji Sung Nam',
#  'Andrej Kracman',
#  'Gustavo Marcaccio',
#  'Julen Uriguen',
#  'Nicolas Xiviller',
#  'Ben Qiang Zhu',
#  'Evgeny Karlovskiy',
#  'Baris Ergun',
#  'Xin Yuan Yu',
#  'Leonardo Ramirez',
#  'Carlos Drada',
#  'Austin Krajicek',
#  'Lefteris Alexiou',
#  'Cheng Yu Yu',
#  'Akira Santillan',
#  'Irakli Ushangishvili',
#  'Collin Altamirano',
#  'Pedro Sakamoto',
#  'Brett Baudinet',
#  'Lavaughn Munroe',
#  'Raimonds Sproga',
#  'Jhonnatan Medina Alvarez',
#  'Tunde Segodo',
#  'Ramin Raziyani',
#  'Ali Hamadeh',
#  'Israel Morales',
#  'Thomas Drouet',
#  'Bastian Trinker',
#  'Juan Lugo',
#  'Blake Mott',
#  'Adelo Abadia',
#  'Jose Antonio Sanchez De Luna',
#  'Hillel Rousseau',
#  'Mubarak Shannan Zayid',
#  'Lazaro Navarro Batles',
#  'Elmar Gerth',
#  'David Josepa',
#  'Daniel Llarenas',
#  'Phillip Harboe',
#  'Mohammad Ghareeb',
#  'Shahzad Khan',
#  'Andre Gaspar Murta',
#  'Minh Quan Do',
#  'Kasparas Zemaitelis',
#  'Michel Saade',
#  'Olivier Sajous',
#  'Enzo Pigola',
#  'Clay Thompson',
#  'Francisco Yim Kim',
#  'Dzmitry Zhyrmont',
#  'Sebo Kiss',
#  'Daniel Glancy',
#  'Juan Ignacio Londero',
#  'Israel Matos Gil',
#  'Eric Quigley',
#  'Philip Riise Hansen',
#  'Adam Kellner',
#  'Hassan Al Mousa',
#  'Khalid Al Nabhani',
#  'Enrique Lopez Perez',
#  'David Souto',
#  'Ivor Grazette',
#  'George Kallis',
#  'Alex Fairbanks',
#  'Milen Velev',
#  'Gabriel Pitta',
#  'Bob Borella',
#  'Kuan Yi Lee',
#  'Francesco Piccari',
#  'Yusuke Takahashi',
#  'Alex Knaff',
#  'Miguel Angel Este',
#  'Mohamed Wafa',
#  'Adrian Forberg Skogeng',
#  'Christopher Eldon',
#  'Erling Tveit',
#  'Andrei Ciumac',
#  'Takanyi Garanganga',
#  'Andres Weisskopf',
#  'Iurie Gorban',
#  'Alexandre Sidorenko',
#  'Valentin Sanon',
#  'Wei Jen Cheng',
#  'Tadas Babelis',
#  'Hady Habib',
#  'Rohan De Silva',
#  'Dominic Pagon',
#  'Philip Davydenko',
#  'Andrei Luzgin',
#  'Y Wang',
#  'Paul Jubb',
#  'Zibusiso Ncube',
#  'Patrick Boza',
#  'Federico Coria',
#  'Daniel Chavez Morales',
#  'Henrik Sillanpaa',
#  'Demetrios Leontis',
#  'Abdelhak Hameurlaine',
#  'Predrag Rusevski',
#  'Alessandro Camarco',
#  'Bryan Juinio',
#  'Alastair Gray',
#  'Marek Marksoo',
#  'Ayoub Chakrouni',
#  'Martin Rmus',
#  'Vladyslav Manafov',
#  'Melvin Tong',
#  'Laurent Lokoli',
#  'Andrei Karatchenia',
#  'Jonas Forejtek',
#  'Facundo Arguello',
#  'Lucas Miedler',
#  'Soteris Hadjistyllis',
#  'Mehdi Ziadi',
#  'John Doran',
#  'Bartlomiej Dabrowski',
#  'Marcus Willis',
#  'Mohammed Fawzy',
#  'Jason Engelhardt',
#  'Loic Didavi',
#  'Naser Al Obaidly',
#  'Tihomir Grozdanov',
#  'Robin Roshardt',
#  'Philip Wilbert Major',
#  'Sergio Gutierrez Ferrol',
#  'Alexios Halebian',
#  'Oliver Anderson',
#  'Frederick Sletting Johnsen',
#  'Kenneth Raisma',
#  'Mykyta Mashtakov',
#  'Diego Cubas',
#  'Victor Baluda',
#  'Pierre Ludovic Duclos',
#  'Robert Yim',
#  'Romano Tatuhey',
#  'Mousa Shanan Zayed',
#  'Maximilian Abel',
#  'Andrea Arnaboldi',
#  'Hiu Tung Yu',
#  'Shendrit Deari',
#  'Sarvar Ikramov',
#  'Patricio Alvarado',
#  'Jayendra Wijeyesekera',
#  'Wisnu Adi Nugroho',
#  'Haithem Abid',
#  'Austen Childs',
#  'Nikos Rovas',
#  'Daniel Altmaier',
#  'Kerlin Leon Zamora',
#  'Gian Marco Moroni',
#  'Khumoun Sultanov',
#  'Dennis Peschek',
#  'Lucas Andriamasilalao',
#  'Andres Filimonov',
#  'Manuel Tejada',
#  'Henry Adjei Darko',
#  'Juan Pablo Varillas',
#  'Mohd Assri Merzuki',
#  'Navdeep Singh',
#  'Ivan Nedelko',
#  'Ismar Gorcic',
#  'Marcin Gawron',
#  'Tomislav Jotovski',
#  'Yanquiel Medina Sobrino',
#  'Christophe Pognon',
#  'Sergio Ramirez',
#  'Rodrigo Rappaccioli',
#  'Borna Gojo',
#  'Darko Bojanovic',
#  'Wael Zeidan',
#  'Carl Soderlund',
#  'Jordi Munoz Abreu',
#  'Vaja Uzakov',
#  'Filip Horansky',
#  'Adrian Menendez Maceiras',
#  'Diego Camacho',
#  'Ilia Kushev',
#  'Yassine Idmbarek',
#  'Milos Sekulic',
#  'Eldad Campbell',
#  'Helge Rosjo',
#  'Samir Iftikhar',
#  'Igor Kornienko',
#  'Eduardo Struvay',
#  'Mariano Albert Ferrando',
#  'Kamil Majchrzak',
#  'Matteo Marrai',
#  'Dmitri Tomashevich',
#  'Gino Meeuwsen',
#  'Brandon Perez',
#  'Ryan Shane',
#  'Genius Chidzikwe',
#  'Pruchya Isarow',
#  'Mazen Osama',
#  'Lazar Magdincev',
#  'Federico Camacho',
#  'Simon Rea',
#  'Evgenii Tiurnev',
#  'Yosuke Watanuki',
#  'Jorge Brian Panta Herreros',
#  'Issam Al Tawil',
#  'Colin Ebelthite',
#  'Kirati Siributwong',
#  'Peter Torebko',
#  'Martin Sayer',
#  'Guillem Burniol',
#  'Leonardo Olguin',
#  'Seanon Williams',
#  'Anoosha Shahgholi',
#  'Dilshod Sharifi',
#  'Giovani Samaha',
#  'Will Farah Lebar',
#  'Hee Sung Chung',
#  'Ryan Russell',
#  'Franz Luna Lavidalie',
#  'Kasidit Samrej',
#  'Karim Alayli',
#  'Mik Ledvonova',
#  'Andrew Whittington',
#  'Gianluigi Quinzi',
#  'Adrian Bodmer',
#  'Fredrik Aarum',
#  'Janis Skroderis',
#  'John Bryan Decasa Otico',
#  'Tallon Griekspoor',
#  'Mehluli Don Ayanda Sibanda',
#  'Rob Steckley',
#  'Roman Recarte',
#  'Luis Haddock',
#  'Troy Stone',
#  'Alexander Skrypko',
#  'Fadi Youssef',
#  'Laurent Hild',
#  'Jonas Froberg',
#  'Tim Van Rijthoven',
#  'Luis Diego Nunez',
#  'Peit Hein Boekel',
#  'Hans Hach Verdugo',
#  'Scott Willinsky',
#  'Kento Takeuchi',
#  'Juan Borba',
#  'Lawal Shehu',
#  'Thien Nguyen Hoang',
#  'Vasuthevan Ortchuan',
#  'Abdulhameed Alshatti',
#  'Emilio Nava',
#  'Thomas Fabbiano',
#  'Yari Bernardo',
#  'Aivaras Balzekas',
#  'Andrey Stepanov',
#  'Sebastian Arcila',
#  'Toni Androic',
#  'Andres Molteni',
#  'Liang Chi Huang',
#  'Tetsuya Chaen',
#  'Peter Nagy',
#  'Sekou Bangoura',
#  'Mats Moraing',
#  'Inam Gul',
#  'Nam Hoang Ly',
#  'Filip Cristian Jianu',
#  'Luis Delgado',
#  'Ignacio Garcia',
#  'Mohammed Rajan Sundera Karuppiah',
#  'Constant Lestienne',
#  'Xin Gao',
#  'Alexis Klegou',
#  'Robert Collins',
#  'Seung Hoon Lee',
#  'Bjorn Fratangelo',
#  'Mathias Hellstrom',
#  'Magloire Yakpa',
#  'Yibing Wu',
#  'Benito Jose Suriano',
#  'Daniel Isaza',
#  'Dekel Valtzer',
#  'Hee Seok Chung',
#  'Chak Lam Coleman Wong',
#  'Diogo Rocha',
#  'Muhammad Khaliq Siddiq',
#  'Jose Baires',
#  'Shahin Khaledan',
#  'Jasper Smit',
#  'Jurabek Karimov',
#  'Julio Cesar Campozano',
#  'Anis Ghorbel',
#  'Hideki Kaneko',
#  'Ruben Gonzales',
#  'Sulaiman Al Rawahi',
#  'Dias Doskarayev',
#  'Ricardo Chile Fonte',
#  'Jan Choinski',
#  'Alexander Merino',
#  'Brandon Burke',
#  'Aleksandar Vukic',
#  'James Auckland',
#  'Joan Jimenez Guerra',
#  'Jean Marc Bazanne',
#  'Mikal Oliver Statham',
#  'Jason Sankey',
#  'George Chantouria',
#  'Lukas Mugevicius',
#  'Peerakiat Siriluethaiwattana',
#  'Tapio Nurminen',
#  'Adrian Cruciat',
#  'Santiago Maresca',
#  'Rolando Ruel',
#  'Jonathan Dasnieres De Veigy',
#  'Mohsen Hossein Zade',
#  'Levar Harper Griffith',
#  'Andrew Carlson',
#  'Dimitar Kutrovsky',
#  'Edris Fetisleam',
#  'Tucker Vorster',
#  'Marco Aurelio Nunez',
#  'Holger Rune',
#  'Abdul Mumin Babalola',
#  'Erik Chvojka',
#  'Yuichi Ito',
#  'Sebastian Fitz',
#  'Nomi Qamar',
#  'Dusan Lojda',
#  'Tiago Godinho',
#  'Daniel Garza',
#  'Oskars Vaskis',
#  'Ivan Endara',
#  'Mohammed Reza Tavakoli',
#  'Prajnesh Gunneswaran',
#  'Mohammed Abdulla',
#  'Arthur Konan',
#  'Bruno Agostinelli',
#  'Takahiro Ittogi',
#  'Daniel Smethurst',
#  'Victor Bruthans',
#  'Darius Florin Bragusi',
#  'Ariez Elyaas Deen Heshaam',
#  'Bruno Rosa',
#  'Konstantinos Mikos',
#  'Srinath Prahlad',
#  'Philippe Grandjean',
#  'Sebastien Vidal',
#  'Suk Young Jeong',
#  'Dinko Halachev',
#  'Dimitri Mazur',
#  'Mohammed Faizal Bin Othman',
#  'Salifu Mohammed',
#  'Dmitrii Baskov',
#  'Zsombor Piros',
#  'Kornel Bardoczky',
#  'Laurent Bram',
#  'Adam Thompson',
#  'Aljaz Radinski',
#  'Yaraslav Shyla',
#  'Irakli Metreveli',
#  'Jose Bernard',
#  'Chia Yen Tsai',
#  'Roberto Ortega Olmedo',
#  'Fred Simonsson',
#  'Carlos Taberner',
#  'Gerardo Lopez Villasenor',
#  'Nicolaas Scholtz',
#  'Dennis Novikov',
#  'Liam Broady',
#  'Puriwat Chatpatcharoen',
#  'Slah Mbarek',
#  'Juan Carlos Rebaza Lozano',
#  'Ali Ghareeb',
#  'Dino Marcan',
#  'Raymond Sarmiento',
#  'Janne Ojala',
#  'Jean Nabi',
#  'Nathan Pasha',
#  'Gabor Borsos',
#  'Philippe Lacombe',
#  'Christos Hadjigeorgiou',
#  'Iztok Bozic',
#  'Michal Gawlowski',
#  'Hyun Joon Suk',
#  'Stefano Napolitano',
#  'Scott Barron',
#  'Stefan Kozlov',
#  'Gerard Granollers',
#  'Jae Min Seol',
#  'Ruben Torres',
#  'Pedro Martinez',
#  'Nemanja Kontic',
#  'Gwinyai Tongoona',
#  'Luka Gregorc',
#  'Riccardo Bellotti',
#  'Ivan Vajda',
#  'Nerman Fatic',
#  'Nikola Cacic',
#  'Sultan Khalfan',
#  'Jirat Navasirisomboon',
#  'Juan Sebastian Langton',
#  'Antal Van Der Duim',
#  'Tiago Sousa',
#  'Calvin Hemery',
#  'Matthew Behrmann',
#  'Frederico Ferreira Silva',
#  'Marc Fornell Mestres',
#  'Shan Jiang',
#  'Rhett Purcell',
#  'Alejandro Olivera',
#  'Ben Patael',
#  'Kasper Warming',
#  'Tom Diederich',
#  'Jean Michel Durango',
#  'Michihisa Onoda',
#  'Luis David Martinez',
#  'Bruno Fragoso',
#  'Martin Slanar',
#  'Simon Carr',
#  'Vladimir Pavicevic',
#  'Goran Bosalevski',
#  'Oh Hee Kwon',
#  'Jay Clarke',
#  'Nasser Ghanim Al Khulaifi',
#  'Tzvetan Mihov',
#  'Michel Koning',
#  'Anas Fattar',
#  'Piotr Szczepanik',
#  'Emilio Gomez',
#  'Dentry Mortimer',
#  'Igor Levine',
#  'Hong Chung',
#  'Ouassel Hared',
#  'Benjamin Hannestad',
#  'Sumit Nagal',
#  'Daniel Langre',
#  'Si Bruce Li',
#  'Mariusz Zielinski',
#  'Nicolas Meister',
#  'Quentin Halys',
#  'Matteo Viola',
#  'Maxim Bulat',
#  'James Shortall',
#  'Florian Allgauer',
#  'Miguel Gallardo Valles',
#  'Christoffer Konigsfeldt',
#  'Liam Caruana',
#  'Mohammed Noor Noordin',
#  'Julien Cagnina',
#  'Ashkan Shokoofi',
#  'Maximilian Marterer',
#  'Jae Sung An',
#  'Esat Tanik',
#  'Juan Lorenzo Gonzalez',
#  'Alberto Brause',
#  'Gvidas Sabeckis',
#  'Oscar Posada',
#  'Pau Gerbaud Farras',
#  'Lars Uebel',
#  'Jing Yi Li',
#  'Daniel Kosakowski',
#  'Alex Llompart',
#  'Vitaliy Pavlov',
#  'Alexander Tavkhelidze',
#  'Matteo Donati',
#  'Temur Ismailov',
#  'Ricardo Rodriguez',
#  'Ivo Lagzdins',
#  'Blazej Koniusz',
#  'Jose Olivares',
#  'Jose Perdomo',
#  'Maxime Janvier',
#  'Tim Puetz',
#  'Rafa Orantes',
#  'Sergei Samoseiko',
#  'Dineshkanthan Thangarajah',
#  'Tyler Chin',
#  'Matthew Prentice',
#  'Yohny Romero',
#  'Louis Wessels',
#  'Sascha Kloer',
#  'Syrym Abdukhalikov',
#  'Nicholas Campbell',
#  'Bogdan Borza',
#  'Davin Russell',
#  'Mauricio Echazu',
#  'Paulo Carvallo',
#  'Rabi Bouhassoun',
#  'Hugo Gaston',
#  'Andrey Kumantsov',
#  'Thai Son Kwiatkowski',
#  'Juan Luis Tati Rascon',
#  'Nik Razborsek',
#  'Stefan Wauters',
#  'Cheuk Wai Hui',
#  'Febi Widhiyanto',
#  'Marco Osorio',
#  'Roberto Maytin',
#  'Lars Poerschke',
#  'Soren Hess Olesen',
#  'Kalle Flygt',
#  'Marwan Zewar',
#  'Raoul Behr',
#  'Ervin Eleskovic',
#  'Federico Zeballos',
#  'Walter Trusendi',
#  'Leroy Tujeehut',
#  'David Szintai',
#  'Sebastian Rieschick',
#  'Andrian Raturandang',
#  'Matias Boeker',
#  'Gabriel Montilla',
#  'Eero Vasa',
#  'Guillaume Couillard',
#  'Miljan Zekic',
#  'Eddy Chala',
#  'Martin Cuevas',
#  'Colin Obrien',
#  'Marc Andrea Huesler',
#  'Cristian Paiz',
#  'Shane Stone',
#  'Austin Smith',
#  'Jabor Al Mutawa',
#  'Ricardo Ojeda Lara',
#  'Sergio Galdos',
#  'Nicola Kuhn',
#  'Jason Kubler',
#  'Sid Ali Akkal',
#  'Alexandru Andronachi',
#  'Clement Reix',
#  'Aleksandre Metreveli',
#  'Elvis Henry',
#  'Filippo Baldi',
#  'Hiroki Kondo',
#  'Damian Patriarca',
#  'Mike Vermeer',
#  'Romain Bogaerts',
#  'Dejan Petrovic',
#  'Joachim Bjerke',
#  'Mario Monroy',
#  'Hyeong Keun Song',
#  'Viktor Galovic',
#  'Fritz Wolmarans',
#  'Andrei Gorban',
#  'Victor Romero',
#  'Mohammed Nazreen Fuzi Nasruddin',
#  'Alibek Kachmazov',
#  'Kevin King',
#  'Jad Ballout',
#  ...]

# %% [markdown]
# #### Thanks atptour.com!
# * Maximilian Marterer 188 cm
# * Bjorn Fratangelo 183 cm

# %%
max_mar_idx = df[df.player_1 == 'Maximilian Marterer'].index
max_mar_idx2 = df[df.player_2 == 'Maximilian Marterer'].index
df.loc[max_mar_idx, 'player_1_ht'] = 188
df.loc[max_mar_idx2, 'player_2_ht'] = 188

bjorn_frat_idx = df[df.player_1 == 'Bjorn Fratangelo'].index
bjorn_frat_idx2 = df[df.player_2 == 'Bjorn Fratangelo'].index
df.loc[bjorn_frat_idx, 'player_1_ht'] = 183
df.loc[bjorn_frat_idx2, 'player_2_ht'] = 183

# %%
from proper_prep import *

# %%
df = prepare_atp()
df.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-4507b05ce1da> in <module>
#       1 df = prepare_atp()
# ----> 2 df.info()
#
# AttributeError: 'NoneType' object has no attribute 'info'

# %%
calculate_column_nulls(df)

# %%
import numpy as np
import pandas as pd


def prepare_atp():

    # read .csv into a dataframe
    df = pd.read_csv('ATPMain.csv', index_col = 0)
    print(f'0 |{len(df)}')                                                         # LOOK HERE MASON
    # sort your life out, m8
    df = df.sort_values(by = ['tourney_date', 'tourney_id', 'match_num'])
    df = df.reset_index().drop(columns = 'index')

    # make tourney date a datetime object
    df.tourney_date = pd.to_datetime(df.tourney_date, format = '%Y%m%d')

    # set dataframe to years 1999-2019 (21 years of recent data minus corona years)
    df = df[(df.tourney_date > '1998-12-31') & (df.tourney_date < '2020-01-01')]
    df = df.reset_index().drop(columns = 'index')

    # drop all walkovers (no useful stats) and best of 1 matches (extremely rare format)
    df = df.drop(df[df.score == 'W/O'].index)
    df = df.drop(df[df.best_of == 1].index)

    df = df.reset_index().drop(columns = 'index')
    
    # drop player entry columns, verify
    df = df.drop(columns = ['player_1_entry', 'player_2_entry'])

    # drop janky records
    df = df[df['player_1_first_serve_%'].notnull()]
    df = df[df['player_2_first_serve_%'].notnull()]
    df = df[df['player_1_first_serve_win_%'].notnull()]
    df = df[df['player_2_first_serve_win_%'].notnull()]

    # assign variable to list of tourney ids that have missing minutes
    missing_minutes = list(df[df.minutes.isnull()].tourney_id.unique())
    # commence loop through list of tournaments with missing match lengths
    for tourney in missing_minutes:
        # assign mean match length for tournament to variable
        mean_match_length = df[df.tourney_id == tourney].minutes.mean()
        # locate index where there are mml for the tournament, fill values with average match length
        df.loc[df[df.tourney_id == tourney].minutes.isnull().index, 'minutes'] = mean_match_length

    ## generate subsets for data and group by match format and surface type
    # best of 3
    best_of_3_hard = df[(df.best_of == 3) & (df.surface == 'Hard')]
    best_of_3_clay = df[(df.best_of == 3) & (df.surface == 'Clay')]
    best_of_3_grass = df[(df.best_of == 3) & (df.surface == 'Grass')]
    best_of_3_carpet = df[(df.best_of == 3) & (df.surface == 'Carpet')]
    # best of 5
    best_of_5_hard = df[(df.best_of == 5) & (df.surface == 'Hard')]
    best_of_5_clay = df[(df.best_of == 5) & (df.surface == 'Clay')]
    best_of_5_grass = df[(df.best_of == 5) & (df.surface == 'Grass')]
    best_of_5_carpet = df[(df.best_of == 5) & (df.surface == 'Carpet')]

    # list subsets for a good ole fashion loop
    subsets = [
        best_of_3_hard,
        best_of_3_clay,
        best_of_3_grass,
        best_of_3_carpet,
        best_of_5_hard,
        best_of_5_clay,
        best_of_5_grass,
        best_of_5_carpet
    ]

    # loop through subsets
    for subset in subsets:
        # generate average match time length
        mean_match_length = subset.minutes.mean()
        # locate indexes where there are mtls
        ss_idx = subset[subset.minutes.isnull()].index
        # fill missing minutes
        df.loc[ss_idx, 'minutes'] = mean_match_length

    # gather all players in two sets
    players = set(list(df.player_1.unique()))
    players2 = set(list(df.player_2.unique()))

    # combine, drop duplicates, convert set to list type and sort for fun 
    players = players.union(players2)
    players = list(players)
    players.sort()

    # set an empty list to fill
    less_than_50 = []

    # use a for-loop to run through the list of players
    for player in players:
        # set up if-conditional to see if the length of records where a player shows up in the dataframe is less than 50
        if len(df[(df.player_1 == player) | (df.player_2 == player)]) < 50:
            # if there are less than 50 records, add the player's name to the list
            less_than_50.append(player)
    # sort list
    less_than_50.sort()

    # run through loop of list of players with less than 50 matches
    for player in less_than_50:
        # set dataframe to records where these players are not present
        df = df[df.player_1 != player]
        df = df[df.player_2 != player]

    # love resets
    df = df.reset_index().drop(columns = 'index')

    # assign variable to index
    jd_p1_index = list(df[df.player_1 == 'Jared Donaldson'].index)
    # review index where Jared is player 2, assign to variable
    jd_p2_index = df[df.player_2 == 'Jared Donaldson'].index
    # fill all his heights with 188 cm
    df.loc[jd_p1_index, 'player_1_ht'] = 188
    # fill all his heights with 188
    df.loc[jd_p2_index, 'player_2_ht'] = 188

    # assign variable to index where AG is ready player1
    ag_p1_index = df[df.player_1 == 'Alejandro Gonzalez'].index
    # fill his heights 191
    df.loc[ag_p1_index, 'player_1_ht'] = 191
    # assign variable to indexes where AG is player2
    ag_p2_index = df[df.player_2 == 'Alejandro Gonzalez'].index
    # fill his heights 191
    df.loc[ag_p2_index, 'player_2_ht'] = 191

    # assign variables to indexes where Thomas is player 1 or player 2
    tf_p1_index = df[df.player_1 == 'Thomas Fabbiano'].index
    tf_p2_index = df[df.player_2 == 'Thomas Fabbiano'].index
    # fill his heights with 173 cm
    df.loc[tf_p1_index, 'player_1_ht'] = 173
    df.loc[tf_p2_index, 'player_2_ht'] = 173

    # if you kill it, fill it
    max_mar_idx = df[df.player_1 == 'Maximilian Marterer'].index
    max_mar_idx2 = df[df.player_2 == 'Maximilian Marterer'].index
    df.loc[max_mar_idx, 'player_1_ht'] = 188
    df.loc[max_mar_idx2, 'player_2_ht'] = 188
    print(f'1 |{len(df)}')                                                         # LOOK HERE MASON
    bjorn_frat_idx = df[df.player_1 == 'Bjorn Fratangelo'].index
    bjorn_frat_idx2 = df[df.player_2 == 'Bjorn Fratangelo'].index
    df.loc[bjorn_frat_idx, 'player_1_ht'] = 183
    df.loc[bjorn_frat_idx2, 'player_2_ht'] = 183

    # fill rank points with 0, brand new players on the tour
    jg_rnull_idx = df[(df.player_1 == 'Justin Gimelstob') & (df.player_1_rank_points.isnull())].index
    df.loc[jg_rnull_idx, 'player_1_rank_points'] = 0
    jj_1rnull_idx = df[df.player_1 == 'Joachim Johansson'].index[0]
    df.loc[jj_1rnull_idx, 'player_1_rank_points'] = 0

    # fill rank points manually with inferred values
    jj_2rnull_idx = df[df.player_1 == 'Joachim Johansson'].index[-1]
    df.loc[jj_2rnull_idx, 'player_1_rank_points'] = 0
    jj_3rnull_idx = df[(df.player_2 == 'Joachim Johansson') & (df.player_2_rank_points.isnull())].index
    df.loc[jj_3rnull_idx, 'player_2_rank_points'] = 0
    kc_rnull_idx = df[(df.player_1 == 'Kenneth Carlsen') & (df.player_1_rank.isnull())].index
    df.loc[kc_rnull_idx, 'player_1_rank'] = 46
    df.loc[kc_rnull_idx, 'player_1_rank_points'] = 880

    # fill remaining rank point nulls with 0
    df.player_1_rank_points = df.player_1_rank_points.fillna(0)
    df.player_2_rank_points = df.player_2_rank_points.fillna(0)

    # infer ranks from last match plus pentalties 
    th_r2null_idx = df[(df.player_2 == 'Tommy Haas') & (df.player_2_rank.isnull())].index[:2]
    df.loc[th_r2null_idx, 'player_2_rank'] = 33
    th_r1null_idx = df[(df.player_1 == 'Tommy Haas') & (df.player_1_rank.isnull())].index
    df.loc[th_r1null_idx, 'player_1_rank'] = 33
    th_r3null_idx = df[(df.player_2 == 'Tommy Haas') & (df.player_2_rank.isnull())].index
    df.loc[th_r3null_idx, 'player_2_rank'] = 490

    # 'fix'
    mrp2_idx = df[df.player_2_rank.isnull()].index
    mrp1_idx = df[df.player_1_rank.isnull()].index
    df.loc[mrp2_idx, 'player_2_rank'] = 300
    df.loc[mrp1_idx, 'player_1_rank'] = 300

    # create columns (engineer categorical feature) to determine if players are seeded
    df['player_1_seeded'] = df.player_1_seed.apply(lambda x: x > 0)
    df['player_2_seeded'] = df.player_2_seed.apply(lambda x: x > 0)

    df_clean = df = df.dropna(subset=['player_1_aces'])
    print(f'2 |{len(df)}')                                                         # LOOK HERE MASON
    # create dummy columns for surface, level, hand, and round 
    dummy_df = pd.get_dummies(df[['surface', 'tourney_level', 'player_1_hand', 'player_2_hand', 'round']], dummy_na = False, drop_first = False)
    # concat dummy columns to df
    df = pd.concat([df, dummy_df], axis = 1)
    print(f'3 |{len(df)}')                                                         # LOOK HERE MASON
    # create a empty dataframe
    h2h_df = pd.DataFrame()

    # loop through each pair of players
    for players, winner in df.groupby(['player_1', 'player_2'])['winner']:
        num_matches = len(winner)
        p1 = 0
        p2 = 0
        temp_df = pd.DataFrame()
        for i in range(0, num_matches):
            if winner.iloc[i] == players[0]:
                p1 = p1 + 1
                temp_df = temp_df.append(pd.DataFrame([[players[0], players[1], p1, p2]], columns = ['player_1', 'player_2', 'h2h_1', 'h2h_2'], index = [winner.index[i]]))
            else:
                p2 = p2 + 1 
                temp_df = temp_df.append(pd.DataFrame([[players[0], players[1], p1, p2]], columns = ['player_1', 'player_2', 'h2h_1', 'h2h_2'], index = [winner.index[i]]))


        # shift the stats by 1 row so we're not cheating on h2h record a match early
        temp_df[['h2h_1', 'h2h_2']] = temp_df[['h2h_1', 'h2h_2']].shift(1).fillna(0)
        h2h_df = h2h_df.append(temp_df)

    # join h2h info with df
    df = df.join(h2h_df[['h2h_1', 'h2h_2']])
    
    # noise
    df.h2h_1 = df.h2h_1.astype(int)
    df.h2h_2 = df.h2h_2.astype(int)
    
    # reset index to tourney date
    df = df.set_index('tourney_date')
    df.index = pd.to_datetime(df.index, format = '%Y-%m-%d')
    
    return df

# %%
# %%time
df = prepare_atp()
df.info()
# Out:
# 0 |180305
# 1 |50470
# 2 |50470
# 3 |50470
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 50470 entries, 1999-01-04 to 2019-11-24
# Data columns (total 82 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   tourney_id                        50470 non-null  object
#  1   tourney_name                      50470 non-null  object
#  2   surface                           50470 non-null  object
#  3   draw_size                         50470 non-null  int64
#  4   tourney_level                     50470 non-null  object
#  5   match_num                         50470 non-null  int64
#  6   score                             50470 non-null  object
#  7   best_of                           50470 non-null  int64
#  8   round                             50470 non-null  object
#  9   minutes                           50470 non-null  float64
#  10  player_1                          50470 non-null  object
#  11  player_2                          50470 non-null  object
#  12  player_1_age                      50470 non-null  float64
#  13  player_2_age                      50470 non-null  float64
#  14  player_1_hand                     50470 non-null  object
#  15  player_2_hand                     50470 non-null  object
#  16  player_1_ht                       50470 non-null  float64
#  17  player_2_ht                       50470 non-null  float64
#  18  player_1_id                       50470 non-null  int64
#  19  player_2_id                       50470 non-null  int64
#  20  player_1_ioc                      50470 non-null  object
#  21  player_2_ioc                      50470 non-null  object
#  22  player_1_name                     50470 non-null  object
#  23  player_2_name                     50470 non-null  object
#  24  player_1_rank                     50470 non-null  float64
#  25  player_2_rank                     50470 non-null  float64
#  26  player_1_rank_points              50470 non-null  float64
#  27  player_2_rank_points              50470 non-null  float64
#  28  player_1_seed                     18372 non-null  float64
#  29  player_2_seed                     19652 non-null  float64
#  30  player_1_aces                     50470 non-null  float64
#  31  player_2_aces                     50470 non-null  float64
#  32  player_1_double_faults            50470 non-null  float64
#  33  player_2_double_faults            50470 non-null  float64
#  34  player_1_service_points           50470 non-null  float64
#  35  player_2_service_points           50470 non-null  float64
#  36  player_1_first_serves_in          50470 non-null  float64
#  37  player_2_first_serves_in          50470 non-null  float64
#  38  player_1_first_serve_points_won   50470 non-null  float64
#  39  player_2_first_serve_points_won   50470 non-null  float64
#  40  player_1_second_serve_points_won  50470 non-null  float64
#  41  player_2_second_serve_points_won  50470 non-null  float64
#  42  player_1_service_game_total       50470 non-null  float64
#  43  player_2_service_game_total       50470 non-null  float64
#  44  player_1_break_points_saved       50470 non-null  float64
#  45  player_2_break_points_saved       50470 non-null  float64
#  46  player_1_break_points_faced       50470 non-null  float64
#  47  player_2_break_points_faced       50470 non-null  float64
#  48  winner                            50470 non-null  object
#  49  player_1_first_serve_%            50470 non-null  float64
#  50  player_2_first_serve_%            50470 non-null  float64
#  51  player_1_first_serve_win_%        50470 non-null  float64
#  52  player_2_first_serve_win_%        50470 non-null  float64
#  53  player_1_break_points_won         50470 non-null  float64
#  54  player_2_break_points_won         50470 non-null  float64
#  55  player_1_seeded                   50470 non-null  bool
#  56  player_2_seeded                   50470 non-null  bool
#  57  surface_Carpet                    50470 non-null  uint8
#  58  surface_Clay                      50470 non-null  uint8
#  59  surface_Grass                     50470 non-null  uint8
#  60  surface_Hard                      50470 non-null  uint8
#  61  tourney_level_A                   50470 non-null  uint8
#  62  tourney_level_D                   50470 non-null  uint8
#  63  tourney_level_F                   50470 non-null  uint8
#  64  tourney_level_G                   50470 non-null  uint8
#  65  tourney_level_M                   50470 non-null  uint8
#  66  player_1_hand_L                   50470 non-null  uint8
#  67  player_1_hand_R                   50470 non-null  uint8
#  68  player_2_hand_L                   50470 non-null  uint8
#  69  player_2_hand_R                   50470 non-null  uint8
#  70  round_BR                          50470 non-null  uint8
#  71  round_ER                          50470 non-null  uint8
#  72  round_F                           50470 non-null  uint8
#  73  round_QF                          50470 non-null  uint8
#  74  round_R128                        50470 non-null  uint8
#  75  round_R16                         50470 non-null  uint8
#  76  round_R32                         50470 non-null  uint8
#  77  round_R64                         50470 non-null  uint8
#  78  round_RR                          50470 non-null  uint8
#  79  round_SF                          50470 non-null  uint8
#  80  h2h_1                             50470 non-null  int64
#  81  h2h_2                             50470 non-null  int64
# dtypes: bool(2), float64(35), int64(7), object(15), uint8(23)
# memory usage: 23.5+ MB
# CPU times: user 1min 31s, sys: 485 ms, total: 1min 31s
# Wall time: 1min 31s

# %%
from proper_prep import *

# %%
calculate_column_nulls(df)
# Out:
#                            nulls  null_ratio null_percentage
# player_1_seed              32098     0.63598           63.6%
# player_2_seed              30818     0.61062          61.06%
# tourney_id                     0     0.00000            0.0%
# player_1_break_points_won      0     0.00000            0.0%
# surface_Grass                  0     0.00000            0.0%
# ...                          ...         ...             ...
# player_2_rank                  0     0.00000            0.0%
# player_1_rank                  0     0.00000            0.0%
# player_2_name                  0     0.00000            0.0%
# player_1_name                  0     0.00000            0.0%
# h2h_2                          0     0.00000            0.0%
#
# [82 rows x 3 columns]

# %%
# sanity check
df[(df.player_1 == 'Rafael Nadal') & (df.player_2 == 'Roger Federer')]
# Out:
#              tourney_id          tourney_name surface  draw_size  \
# tourney_date
# 2004-03-22     2004-403         Miami Masters    Hard         96
# 2005-03-21     2005-403         Miami Masters    Hard         96
# 2005-05-23     2005-520         Roland Garros    Clay        128
# 2006-02-27     2006-495                 Dubai    Hard         32
# 2006-04-17     2006-410   Monte Carlo Masters    Clay         64
# 2006-05-08     2006-416          Rome Masters    Clay         64
# 2006-05-29     2006-520         Roland Garros    Clay        128
# 2006-06-26     2006-540             Wimbledon   Grass        128
# 2006-11-13     2006-605           Masters Cup    Hard          8
# 2007-04-15     2007-410   Monte Carlo Masters    Clay         56
# 2007-05-14     2007-414       Hamburg Masters    Clay         56
# 2007-05-28     2007-520         Roland Garros    Clay        128
# 2007-06-25     2007-540             Wimbledon   Grass        128
# 2007-11-12     2007-605           Masters Cup    Hard          8
# 2008-04-20     2008-410   Monte Carlo Masters    Clay         56
# 2008-05-11     2008-414       Hamburg Masters    Clay         56
# 2008-05-25     2008-520         Roland Garros    Clay        128
# 2008-06-23     2008-540             Wimbledon   Grass        128
# 2009-01-19     2009-580       Australian Open    Hard        128
# 2009-05-10    2009-1536        Madrid Masters    Clay         56
# 2010-05-09    2010-1536        Madrid Masters    Clay         56
# 2010-11-21     2010-605           Tour Finals    Hard          8
# 2011-03-23     2011-403         Miami Masters    Hard         96
# 2011-05-01    2011-1536        Madrid Masters    Clay         56
# 2011-05-22     2011-520         Roland Garros    Clay        128
# 2011-11-20     2011-605           Tour Finals    Hard         16
# 2012-01-16     2012-580       Australian Open    Hard        128
# 2012-03-08     2012-404  Indian Wells Masters    Hard         96
# 2013-03-07     2013-404  Indian Wells Masters    Hard         96
# 2013-05-12     2013-416          Rome Masters    Clay         56
# 2013-08-11     2013-422    Cincinnati Masters    Hard         56
# 2013-11-04     2013-605           Tour Finals    Hard          8
# 2014-01-13     2014-580       Australian Open    Hard        128
# 2015-10-26     2015-328                 Basel    Hard         32
# 2017-01-16     2017-580       Australian Open    Hard        128
# 2017-03-06    2017-M006  Indian Wells Masters    Hard        128
# 2017-03-20    2017-M007         Miami Masters    Hard        128
# 2017-10-09    2017-5014      Shanghai Masters    Hard         64
# 2019-05-27     2019-520         Roland Garros    Clay        128
# 2019-07-01     2019-540             Wimbledon   Grass        128
#
#              tourney_level  match_num                         score  best_of  \
# tourney_date
# 2004-03-22               M         65                       6-3 6-3        3
# 2005-03-21               M         95     2-6 6-7(4) 7-6(5) 6-3 6-1        5
# 2005-05-23               G        125               6-3 4-6 6-4 6-3        5
# 2006-02-27               A         31                   2-6 6-4 6-4        3
# 2006-04-17               M         63         6-2 6-7(2) 6-3 7-6(5)        5
# 2006-05-08               M         63  6-7(0) 7-6(5) 6-4 2-6 7-6(5)        5
# 2006-05-29               G        127            1-6 6-1 6-4 7-6(4)        5
# 2006-06-26               G        127         6-0 7-6(5) 6-7(2) 6-3        5
# 2006-11-13               F          4                       6-4 7-5        3
# 2007-04-15               M         55                       6-4 6-4        3
# 2007-05-14               M         55                   2-6 6-2 6-0        3
# 2007-05-28               G        127               6-3 4-6 6-3 6-4        5
# 2007-06-25               G        127     7-6(7) 4-6 7-6(3) 2-6 6-2        5
# 2007-11-12               F          4                       6-4 6-1        3
# 2008-04-20               M         55                       7-5 7-5        3
# 2008-05-11               M         55                7-5 6-7(3) 6-3        3
# 2008-05-25               G        127                   6-1 6-3 6-0        5
# 2008-06-23               G        127     6-4 6-4 6-7(5) 6-7(8) 9-7        5
# 2009-01-19               G        127        7-5 3-6 7-6(3) 3-6 6-2        5
# 2009-05-10               M         55                       6-4 6-4        3
# 2010-05-09               M         55                    6-4 7-6(5)        3
# 2010-11-21               F          5                   6-3 3-6 6-1        3
# 2011-03-23               M         93                       6-3 6-2        3
# 2011-05-01               M         53                   5-7 6-1 6-3        3
# 2011-05-22               G        127            7-5 7-6(3) 5-7 6-1        5
# 2011-11-20               F          2                       6-3 6-0        3
# 2012-01-16               G        126         6-7(5) 6-2 7-6(5) 6-4        5
# 2012-03-08               M         94                       6-3 6-4        3
# 2013-03-07               M         92                       6-4 6-2        3
# 2013-05-12               M         55                       6-1 6-3        3
# 2013-08-11               M         51                   5-7 6-4 6-3        3
# 2013-11-04               F        514                       7-5 6-3        3
# 2014-01-13               G        125                7-6(4) 6-3 6-3        5
# 2015-10-26               A         31                   6-3 5-7 6-3        3
# 2017-01-16               G        226           6-4 3-6 6-1 3-6 6-3        5
# 2017-03-06               M        287                       6-2 6-3        3
# 2017-03-20               M        300                       6-3 6-4        3
# 2017-10-09               M        300                       6-4 6-3        3
# 2019-05-27               G       1602                   6-3 6-4 6-2        5
# 2019-07-01               G        225            7-6(3) 1-6 6-3 6-4        5
#
#              round  minutes  ... round_F round_QF  round_R128  round_R16  \
# tourney_date                 ...
# 2004-03-22     R32     70.0  ...       0        0           0          0
# 2005-03-21       F    223.0  ...       1        0           0          0
# 2005-05-23      SF    167.0  ...       0        0           0          0
# 2006-02-27       F    113.0  ...       1        0           0          0
# 2006-04-17       F    230.0  ...       1        0           0          0
# 2006-05-08       F    305.0  ...       1        0           0          0
# 2006-05-29       F    182.0  ...       1        0           0          0
# 2006-06-26       F    178.0  ...       1        0           0          0
# 2006-11-13      SF    113.0  ...       0        0           0          0
# 2007-04-15       F     95.0  ...       1        0           0          0
# 2007-05-14       F    115.0  ...       1        0           0          0
# 2007-05-28       F    190.0  ...       1        0           0          0
# 2007-06-25       F    225.0  ...       1        0           0          0
# 2007-11-12      SF     59.0  ...       0        0           0          0
# 2008-04-20       F    103.0  ...       1        0           0          0
# 2008-05-11       F    172.0  ...       1        0           0          0
# 2008-05-25       F    108.0  ...       1        0           0          0
# 2008-06-23       F    288.0  ...       1        0           0          0
# 2009-01-19       F    259.0  ...       1        0           0          0
# 2009-05-10       F     86.0  ...       1        0           0          0
# 2010-05-09       F    131.0  ...       1        0           0          0
# 2010-11-21       F     98.0  ...       1        0           0          0
# 2011-03-23      SF     79.0  ...       0        0           0          0
# 2011-05-01      SF    156.0  ...       0        0           0          0
# 2011-05-22       F    220.0  ...       1        0           0          0
# 2011-11-20      RR     61.0  ...       0        0           0          0
# 2012-01-16      SF    222.0  ...       0        0           0          0
# 2012-03-08      SF     92.0  ...       0        0           0          0
# 2013-03-07      QF     85.0  ...       0        1           0          0
# 2013-05-12       F     69.0  ...       1        0           0          0
# 2013-08-11      QF    134.0  ...       0        1           0          0
# 2013-11-04      SF     80.0  ...       0        0           0          0
# 2014-01-13      SF    144.0  ...       0        0           0          0
# 2015-10-26       F    123.0  ...       1        0           0          0
# 2017-01-16       F    217.0  ...       1        0           0          0
# 2017-03-06     R16     68.0  ...       0        0           0          1
# 2017-03-20       F     94.0  ...       1        0           0          0
# 2017-10-09       F     72.0  ...       1        0           0          0
# 2019-05-27      SF    145.0  ...       0        0           0          0
# 2019-07-01      SF    182.0  ...       0        0           0          0
#
#              round_R32 round_R64  round_RR  round_SF  h2h_1  h2h_2
# tourney_date
# 2004-03-22           1         0         0         0      0      0
# 2005-03-21           0         0         0         0      1      0
# 2005-05-23           0         0         0         1      1      1
# 2006-02-27           0         0         0         0      2      1
# 2006-04-17           0         0         0         0      3      1
# 2006-05-08           0         0         0         0      4      1
# 2006-05-29           0         0         0         0      5      1
# 2006-06-26           0         0         0         0      6      1
# 2006-11-13           0         0         0         1      6      2
# 2007-04-15           0         0         0         0      6      3
# 2007-05-14           0         0         0         0      7      3
# 2007-05-28           0         0         0         0      7      4
# 2007-06-25           0         0         0         0      8      4
# 2007-11-12           0         0         0         1      8      5
# 2008-04-20           0         0         0         0      8      6
# 2008-05-11           0         0         0         0      9      6
# 2008-05-25           0         0         0         0     10      6
# 2008-06-23           0         0         0         0     11      6
# 2009-01-19           0         0         0         0     12      6
# 2009-05-10           0         0         0         0     13      6
# 2010-05-09           0         0         0         0     13      7
# 2010-11-21           0         0         0         0     14      7
# 2011-03-23           0         0         0         1     14      8
# 2011-05-01           0         0         0         1     15      8
# 2011-05-22           0         0         0         0     16      8
# 2011-11-20           0         0         1         0     17      8
# 2012-01-16           0         0         0         1     17      9
# 2012-03-08           0         0         0         1     18      9
# 2013-03-07           0         0         0         0     18     10
# 2013-05-12           0         0         0         0     19     10
# 2013-08-11           0         0         0         0     20     10
# 2013-11-04           0         0         0         1     21     10
# 2014-01-13           0         0         0         1     22     10
# 2015-10-26           0         0         0         0     23     10
# 2017-01-16           0         0         0         0     23     11
# 2017-03-06           0         0         0         0     23     12
# 2017-03-20           0         0         0         0     23     13
# 2017-10-09           0         0         0         0     23     14
# 2019-05-27           0         0         0         1     23     15
# 2019-07-01           0         0         0         1     24     15
#
# [40 rows x 82 columns]

# %% [markdown]
# I am

# %%
df['round'].value_counts()
# Out:
# R32     16682
# R16      9648
# R64      8616
# R128     5445
# QF       5141
# SF       2684
# F        1386
# RR        846
# ER         20
# BR          2
# Name: round, dtype: int64

# %%
pd.set_option('display.max_columns', None)

# %%
df[df['round'] == 'BR']
# Out:
#              tourney_id    tourney_name surface  draw_size tourney_level  \
# tourney_date
# 2016-08-08     2016-O16    Rio Olympics    Hard         64             A
# 2018-11-05    2018-7696  NextGen Finals    Hard          8             F
#
#               match_num                      score  best_of round  minutes  \
# tourney_date
# 2016-08-08          163             6-2 6-7(1) 6-3        3    BR    169.0
# 2018-11-05          300  1-4 4-3(4) 2-4 4-2 4-3(3)        3    BR    107.0
#
#                    player_1      player_2  player_1_age  player_2_age  \
# tourney_date
# 2016-08-08    Kei Nishikori  Rafael Nadal     26.609172     30.182067
# 2018-11-05    Andrey Rublev   Jaume Munar     21.043121     21.503080
#
#              player_1_hand player_2_hand  player_1_ht  player_2_ht  \
# tourney_date
# 2016-08-08               R             L        178.0        185.0
# 2018-11-05               R             R        188.0        183.0
#
#               player_1_id  player_2_id player_1_ioc player_2_ioc  \
# tourney_date
# 2016-08-08         105453       104745          JPN          ESP
# 2018-11-05         126094       144719          RUS          ESP
#
#               player_1_name player_2_name  player_1_rank  player_2_rank  \
# tourney_date
# 2016-08-08    Kei Nishikori  Rafael Nadal            7.0            5.0
# 2018-11-05    Andrey Rublev   Jaume Munar           68.0           76.0
#
#               player_1_rank_points  player_2_rank_points  player_1_seed  \
# tourney_date
# 2016-08-08                  4390.0                4940.0            4.0
# 2018-11-05                   760.0                 703.0            5.0
#
#               player_2_seed  player_1_aces  player_2_aces  \
# tourney_date
# 2016-08-08              3.0            7.0            5.0
# 2018-11-05              7.0           10.0           15.0
#
#               player_1_double_faults  player_2_double_faults  \
# tourney_date
# 2016-08-08                       2.0                     1.0
# 2018-11-05                       7.0                     0.0
#
#               player_1_service_points  player_2_service_points  \
# tourney_date
# 2016-08-08                       89.0                    106.0
# 2018-11-05                       86.0                     95.0
#
#               player_1_first_serves_in  player_2_first_serves_in  \
# tourney_date
# 2016-08-08                        52.0                      82.0
# 2018-11-05                        52.0                      68.0
#
#               player_1_first_serve_points_won  \
# tourney_date
# 2016-08-08                               36.0
# 2018-11-05                               44.0
#
#               player_2_first_serve_points_won  \
# tourney_date
# 2016-08-08                               49.0
# 2018-11-05                               48.0
#
#               player_1_second_serve_points_won  \
# tourney_date
# 2016-08-08                                24.0
# 2018-11-05                                14.0
#
#               player_2_second_serve_points_won  player_1_service_game_total  \
# tourney_date
# 2016-08-08                                11.0                         15.0
# 2018-11-05                                16.0                         14.0
#
#               player_2_service_game_total  player_1_break_points_saved  \
# tourney_date
# 2016-08-08                           14.0                          3.0
# 2018-11-05                           15.0                          5.0
#
#               player_2_break_points_saved  player_1_break_points_faced  \
# tourney_date
# 2016-08-08                            8.0                          5.0
# 2018-11-05                           10.0                          8.0
#
#               player_2_break_points_faced         winner  \
# tourney_date
# 2016-08-08                           13.0  Kei Nishikori
# 2018-11-05                           12.0  Andrey Rublev
#
#               player_1_first_serve_%  player_2_first_serve_%  \
# tourney_date
# 2016-08-08                  0.584270                0.773585
# 2018-11-05                  0.604651                0.715789
#
#               player_1_first_serve_win_%  player_2_first_serve_win_%  \
# tourney_date
# 2016-08-08                      0.692308                    0.597561
# 2018-11-05                      0.846154                    0.705882
#
#               player_1_break_points_won  player_2_break_points_won  \
# tourney_date
# 2016-08-08                          5.0                        2.0
# 2018-11-05                          2.0                        3.0
#
#               player_1_seeded  player_2_seeded  surface_Carpet  surface_Clay  \
# tourney_date
# 2016-08-08               True             True               0             0
# 2018-11-05               True             True               0             0
#
#               surface_Grass  surface_Hard  tourney_level_A  tourney_level_D  \
# tourney_date
# 2016-08-08                0             1                1                0
# 2018-11-05                0             1                0                0
#
#               tourney_level_F  tourney_level_G  tourney_level_M  \
# tourney_date
# 2016-08-08                  0                0                0
# 2018-11-05                  1                0                0
#
#               player_1_hand_L  player_1_hand_R  player_2_hand_L  \
# tourney_date
# 2016-08-08                  0                1                1
# 2018-11-05                  0                1                0
#
#               player_2_hand_R  round_BR  round_ER  round_F  round_QF  \
# tourney_date
# 2016-08-08                  0         1         0        0         0
# 2018-11-05                  1         1         0        0         0
#
#               round_R128  round_R16  round_R32  round_R64  round_RR  round_SF  \
# tourney_date
# 2016-08-08             0          0          0          0         0         0
# 2018-11-05             0          0          0          0         0         0
#
#               h2h_1  h2h_2
# tourney_date
# 2016-08-08        1      9
# 2018-11-05        0      1
