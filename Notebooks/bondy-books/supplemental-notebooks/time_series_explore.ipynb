# %%
# basic imports 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import mason_functions as mf

from prepare import * 

# Remove Limits On Viewing Dataframes
pd.set_option('display.max_columns', None)

# %%
# load data
df = prepare_atp()

# %%
df.head()
# Out:
#              tourney_id tourney_name surface  draw_size tourney_level  \
# tourney_date
# 1999-01-11     1999-338       Sydney    Hard         32             A
# 1999-01-11     1999-338       Sydney    Hard         32             A
# 1999-01-11     1999-338       Sydney    Hard         32             A
# 1999-01-11     1999-338       Sydney    Hard         32             A
# 1999-01-11     1999-338       Sydney    Hard         32             A
#
#               match_num        score  best_of round  minutes        player_1  \
# tourney_date
# 1999-01-11           16   7-6(1) 6-1        3   R32     84.0  Lleyton Hewitt
# 1999-01-11           15  5-7 6-3 6-2        3   R32    115.0  Martin Damm Sr
# 1999-01-11           14      6-2 6-4        3   R32     61.0   Jan Siemerink
# 1999-01-11           13      6-1 6-3        3   R32     43.0    Hicham Arazi
# 1999-01-11           12   6-3 7-6(4)        3   R32     85.0     Carlos Moya
#
# ...

# %%
def cumulative_sum(L):
    # Return a list of numbers that are each the sum of a number in the input list plus all of the numbers prior to
    # this number in the index. use python's zero-indexing to format the individual sums for the return list. 
    # use a for-loop to run through the index of the input list and generate sums for each item on the return list.
    return [sum(L[:n + 1]) for n in range(len(L))]

# %%
lleyton_hewitt = df[(df.player_1 == 'Lleyton Hewitt') | (df.player_2 == 'Lleyton Hewitt')]
lleyton_hewitt
# Out:
#              tourney_id     tourney_name surface  draw_size tourney_level  \
# tourney_date
# 1999-01-11     1999-338           Sydney    Hard         32             A
# 1999-01-11     1999-338           Sydney    Hard         32             A
# 1999-01-11     1999-338           Sydney    Hard         32             A
# 1999-01-18     1999-580  Australian Open    Hard        128             G
# 1999-01-18     1999-580  Australian Open    Hard        128             G
# ...                 ...              ...     ...        ...           ...
# 2015-06-08     2015-440  s Hertogenbosch   Grass         28             A
# 2015-06-15     2015-311     Queen's Club   Grass         32             A
# 2015-08-03     2015-418       Washington    Hard         48             A
# 2015-08-31     2015-560          US Open    Hard        128             G
# 2016-01-18     2016-580  Australian Open    Hard        128             G
#
# ...

# %%
lleyton_hewitt.head(20)
# Out:
#              tourney_id          tourney_name surface  draw_size  \
# tourney_date
# 1999-01-11     1999-338                Sydney    Hard         32
# 1999-01-11     1999-338                Sydney    Hard         32
# 1999-01-11     1999-338                Sydney    Hard         32
# 1999-01-18     1999-580       Australian Open    Hard        128
# 1999-01-18     1999-580       Australian Open    Hard        128
# 1999-03-01     1999-433            Scottsdale    Hard         32
# 1999-03-01     1999-433            Scottsdale    Hard         32
# 1999-03-01     1999-433            Scottsdale    Hard         32
# 1999-03-01     1999-433            Scottsdale    Hard         32
# 1999-03-08     1999-404  Indian Wells Masters    Hard         56
# 1999-03-15     1999-403         Miami Masters    Hard         96
# 1999-05-03     1999-499          Delray Beach    Clay         32
# 1999-05-03     1999-499          Delray Beach    Clay         32
# ...
